# %% [markdown]
# ## Build a Wflow model from scratch

# %% [markdown]
# This notebook demonstrates how to prepare **Wflow** model from scratch using the command line interace (CLI).

# %% [markdown]
# All lines in this notebook which start with `!` are executed from the command line. Within the notebook environment the logging messages are shown after completion. You can also copy these lines and paste these in your shell to get more direct feedback.

# %% [markdown]
# ### HydroMT CLI build interface

# %% [markdown]
# Lets first check if the Wflow model is recognized by HydroMT

# %% [markdown]
# # SELECT CORRECT Kernal

# %%
import hydromt
# !hydromt --models
# Out:
# Model plugins:
# 	- model (hydromt 1.3.0rc5)
# 	- example_model (hydromt 1.3.0rc5)
# 	- wflow_sbm (hydromt_wflow 1.0.0.dev0)
# 	- wflow_sediment (hydromt_wflow 1.0.0.dev0)

# %%
# !hydromt --models
# Out:
# Model plugins:
# 	- model (hydromt 1.3.0rc5)
# 	- example_model (hydromt 1.3.0rc5)
# 	- wflow_sbm (hydromt_wflow 1.0.0.dev0)
# 	- wflow_sediment (hydromt_wflow 1.0.0.dev0)

# %%
# !hydromt build --help
# Out:
# Usage: hydromt build [OPTIONS] MODEL MODEL_ROOT
#
#   Build models from scratch.
#
#   Example usage: --------------
#
#   To build a wflow model: hydromt build wflow_sbm /path/to/model_root -i
#   /path/to/wflow_config.yml -d deltares_data -d /path/to/data_catalog.yml -v
#
#   To build a sfincs model: hydromt build sfincs /path/to/model_root  -i
#   /path/to/sfincs_config.yml -d /path/to/data_catalog.yml -v
#
# Options:
#   -i, --config PATH        Path to hydroMT configuration file, for the model
#                            specific implementation.  [required]
#   -d, --data TEXT          Path to local yaml data catalog file OR name of
#                            predefined data catalog.
#   --dd, --deltares-data    Flag: Shortcut to add the "deltares_data" catalog
#   --fo, --force-overwrite  Flag: If provided overwrite existing model files
#   --cache                  Flag: If provided cache tiled rasterdatasets
#   -v, --verbose            Increase verbosity.
#   -q, --quiet              Decrease verbosity.
#   --help                   Show this message and exit.

# %%
-r "{'subbasin': [12.2051, 45.8331], 'strord': 4, 'bounds': [11.70, 45.35, 12.95, 46.70]}"

# %%
# !hydromt build wflow_sbm "./wflow_test_full"  -i wflow_build.yml -d artifact_data -vv

# %%
# this should return "wflow, wflow_sediment"
# as well as the generic HydroMT models "grid_model, lumped_model, network_model, (mesh_model)"
# !hydromt --models
# Out:
# Model plugins:
# 	- model (hydromt 1.2.0.dev0)
# 	- example_model (hydromt 1.2.0.dev0)

# %% [markdown]
# Using the **HydroMT build** API we can setup a complete model from scratch. Let's get an overview of all the available options:

# %% [markdown]
# ### Model setup configuration

# %% [markdown]
# The HydroMT configuration file (YAML) contains the model setup configuration and determines which methods are used to prepare the different components of a Wflow model and in which order and optionally sets non-default arguments for each method. This configuration is passed to HydroMT using `-i <path_to_config_file>`. We have prepared several example files which are available in the model repository [examples folder](https://github.com/Deltares/hydromt_wflow/tree/main/examples) and from the [docs (building a model)](https://deltares.github.io/hydromt_wflow/latest/user_guide/wflow_build).
#
# Each header (without indent) (e.g. `setup_basemaps:`) corresponds to a model method. All model methods are explained in the [docs (model components)](https://deltares.github.io/hydromt_wflow/latest/user_guide/wflow_model_setup.html).

# %% [markdown]
# We will load the default wflow build configuration yaml file for inspection:

# %%
fn_config = "/data/shared/hydroMT_data/hydromt_dire_dawa/local_data.yml"

with open(fn_config, "r") as f:
    txt = f.read()
print(txt)
# Out:
# esa_worldcover_2021:
#   crs: 4326
#   data_type: RasterDataset
#   driver: raster
#   kwargs:
#     chunks:
#       x: 3600
#       y: 3600
#   meta:
#     category: landuse
#   path: esa_worldcover_2021.tif
# Delta_DTM:
#   crs: 4326
#   data_type: RasterDataset
#   driver: raster
#   kwargs:
#     chunks:
#       x: 3600
#       y: 3600
#   meta:
#     category: elevation
#   path: delta_DTM.tif
# soilgrids_v2.0:
#   data_type: RasterDataset
#   driver: raster
#   kwargs:
#     chunks:
#       x: 2400
#       y: 2400
#   meta:
#     category: soil
#     notes: "soilthickness is based on 1) soilgrids (global) and 2) dataset for Eurasia\
#       \ (ESDAC, 2004; Panagos et al., 2012): ESDAC, 2004. The european soil database\
#       \ distribution version 2.0, european commission and the European soil bureau\
#       \ network.  esdac.jrc.ec.europa.eu, accessed: 2017-11-17.  Panagos, P., Van\
#       \ Liedekerke, M., Jones, A., Montanarella, L., 2012. European soil data centre:\
#       \ Response to european policy support  and public data requirements. Land Use\
#       \ Policy 29 (2), 329\xE2\u20AC\u201C338. \n"
#     paper_doi: https://doi.org/10.5194/soil-2020-65
#     paper_ref: de Sousa et al. (2020)
#     source_license: CC BY 4.0
#     source_url: https://www.isric.org/explore/soilgrids/faq-soilgrids
#     source_version: 2020
#   path: soilgrids_data/*.tif
# merit_hydro_v1.0:
#   crs: 4326
#   data_type: RasterDataset
#   driver: raster
#   kwargs:
#     chunks:
#       x: 60
#       y: 60
#   meta:
#     category: topography
#     paper_doi: 10.1029/2019WR024873
#     paper_ref: Yamazaki et al. (2019)
#     source_license: CC-BY-NC 4.0 or ODbL 1.0
#     source_url: http://hydro.iis.u-tokyo.ac.jp/~yamadai/MERIT_Hydro
#     source_version: 1.0
#   path: merit_hydro_data/*.tif
# merit_hydro_index_v1.0:
#   crs: 4326
#   data_type: GeoDataFrame
#   driver: vector
#   meta:
#     category: topography
#     paper_doi: 10.5194/hess-2020-582
#     paper_ref: Eilander et al. (in review)
#     source_license: CC-BY-NC 4.0
#   path: merit_hydro_data/merit_hydro_index.geojson
# rivers_lin2019_v1:
#   data_type: GeoDataFrame
#   driver: vector
#   meta:
#     category: hydrography
#     paper_doi: 10.5281/zenodo.3552776
#     paper_ref: Lin et al. (2019)
#     source_license: CC-BY-NC 4.0
#     source_url: https://zenodo.org/record/3552776#.YVbOrppByUk
#     source_version: 1
#   path: rivers_lin2019_v1.geojson
#   rename:
#     width_m: rivwth
#     Q2: qbankfull
# chelsa_v1.2:
#   crs: 4326
#   data_type: RasterDataset
#   driver: raster
#   kwargs:
#     chunks:
#       x: 3600
#       y: 3600
#   meta:
#     category: meteo
#     paper_doi: 10.1038/sdata.2017.122
#     paper_ref: Karger et al. (2017)
#     source_license: CC BY 4.0
#     source_url: http://chelsa-climate.org/downloads/
#     source_version: 1.2
#   path: chelsa.tif
# koppen_geiger:
#   crs: 4326
#   data_type: RasterDataset
#   driver: raster
#   kwargs:
#     chunks:
#       x: 360
#       y: 360
#   meta:
#     category: meteo
#     paper_doi: 10.1127/0941-2948/2006/0130
#     paper_ref: Kottek et al. (2006)
#     source_url: http://koeppen-geiger.vu-wien.ac.at/present.htm
#     source_version: 2017
#   nodata: 0
#   path: koppen_geiger.tif
# modis_mcd15a3h_v006:
#   crs: 4326
#   data_type: RasterDataset
#   driver: raster
#   kwargs:
#     chunks:
#       x: 360
#       y: 360
#     concat: true
#   meta:
#     category: landuse
#     notes: this dataset has been extracted from GEE ('MODIS/006/MCD15A3H') for the
#       period '2003-01-01', '2017-12-31'
#     paper_doi: 10.5067/MODIS/MCD15A3H.006
#     paper_ref: Myneni et al (2015)
#     source_license: https://lpdaac.usgs.gov/data/data-citation-and-policies/
#     source_url: https://lpdaac.usgs.gov/products/mcd15a3hv006/
#     source_version: MCD15A3H V006
#   path: modis_lai_data/*.tif
# vito_2015_v2.0.2:
#   crs: 4326
#   data_type: RasterDataset
#   driver: raster
#   kwargs:
#     chunks:
#       x: 3600
#       y: 3600
#   meta:
#     category: landuse
#     paper_doi: 10.5281/zenodo.3939038
#     paper_ref: Buchhorn et al (2020)
#     source_url: https://land.copernicus.eu/global/products/lc
#     source_version: v2.0.2
#   path: vito_landuse.tif

# %% [markdown]
# ### Data for model setup

# %% [markdown]
# The `<...>_fn` arguments correspond to a data source from the `DataCatalog` which is based on a yml-file with references to the data paths/urls and how the data should be read. This file can be provided to hydromt using `-d <path_to_yml_file>`.
#
# By default, the pre-defined `artifact_data` catalog containing some example data for the Piave basin will be downloaded to `~/.hydromt_data/` which is also used for this example. An overview of the available example data is provided [here](https://deltares.github.io/hydromt/latest/user_guide/data_existing_cat.html)
# This example data is a based on the data which is available from the Deltares p-drive.
# If you have acces to this drive, a pre-configured catalog file can be loaded using the `-d deltares_data` pre-defined catalog.
#
# More background how to write a data catalog yml file can be found in the [HydroMT core docs](https://deltares.github.io/hydromt/latest/user_guide/data_prepare_cat.html)

# %% [markdown]
# ### Setup complete Wflow model

# %% [markdown]
# Once we have prepared our data catalog and model build settings file, we are ready to ask HydroMT to build our Wflow model. Building the model can be done from the command line. Down below is an example for the Northern part of the Piave basin in Italy:

# %%
# NOTE: copy this line (without !) to your shell for more direct feedback
# !hydromt build wflow_sbm "./wflow_test_full2" -i ./model_build_files/first_wflow_build.yml -d artifact_data --fo -v
# Out:
# 2025-11-20 09:13:11,638 - hydromt - log - INFO - HydroMT version: 1.3.0-rc5
# 2025-11-20 09:13:12,168 - hydromt.data_catalog.data_catalog - data_catalog - INFO - Reading data catalog artifact_data latest
# 2025-11-20 09:13:12,168 - hydromt.data_catalog.data_catalog - data_catalog - INFO - Parsing data catalog from /home/test2/.hydromt/artifact_data/v1.0.0/data_catalog.yml
# 2025-11-20 09:13:12,922 - hydromt.model.model - model - INFO - Initializing wflow_sbm model from hydromt_wflow (v1.0.0.dev0).
# 2025-11-20 09:13:12,922 - hydromt.data_catalog.data_catalog - data_catalog - INFO - Parsing data catalog from /opt/icpac-course/hydromt_wflow/hydromt_wflow/data/parameters_data.yml
# 2025-11-20 09:13:12,937 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Supported Wflow.jl version v1+
# 2025-11-20 09:13:12,937 - hydromt.hydromt_wflow.components.config - config - INFO - Reading default config file from /opt/icpac-course/hydromt_wflow/hydromt_wflow/data/wflow_sbm/wflow_sbm.toml.
# 2025-11-20 09:13:12,938 - hydromt - log - INFO - HydroMT version: 1.3.0-rc5
# 2025-11-20 09:13:12,939 - hydromt.model.model - model - INFO - build: setup_config
# 2025-11-20 09:13:12,939 - hydromt.model.model - model - INFO - setup_config.data={'time.starttime': datetime.datetime(2010, 1, 1, 0, 0), 'time.endtime': datetime.datetime(2010, 3, 31, 0, 0), 'time.timestepsecs': 86400, 'input.path_forcing': 'inmaps-era5-2010.nc', 'output.netcdf_grid.path': 'output.nc', 'output.netcdf_grid.compressionlevel': 1, 'output.netcdf_grid.variables.river_water__volume_flow_rate': 'q_av'}
# 2025-11-20 09:13:12,939 - hydromt.model.model - model - INFO - build: setup_basemaps
# 2025-11-20 09:13:12,939 - hydromt.model.model - model - INFO - setup_basemaps.basin_index_fn=merit_hydro_index
# 2025-11-20 09:13:12,939 - hydromt.model.model - model - INFO - setup_basemaps.res=0.00833
# 2025-11-20 09:13:12,939 - hydromt.model.model - model - INFO - setup_basemaps.upscale_method=ihu
# 2025-11-20 09:13:12,939 - hydromt.model.model - model - INFO - setup_basemaps.output_names={'basin__local_drain_direction': 'local_drain_direction', 'subbasin_location__count': 'subcatchment', 'land_surface__slope': 'land_slope'}
# 2025-11-20 09:13:12,939 - hydromt.model.model - model - INFO - setup_basemaps.hydrography_fn=merit_hydro
# 2025-11-20 09:13:12,939 - hydromt.model.model - model - INFO - setup_basemaps.region={'subbasin': [12.2051, 45.8331], 'strord': 4, 'bounds': [11.7, 45.35, 12.95, 46.7]}
# 2025-11-20 09:13:12,939 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Preparing base hydrography basemaps.
# 2025-11-20 09:13:12,940 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading merit_hydro RasterDataset data from /home/test2/.hydromt/artifact_data/latest/merit_hydro/{variable}.tif
# 2025-11-20 09:13:13,062 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading merit_hydro_index GeoDataFrame data from /home/test2/.hydromt/artifact_data/latest/merit_hydro_index.gpkg
# 2025-11-20 09:13:16,405 - hydromt.model.processes.basin_mask - basin_mask - INFO - subbasin bbox: [11.7750, 45.8042, 12.7450, 46.6900]
# 2025-11-20 09:13:16,488 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - (Sub)basin at original resolution has 664756 cells.
# 2025-11-20 09:13:16,679 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Upscale flow direction data: 10x, ihu method.
# 2025-11-20 09:13:30,652 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Derive stream order.
# 2025-11-20 09:13:30,838 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Map shape: (106, 116); active cells: 6637.
# 2025-11-20 09:13:30,838 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Outlet coordinates (1/1): (12.20750,45.83583).
# 2025-11-20 09:13:30,862 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Adding basin shape to staticgeoms.
# 2025-11-20 09:13:30,878 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Derive elevation and slope.
# 2025-11-20 09:13:31,123 - hydromt.model.model - model - INFO - build: setup_rivers
# 2025-11-20 09:13:31,123 - hydromt.model.model - model - INFO - setup_rivers.river_geom_fn=hydro_rivers_lin
# 2025-11-20 09:13:31,124 - hydromt.model.model - model - INFO - setup_rivers.river_upa=30
# 2025-11-20 09:13:31,124 - hydromt.model.model - model - INFO - setup_rivers.rivdph_method=powlaw
# 2025-11-20 09:13:31,124 - hydromt.model.model - model - INFO - setup_rivers.slope_len=2000
# 2025-11-20 09:13:31,124 - hydromt.model.model - model - INFO - setup_rivers.min_rivlen_ratio=0.0
# 2025-11-20 09:13:31,124 - hydromt.model.model - model - INFO - setup_rivers.min_rivdph=1
# 2025-11-20 09:13:31,124 - hydromt.model.model - model - INFO - setup_rivers.min_rivwth=30
# 2025-11-20 09:13:31,124 - hydromt.model.model - model - INFO - setup_rivers.smooth_len=5000
# 2025-11-20 09:13:31,124 - hydromt.model.model - model - INFO - setup_rivers.elevtn_map=land_elevation
# 2025-11-20 09:13:31,124 - hydromt.model.model - model - INFO - setup_rivers.river_routing=kinematic_wave
# 2025-11-20 09:13:31,124 - hydromt.model.model - model - INFO - setup_rivers.connectivity=8
# 2025-11-20 09:13:31,124 - hydromt.model.model - model - INFO - setup_rivers.output_names={'river_location__mask': 'river_mask', 'river__length': 'river_length', 'river__width': 'river_width', 'river_bank_water__depth': 'river_depth', 'river__slope': 'river_slope', 'river_bank_water__elevation': 'river_bank_elevation'}
# 2025-11-20 09:13:31,124 - hydromt.model.model - model - INFO - setup_rivers.hydrography_fn=merit_hydro
# 2025-11-20 09:13:31,124 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Preparing river maps.
# 2025-11-20 09:13:31,129 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading merit_hydro RasterDataset data from /home/test2/.hydromt/artifact_data/latest/merit_hydro/{variable}.tif
# 2025-11-20 09:13:31,227 - hydromt.hydromt_wflow.workflows.river - river - INFO - Set river mask (min uparea: 30 km2) and prepare flow dirs.
# 2025-11-20 09:13:31,450 - hydromt.hydromt_wflow.workflows.river - river - INFO - Derive river length.
# 2025-11-20 09:13:34,920 - hydromt.hydromt_wflow.workflows.river - river - INFO - Derive river slope.
# 2025-11-20 09:13:35,674 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading hydro_rivers_lin GeoDataFrame data from /home/test2/.hydromt/artifact_data/latest/rivers_lin2019_v1.gpkg
# 2025-11-20 09:13:35,870 - hydromt.hydromt_wflow.workflows.river - river - INFO - Derive ['rivwth', 'qbankfull'] from shapefile.
# 2025-11-20 09:13:35,921 - hydromt.hydromt_wflow.workflows.river - river - INFO - Valid for 381/655 river cells (max dist: 392 m).
# 2025-11-20 09:13:39,012 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Update wflow config model.river_routing="kinematic_wave"
# 2025-11-20 09:13:39,012 - hydromt.model.model - model - INFO - build: setup_reservoirs_simple_control
# 2025-11-20 09:13:39,012 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.timeseries_fn=gww
# 2025-11-20 09:13:39,012 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.overwrite_existing=False
# 2025-11-20 09:13:39,012 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.duplicate_id=error
# 2025-11-20 09:13:39,012 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.min_area=1.0
# 2025-11-20 09:13:39,012 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.output_names={'reservoir_area__count': 'reservoir_area_id', 'reservoir_location__count': 'reservoir_outlet_id', 'reservoir_surface__area': 'reservoir_area', 'reservoir_water_surface__initial_elevation': 'reservoir_initial_depth', 'reservoir_water__rating_curve_type_count': 'reservoir_rating_curve', 'reservoir_water__storage_curve_type_count': 'reservoir_storage_curve', 'reservoir_water__max_volume': 'reservoir_max_volume', 'reservoir_water__target_min_volume_fraction': 'reservoir_target_min_fraction', 'reservoir_water__target_full_volume_fraction': 'reservoir_target_full_fraction', 'reservoir_water_demand__required_downstream_volume_flow_rate': 'reservoir_demand', 'reservoir_water_release_below_spillway__max_volume_flow_rate': 'reservoir_max_release'}
# 2025-11-20 09:13:39,012 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.geom_name=meta_reservoirs_simple_control
# 2025-11-20 09:13:39,012 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.reservoirs_fn=hydro_reservoirs
# 2025-11-20 09:13:39,012 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing reservoir with simple control maps.
# 2025-11-20 09:13:39,012 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading hydro_reservoirs GeoDataFrame data from /home/test2/.hydromt/artifact_data/latest/hydro_reservoirs.gpkg
# 2025-11-20 09:13:39,033 - hydromt.hydromt_wflow.workflows.reservoirs - reservoirs - INFO - 0 reservoir(s) of sufficient size found within region.
# 2025-11-20 09:13:39,033 - hydromt.model.model - model - INFO - build: setup_reservoirs_no_control
# 2025-11-20 09:13:39,033 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.rating_curve_fns=None
# 2025-11-20 09:13:39,033 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.overwrite_existing=False
# 2025-11-20 09:13:39,033 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.duplicate_id=error
# 2025-11-20 09:13:39,033 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.min_area=10.0
# 2025-11-20 09:13:39,033 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.output_names={'reservoir_area__count': 'reservoir_area_id', 'reservoir_location__count': 'reservoir_outlet_id', 'reservoir_surface__area': 'reservoir_area', 'reservoir_water_surface__initial_elevation': 'reservoir_initial_depth', 'reservoir_water_flow_threshold_level__elevation': 'reservoir_outflow_threshold', 'reservoir_water__rating_curve_coefficient': 'reservoir_b', 'reservoir_water__rating_curve_exponent': 'reservoir_e', 'reservoir_water__rating_curve_type_count': 'reservoir_rating_curve', 'reservoir_water__storage_curve_type_count': 'reservoir_storage_curve', 'reservoir_lower_location__count': 'reservoir_lower_id'}
# 2025-11-20 09:13:39,033 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.geom_name=meta_reservoirs_no_control
# 2025-11-20 09:13:39,033 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.reservoirs_fn=hydro_lakes
# 2025-11-20 09:13:39,033 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing reservoir maps.
# 2025-11-20 09:13:39,034 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading hydro_lakes GeoDataFrame data from /home/test2/.hydromt/artifact_data/latest/hydro_lakes.gpkg
# 2025-11-20 09:13:39,044 - hydromt.hydromt_wflow.workflows.reservoirs - reservoirs - INFO - 0 reservoir(s) of sufficient size found within region.
# 2025-11-20 09:13:39,045 - hydromt.model.model - model - INFO - build: setup_glaciers
# 2025-11-20 09:13:39,045 - hydromt.model.model - model - INFO - setup_glaciers.min_area=0.0
# 2025-11-20 09:13:39,045 - hydromt.model.model - model - INFO - setup_glaciers.output_names={'glacier_surface__area_fraction': 'glacier_fraction', 'glacier_ice__initial_leq_depth': 'glacier_initial_leq_depth'}
# 2025-11-20 09:13:39,045 - hydromt.model.model - model - INFO - setup_glaciers.geom_name=glaciers
# 2025-11-20 09:13:39,045 - hydromt.model.model - model - INFO - setup_glaciers.glaciers_fn=rgi
# 2025-11-20 09:13:39,045 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing glacier maps.
# 2025-11-20 09:13:39,045 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading rgi GeoDataFrame data from /home/test2/.hydromt/artifact_data/latest/rgi.gpkg
# 2025-11-20 09:13:39,057 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - 38 glaciers of sufficient size found within region.
# 2025-11-20 09:13:40,422 - hydromt.model.model - model - INFO - build: setup_lulcmaps
# 2025-11-20 09:13:40,422 - hydromt.model.model - model - INFO - setup_lulcmaps.lulc_mapping_fn=globcover_mapping_default
# 2025-11-20 09:13:40,423 - hydromt.model.model - model - INFO - setup_lulcmaps.lulc_vars=['landuse', 'vegetation_kext', 'land_manning_n', 'soil_compacted_fraction', 'vegetation_root_depth', 'vegetation_leaf_storage', 'vegetation_wood_storage', 'land_water_fraction', 'vegetation_crop_factor', 'vegetation_feddes_alpha_h1', 'vegetation_feddes_h1', 'vegetation_feddes_h2', 'vegetation_feddes_h3_high', 'vegetation_feddes_h3_low', 'vegetation_feddes_h4']
# 2025-11-20 09:13:40,423 - hydromt.model.model - model - INFO - setup_lulcmaps.output_names_suffix=None
# 2025-11-20 09:13:40,423 - hydromt.model.model - model - INFO - setup_lulcmaps.lulc_fn=globcover_2009
# 2025-11-20 09:13:40,423 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Preparing LULC parameter maps.
# 2025-11-20 09:13:40,425 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading globcover_2009 RasterDataset data from /home/test2/.hydromt/artifact_data/latest/globcover.tif
# 2025-11-20 09:13:40,438 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading globcover_mapping_default DataFrame data from /opt/icpac-course/hydromt_wflow/hydromt_wflow/data/lulc/globcover_mapping.csv
# 2025-11-20 09:13:40,450 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving landuse using mode resampling (nodata=230).
# 2025-11-20 09:13:40,560 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_kext using average resampling (nodata=-999.0).
# 2025-11-20 09:13:40,585 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving land_manning_n using average resampling (nodata=-999.0).
# 2025-11-20 09:13:40,611 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving soil_compacted_fraction using average resampling (nodata=-999.0).
# 2025-11-20 09:13:40,636 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_root_depth using average resampling (nodata=-999.0).
# 2025-11-20 09:13:40,662 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_leaf_storage using average resampling (nodata=-999.0).
# 2025-11-20 09:13:40,686 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_wood_storage using average resampling (nodata=-999.0).
# 2025-11-20 09:13:40,712 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving land_water_fraction using average resampling (nodata=-999.0).
# 2025-11-20 09:13:40,737 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_crop_factor using average resampling (nodata=-999.0).
# 2025-11-20 09:13:40,762 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_alpha_h1 using mode resampling (nodata=-999).
# 2025-11-20 09:13:40,868 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h1 using average resampling (nodata=-999).
# 2025-11-20 09:13:40,895 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h2 using average resampling (nodata=-999).
# 2025-11-20 09:13:40,924 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h3_high using average resampling (nodata=-999).
# 2025-11-20 09:13:40,953 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h3_low using average resampling (nodata=-999).
# 2025-11-20 09:13:40,981 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h4 using average resampling (nodata=-999).
# 2025-11-20 09:13:41,048 - hydromt.model.model - model - INFO - build: setup_laimaps
# 2025-11-20 09:13:41,048 - hydromt.model.model - model - INFO - setup_laimaps.lulc_fn=None
# 2025-11-20 09:13:41,048 - hydromt.model.model - model - INFO - setup_laimaps.lulc_sampling_method=any
# 2025-11-20 09:13:41,048 - hydromt.model.model - model - INFO - setup_laimaps.lulc_zero_classes=[]
# 2025-11-20 09:13:41,048 - hydromt.model.model - model - INFO - setup_laimaps.buffer=2
# 2025-11-20 09:13:41,048 - hydromt.model.model - model - INFO - setup_laimaps.output_name=vegetation_leaf_area_index
# 2025-11-20 09:13:41,048 - hydromt.model.model - model - INFO - setup_laimaps.lai_fn=modis_lai
# 2025-11-20 09:13:41,048 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing LAI maps.
# 2025-11-20 09:13:41,051 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading modis_lai RasterDataset data from /home/test2/.hydromt/artifact_data/latest/modis_lai.nc
# 2025-11-20 09:13:42,699 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving LAI using average resampling (nodata=nan).
# 2025-11-20 09:13:42,812 - hydromt.model.model - model - INFO - build: setup_soilmaps
# 2025-11-20 09:13:42,813 - hydromt.model.model - model - INFO - setup_soilmaps.soil_fn=soilgrids
# 2025-11-20 09:13:42,813 - hydromt.model.model - model - INFO - setup_soilmaps.ptf_ksatver=brakensiek
# 2025-11-20 09:13:42,813 - hydromt.model.model - model - INFO - setup_soilmaps.wflow_thicknesslayers=[100, 300, 800]
# 2025-11-20 09:13:42,813 - hydromt.model.model - model - INFO - setup_soilmaps.output_names={'soil_water__saturated_volume_fraction': 'soil_theta_s', 'soil_water__residual_volume_fraction': 'soil_theta_r', 'soil_surface_water__vertical_saturated_hydraulic_conductivity': 'soil_ksat_vertical', 'soil__thickness': 'soil_thickness', 'soil_water__vertical_saturated_hydraulic_conductivity_scale_parameter': 'soil_f', 'soil_layer_water__brooks_corey_exponent': 'soil_brooks_corey_c'}
# 2025-11-20 09:13:42,813 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing soil parameter maps.
# 2025-11-20 09:13:42,816 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading soilgrids RasterDataset data from /home/test2/.hydromt/artifact_data/latest/soilgrids/{variable}.tif
# 2025-11-20 09:13:43,523 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - calculate and resample theta_s
# 2025-11-20 09:13:43,824 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - calculate and resample theta_r
# 2025-11-20 09:13:44,171 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - calculate and resample ksat_vertical
# 2025-11-20 09:13:44,265 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - calculate and resample pore size distribution index
# 2025-11-20 09:13:44,948 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - fit z - log(ksat_vertical ) with numpy linalg regression (y = b*x) -> M_
# 2025-11-20 09:13:45,799 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - fit zi - Ksat with curve_fit (scipy.optimize) -> M
# 2025-11-20 09:13:49,749 - hydromt.gis.raster - raster - WARNING - No numerical nodata value found, skipping set_nodata
# 2025-11-20 09:13:50,455 - hydromt.gis.raster - raster - WARNING - No numerical nodata value found, skipping set_nodata
# 2025-11-20 09:13:50,649 - hydromt.gis.raster - raster - WARNING - No numerical nodata value found, skipping set_nodata
# 2025-11-20 09:13:50,795 - hydromt.model.model - model - INFO - build: setup_outlets
# 2025-11-20 09:13:50,795 - hydromt.model.model - model - INFO - setup_outlets.river_only=True
# 2025-11-20 09:13:50,795 - hydromt.model.model - model - INFO - setup_outlets.toml_output=csv
# 2025-11-20 09:13:50,795 - hydromt.model.model - model - INFO - setup_outlets.gauge_toml_header=['river_q']
# 2025-11-20 09:13:50,795 - hydromt.model.model - model - INFO - setup_outlets.gauge_toml_param=['river_water__volume_flow_rate']
# 2025-11-20 09:13:50,795 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Gauges locations set based on river outlets.
# 2025-11-20 09:13:50,812 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Gauges map based on catchment river outlets added.
# 2025-11-20 09:13:50,812 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Adding ['river_water__volume_flow_rate'] to csv section of toml.
# 2025-11-20 09:13:50,812 - hydromt.model.model - model - INFO - build: setup_gauges
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.index_col=None
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.snap_to_river=True
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.mask=None
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.snap_uparea=False
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.max_dist=10000.0
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.wdw=3
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.rel_error=0.05
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.abs_error=50.0
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.fillna=False
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.derive_subcatch=False
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.basename=None
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.toml_output=csv
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.gauge_toml_header=['river_q', 'precip']
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.gauge_toml_param=['river_water__volume_flow_rate', 'atmosphere_water__precipitation_volume_flux']
# 2025-11-20 09:13:50,813 - hydromt.model.model - model - INFO - setup_gauges.gauges_fn=grdc
# 2025-11-20 09:13:50,813 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading grdc GeoDataFrame data from /home/test2/.hydromt/artifact_data/latest/grdc.csv
# 2025-11-20 09:13:50,823 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - 3 grdc gauge locations found within domain
# 2025-11-20 09:13:51,199 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Adding ['river_water__volume_flow_rate', 'atmosphere_water__precipitation_volume_flux'] to csv section of toml.
# 2025-11-20 09:13:51,200 - hydromt.model.model - model - INFO - build: setup_precip_forcing
# 2025-11-20 09:13:51,200 - hydromt.model.model - model - INFO - setup_precip_forcing.precip_clim_fn=None
# 2025-11-20 09:13:51,200 - hydromt.model.model - model - INFO - setup_precip_forcing.chunksize=None
# 2025-11-20 09:13:51,200 - hydromt.model.model - model - INFO - setup_precip_forcing.precip_fn=era5
# 2025-11-20 09:13:51,202 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading era5 RasterDataset data from /home/test2/.hydromt/artifact_data/latest/era5.nc
# 2025-11-20 09:13:51,303 - hydromt.model.model - model - INFO - build: setup_temp_pet_forcing
# 2025-11-20 09:13:51,303 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.pet_method=debruin
# 2025-11-20 09:13:51,303 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.press_correction=True
# 2025-11-20 09:13:51,303 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.temp_correction=True
# 2025-11-20 09:13:51,303 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.wind_correction=True
# 2025-11-20 09:13:51,303 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.wind_altitude=10
# 2025-11-20 09:13:51,303 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.reproj_method=nearest_index
# 2025-11-20 09:13:51,303 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.fillna_method=None
# 2025-11-20 09:13:51,303 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.dem_forcing_fn=era5_orography
# 2025-11-20 09:13:51,303 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.skip_pet=False
# 2025-11-20 09:13:51,303 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.chunksize=None
# 2025-11-20 09:13:51,303 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.temp_pet_fn=era5
# 2025-11-20 09:13:51,306 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading era5 RasterDataset data from /home/test2/.hydromt/artifact_data/latest/era5.nc
# 2025-11-20 09:13:51,367 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading era5_orography RasterDataset data from /home/test2/.hydromt/artifact_data/latest/era5_orography.nc
# 2025-11-20 09:13:51,674 - hydromt.model.model - model - INFO - build: setup_constant_pars
# 2025-11-20 09:13:51,674 - hydromt.model.model - model - INFO - setup_constant_pars.subsurface_water__horizontal_to_vertical_saturated_hydraulic_conductivity_ratio=100
# 2025-11-20 09:13:51,674 - hydromt.model.model - model - INFO - setup_constant_pars.snowpack__degree_day_coefficient=3.75653
# 2025-11-20 09:13:51,674 - hydromt.model.model - model - INFO - setup_constant_pars.soil_surface_water__infiltration_reduction_parameter=0.038
# 2025-11-20 09:13:51,674 - hydromt.model.model - model - INFO - setup_constant_pars.vegetation_canopy_water__mean_evaporation_to_mean_precipitation_ratio=0.11
# 2025-11-20 09:13:51,674 - hydromt.model.model - model - INFO - setup_constant_pars.compacted_soil_surface_water__infiltration_capacity=10
# 2025-11-20 09:13:51,674 - hydromt.model.model - model - INFO - setup_constant_pars.soil_water_saturated_zone_bottom__max_leakage_volume_flux=0
# 2025-11-20 09:13:51,675 - hydromt.model.model - model - INFO - setup_constant_pars.soil_wet_root__sigmoid_function_shape_parameter=-500
# 2025-11-20 09:13:51,675 - hydromt.model.model - model - INFO - setup_constant_pars.atmosphere_air__snowfall_temperature_threshold=0
# 2025-11-20 09:13:51,675 - hydromt.model.model - model - INFO - setup_constant_pars.atmosphere_air__snowfall_temperature_interval=2
# 2025-11-20 09:13:51,675 - hydromt.model.model - model - INFO - setup_constant_pars.snowpack__melting_temperature_threshold=0
# 2025-11-20 09:13:51,675 - hydromt.model.model - model - INFO - setup_constant_pars.snowpack__liquid_water_holding_capacity=0.1
# 2025-11-20 09:13:51,675 - hydromt.model.model - model - INFO - setup_constant_pars.glacier_ice__degree_day_coefficient=3
# 2025-11-20 09:13:51,675 - hydromt.model.model - model - INFO - setup_constant_pars.glacier_firn_accumulation__snowpack_dry_snow_leq_depth_fraction=0.001
# 2025-11-20 09:13:51,675 - hydromt.model.model - model - INFO - setup_constant_pars.glacier_ice__melting_temperature_threshold=0
# 2025-11-20 09:13:51,675 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Write model data to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/wflow_test_full2
# 2025-11-20 09:13:51,688 - hydromt.model.components.grid - grid - INFO - wflow_sbm.staticmaps: Writing grid data to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/wflow_test_full2/staticmaps.nc.
# 2025-11-20 09:13:51,809 - hydromt.model.components.spatial - spatial - INFO - wflow_sbm.staticmaps: Writing region to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/wflow_test_full2/staticgeoms/region.geojson.
# 2025-11-20 09:13:51,845 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/wflow_test_full2/staticgeoms/basins_highres.geojson.
# 2025-11-20 09:13:51,869 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/wflow_test_full2/staticgeoms/basins.geojson.
# 2025-11-20 09:13:51,875 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/wflow_test_full2/staticgeoms/rivers.geojson.
# 2025-11-20 09:13:51,882 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/wflow_test_full2/staticgeoms/glaciers.geojson.
# 2025-11-20 09:13:51,928 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/wflow_test_full2/staticgeoms/outlets.geojson.
# 2025-11-20 09:13:51,931 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/wflow_test_full2/staticgeoms/gauges_grdc.geojson.
# 2025-11-20 09:13:51,935 - hydromt.hydromt_wflow.components.forcing - forcing - INFO - Write forcing file
# 2025-11-20 09:13:51,936 - hydromt.hydromt_wflow.components.forcing - forcing - WARNING - Start time 2010-01-01T00:00:00.000000 does not match the beginning of the data. Changing to start of the data: 2010-02-02T00:00:00.000000000.
# 2025-11-20 09:13:51,936 - hydromt.hydromt_wflow.components.forcing - forcing - WARNING - End time 2010-03-31T00:00:00.000000 does not match the end of the data. Changing to end of the data: 2010-02-15T00:00:00.000000000.
# 2025-11-20 09:13:51,939 - hydromt.hydromt_wflow.components.forcing - forcing - INFO - Writing file /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/wflow_test_full2/inmaps-era5-2010.nc
# [########################################] | 100% Completed | 202.07 ms
# 2025-11-20 09:13:52,169 - hydromt.model.components.tables - tables - INFO - wflow_sbm.tables: No tables found, skip writing.
# 2025-11-20 09:13:52,169 - hydromt.model.components.grid - grid - INFO - wflow_sbm.states: No grid data found, skip writing.
# 2025-11-20 09:13:52,169 - hydromt.hydromt_wflow.components.config - config - INFO - Writing model config to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/wflow_test_full2/wflow_sbm.toml.

# %% [markdown]
# With this example we build a complete Wflow model including forcing. The example means the following: run **hydromt build** with:
#
# * `wflow` : i.e. build a Wflow model
# * `./wflow_test_full` : output model folder
# * `-r "{'subbasin': [12.2051, 45.8331], 'strord': 4, 'bounds': [11.70, 45.35, 12.95, 46.70]}"` : derive a subbasin with its outlet at the given x,y coordinates and within the given bounds [xmin, ymin, xmax, ymax] (WGS84) snapped to a river with minimum stream order (strord) of 4. All *REGION* options are described in the [docs](https://deltares.github.io/hydromt/latest/user_guide/model_region)
# * `-i wflow_build.yml` : setup configuration file including all components to build and their arguments
# * `-d artifact_data`: data catalog to use. Here `artifact_data` which contains a global data extract for Northern Italy for demo purposes.
# * `-vv` : give some extra verbosity (2 * v) to display feedback on screen. Now debug messages are provided.

# %% [markdown]
# Next we check which files have been created. The model root should contain two netcdf (.nc) files, one for the staticmaps and one for the forcing data, a wflow run configuration (.toml) file. These files are sufficient to run the wflow model. In addition several geometry (.geojson) files are saved in the *staticgeoms* folder.  Finally, the setup process is logged in the hydromt.log file.

# %%
import os

root = "wflow_test_full"
for path, _, files in os.walk(root):
    print(path)
    for name in files:
        if name.endswith(".xml"):
            continue
        print(f" - {name}")
# Out:
# wflow_test_full
#  - staticmaps.nc
#  - wflow_sbm.toml
#  - inmaps-era5-2010.nc
#  - hydromt.log
#  - hydromt_data.yml
# wflow_test_full/staticgeoms
#  - glaciers.geojson
#  - outlets.geojson
#  - basins_highres.geojson
#  - region.geojson
#  - rivers.geojson
#  - basins.geojson
#  - gauges_grdc.geojson

# %% [markdown]
# ### Visualize and/or inspect model schematization

# %% [markdown]
# * The **wflow plot** example notebook contains scripts to visualize your model
# * The **wflow nc to raster files** example notebook contains scripts to write the nc model files to a netcdf which can be used to inspect (and modify) the model layers in e.g. QGIS.

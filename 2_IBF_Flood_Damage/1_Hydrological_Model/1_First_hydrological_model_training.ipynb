# %% [markdown]
# ![Partners](../../images/partners.png)

# %% [markdown]
# # Building Your First Wflow Hydrological Model
#
# ## Overview
#
# This notebook provides a comprehensive, step-by-step guide to building a **Wflow hydrological model** from scratch using **HydroMT** (Hydrological Model Tools). By the end of this tutorial, you will understand how to set up and configure a distributed hydrological model.
#
# ### What is Wflow?
#
# Wflow is an open-source distributed hydrological modeling framework developed by Deltares. It simulates hydrological processes at high spatial and temporal resolution, making it ideal for:
# - Flood forecasting and early warning systems
# - Water resources management
# - Climate impact assessments
# - Catchment-scale water balance studies
#
# ### What is HydroMT?
#
# HydroMT is a Python package that automates and standardizes the setup of various hydrological models. It:
# - Automates data collection from multiple sources
# - Handles spatial data processing and resampling
# - Provides consistent workflows across different model types
# - Reduces manual preprocessing work significantly
#
# ---
#
# ## Learning Objectives
#
# By completing this notebook, you will be able to:
#
# 1. **Verify** that HydroMT recognizes the Wflow model plugin
# 2. **Build** a complete Wflow model using the HydroMT CLI and example data
# 3. **Visualize** the model components (DEM, rivers, land use, etc.)
# 4. **Understand** the structure and key files of a Wflow model
# 5. **Run** the Wflow model simulation
# 6. **Analyze and visualize** model outputs (discharge, spatial patterns)
#
# ---
#
# ## Important Note on Command Execution
#
# All lines in this notebook starting with `!` are executed from the command line. Within the notebook environment, logging messages appear after execution completes.
#
# **Tip**: You can copy these commands (without the `!`) and paste them directly into your terminal for real-time feedback during execution.

# %% [markdown]
# ---
#
# ## Part 1: Environment Setup and Verification
#
# ### 1.1 Select the Correct Kernel
#
# **⚠️ IMPORTANT**: Before running any code, ensure you have selected the correct kernel:
#
# 1. Go to **Kernel** → **Change Kernel** in the Jupyter menu in the top right corner of this notebook
# 2. Select **"HydroMT wflow (pixi)"** or the kernel that contains your HydroMT installation
#
# The kernel name should appear in the top-right corner of this notebook. If you see a different kernel name, click on it to change it.

# %% [markdown]
# ### 1.2 Verify HydroMT Installation
#
# Let's verify that HydroMT is properly installed and can recognize the Wflow model plugin. This command lists all available model plugins in your HydroMT installation.
#
# **Expected output**: You should see `wflow_sbm` and `wflow_sediment` listed among the available model plugins.

# %%
# List all available HydroMT model plugins
# !hydromt --models
# Out:
# Model plugins:
# 	- model (hydromt 1.3.0rc5)
# 	- example_model (hydromt 1.3.0rc5)
# 	- wflow_sbm (hydromt_wflow 1.0.0.dev0)
# 	- wflow_sediment (hydromt_wflow 1.0.0.dev0)

# %% [markdown]
# **Understanding the output**:
# - `model` and `example_model`: Base HydroMT classes
# - `wflow_sbm`: Wflow model using the SBM (Soil-Based Modeling) concept
# - `wflow_sediment`: Wflow sediment transport model (extension)

# %% [markdown]
# ---
#
# ## Part 2: Understanding the HydroMT Build Interface
#
# ### 2.1 The `hydromt build` Command
#
# The `hydromt build` command is the primary tool for creating new models. Its general syntax is:
#
# ```bash
# hydromt build MODEL_TYPE MODEL_ROOT -r REGION -i DATA_CATALOG -d DESTINATION [options]
# ```
#
# **Key arguments**:
# - `MODEL_TYPE`: The model to build (e.g., `wflow_sbm`)
# - `MODEL_ROOT`: Output directory where the model will be saved
# - `-r / --region`: Defines the geographic extent of your model
# - `-i / --config`: Configuration file (YAML) specifying build steps
# - `-d / --data`: Data catalog(s) containing input datasets
#
# ### 2.2 Region Definition Options
#
# You can define your study region in several ways:
#
# 1. **Basin outlets**: `{basin: [lon, lat]}` - Delineates upstream catchment
# 2. **Bounding box**: `{bbox: [xmin, ymin, xmax, ymax]}` - Rectangular area
# 3. **Geometry file**: `{geom: 'path/to/shapefile.shp'}` - Custom boundary
# 4. **Existing basins**: `{basin_index: id}` - Use predefined basin ID
#
# ### 2.3 Configuration File Structure
#
# The configuration file (YAML format) contains a sequence of setup methods that HydroMT executes. Common methods include:
#
# - `setup_basemaps`: Prepares topography, land use, and soil data
# - `setup_rivers`: Delineates river network
# - `setup_reservoirs`: Adds reservoir locations and parameters
# - `setup_lakes`: Includes lake geometries and characteristics
# - `setup_glaciers`: Incorporates glacier coverage (if applicable)
# - `setup_lulcmaps`: Processes land use/land cover data
# - `setup_laimaps`: Sets up leaf area index data
# - `setup_precip_forcing`: Prepares precipitation input
# - `setup_temp_pet_forcing`: Prepares temperature and potential evapotranspiration

# %% [markdown]
# ---
#
# ## Part 3: Building the Model
#
# ### 3.1 Prepare the Build Configuration
#
# Before running the build command, you need to prepare two key files:
#
# 1. **Configuration file** (`./model_build_files/wflow_build_first_model.yaml`): Defines what data to use and how to process it
# 2. **Data catalog** (optional): Specifies data sources if not using defaults
#
# Below is an example configuration file structure:

# %%
# Example: View a sample configuration file structure
sample_config = """
setup_basemaps:
  hydrography_fn: merit_hydro
  basin_index_fn: merit_hydro_index
  
setup_rivers:
  hydrography_fn: merit_hydro
  river_geom_fn: rivers_lin2019_v1
  river_upa: 30  # minimum upstream area in km2
  
setup_lakes:
  lakes_fn: hydrolakes
  min_area: 1.0  # minimum lake area in km2
  
setup_lulcmaps:
  lulc_fn: vito
  
setup_laimaps:
  lai_fn: modis_lai
  
setup_precip_forcing:
  precip_fn: era5_daily
  starttime: 2010-01-01
  endtime: 2015-12-31
  
setup_temp_pet_forcing:
  temp_pet_fn: era5_daily
  starttime: 2010-01-01
  endtime: 2015-12-31
"""

print(sample_config)
# Out:
# setup_basemaps:
#   hydrography_fn: merit_hydro
#   basin_index_fn: merit_hydro_index
#
# setup_rivers:
#   hydrography_fn: merit_hydro
#   river_geom_fn: rivers_lin2019_v1
#   river_upa: 30  # minimum upstream area in km2
#
# setup_lakes:
#   lakes_fn: hydrolakes
#   min_area: 1.0  # minimum lake area in km2
#
# setup_lulcmaps:
#   lulc_fn: vito
#
# setup_laimaps:
#   lai_fn: modis_lai
#
# setup_precip_forcing:
#   precip_fn: era5_daily
#   starttime: 2010-01-01
#   endtime: 2015-12-31
#
# setup_temp_pet_forcing:
#   temp_pet_fn: era5_daily
#   starttime: 2010-01-01
#   endtime: 2015-12-31

# %% [markdown]
# ### 3.2 Execute the Build Command
#
# Now we'll build the actual model. This process:
# 1. Downloads and processes required datasets
# 2. Delineates the catchment boundary
# 3. Creates the model grid
# 4. Derives hydrological parameters
# 5. Prepares forcing data
# 6. Sets up initial model state
#
# **Note**: The first build can take 1-60 minutes depending on:
# - Catchment size
# - Number of forcing years
# - Internet connection speed (for data downloads)
# - Computer processing power

# %%
# Build a Wflow model
# !hydromt build wflow_sbm ./wflow_models/first_wflow_model \
  -i ../model_build_files/wflow_build_first_model.yml \
  -d artifact_data \
  --fo \
  -vv  # Very verbose output for detailed logging
# Out:
# 2025-11-25 18:44:54,940 - hydromt - log - INFO - HydroMT version: 1.3.0-rc5
# 2025-11-25 18:44:55,362 - hydromt.data_catalog.data_catalog - data_catalog - INFO - Reading data catalog artifact_data latest
# 2025-11-25 18:44:55,362 - hydromt.data_catalog.data_catalog - data_catalog - INFO - Parsing data catalog from /home/test2/.hydromt/artifact_data/v1.0.0/data_catalog.yml
# 2025-11-25 18:44:56,216 - hydromt.model.model - model - INFO - Initializing wflow_sbm model from hydromt_wflow (v1.0.0.dev0).
# 2025-11-25 18:44:56,216 - hydromt.data_catalog.data_catalog - data_catalog - INFO - Parsing data catalog from /opt/icpac-course/hydromt_wflow/hydromt_wflow/data/parameters_data.yml
# 2025-11-25 18:44:56,231 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Supported Wflow.jl version v1+
# 2025-11-25 18:44:56,232 - hydromt.hydromt_wflow.components.config - config - INFO - Reading default config file from /opt/icpac-course/hydromt_wflow/hydromt_wflow/data/wflow_sbm/wflow_sbm.toml.
# 2025-11-25 18:44:56,232 - hydromt - log - INFO - HydroMT version: 1.3.0-rc5
# 2025-11-25 18:44:56,233 - hydromt.model.model - model - INFO - build: setup_config
# 2025-11-25 18:44:56,233 - hydromt.model.model - model - INFO - setup_config.data={'time.starttime': datetime.datetime(2010, 1, 1, 0, 0), 'time.endtime': datetime.datetime(2010, 3, 31, 0, 0), 'time.timestepsecs': 86400, 'input.path_forcing': 'inmaps-era5-2010.nc', 'output.netcdf_grid.path': 'output.nc', 'output.netcdf_grid.compressionlevel': 1, 'output.netcdf_grid.variables.river_water__volume_flow_rate': 'q_av'}
# 2025-11-25 18:44:56,233 - hydromt.model.model - model - INFO - build: setup_basemaps
# 2025-11-25 18:44:56,233 - hydromt.model.model - model - INFO - setup_basemaps.basin_index_fn=merit_hydro_index
# 2025-11-25 18:44:56,233 - hydromt.model.model - model - INFO - setup_basemaps.res=0.00833
# 2025-11-25 18:44:56,233 - hydromt.model.model - model - INFO - setup_basemaps.upscale_method=ihu
# 2025-11-25 18:44:56,234 - hydromt.model.model - model - INFO - setup_basemaps.output_names={'basin__local_drain_direction': 'local_drain_direction', 'subbasin_location__count': 'subcatchment', 'land_surface__slope': 'land_slope'}
# 2025-11-25 18:44:56,234 - hydromt.model.model - model - INFO - setup_basemaps.hydrography_fn=merit_hydro
# 2025-11-25 18:44:56,234 - hydromt.model.model - model - INFO - setup_basemaps.region={'subbasin': [12.2051, 45.8331], 'strord': 4, 'bounds': [11.7, 45.35, 12.95, 46.7]}
# 2025-11-25 18:44:56,234 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Preparing base hydrography basemaps.
# 2025-11-25 18:44:56,234 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading merit_hydro RasterDataset data from /home/test2/.hydromt/artifact_data/latest/merit_hydro/{variable}.tif
# 2025-11-25 18:44:56,368 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading merit_hydro_index GeoDataFrame data from /home/test2/.hydromt/artifact_data/latest/merit_hydro_index.gpkg
# 2025-11-25 18:44:59,713 - hydromt.model.processes.basin_mask - basin_mask - INFO - subbasin bbox: [11.7750, 45.8042, 12.7450, 46.6900]
# 2025-11-25 18:44:59,795 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - (Sub)basin at original resolution has 664756 cells.
# 2025-11-25 18:44:59,985 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Upscale flow direction data: 10x, ihu method.
# 2025-11-25 18:45:13,803 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Derive stream order.
# 2025-11-25 18:45:13,988 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Map shape: (106, 116); active cells: 6637.
# 2025-11-25 18:45:13,988 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Outlet coordinates (1/1): (12.20750,45.83583).
# 2025-11-25 18:45:14,012 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Adding basin shape to staticgeoms.
# 2025-11-25 18:45:14,028 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Derive elevation and slope.
# 2025-11-25 18:45:14,296 - hydromt.model.model - model - INFO - build: setup_rivers
# 2025-11-25 18:45:14,297 - hydromt.model.model - model - INFO - setup_rivers.river_geom_fn=hydro_rivers_lin
# 2025-11-25 18:45:14,297 - hydromt.model.model - model - INFO - setup_rivers.river_upa=30
# 2025-11-25 18:45:14,297 - hydromt.model.model - model - INFO - setup_rivers.rivdph_method=powlaw
# 2025-11-25 18:45:14,297 - hydromt.model.model - model - INFO - setup_rivers.slope_len=2000
# 2025-11-25 18:45:14,297 - hydromt.model.model - model - INFO - setup_rivers.min_rivlen_ratio=0.0
# 2025-11-25 18:45:14,297 - hydromt.model.model - model - INFO - setup_rivers.min_rivdph=1
# 2025-11-25 18:45:14,297 - hydromt.model.model - model - INFO - setup_rivers.min_rivwth=30
# 2025-11-25 18:45:14,297 - hydromt.model.model - model - INFO - setup_rivers.smooth_len=5000
# 2025-11-25 18:45:14,297 - hydromt.model.model - model - INFO - setup_rivers.elevtn_map=land_elevation
# 2025-11-25 18:45:14,297 - hydromt.model.model - model - INFO - setup_rivers.river_routing=kinematic_wave
# 2025-11-25 18:45:14,297 - hydromt.model.model - model - INFO - setup_rivers.connectivity=8
# 2025-11-25 18:45:14,297 - hydromt.model.model - model - INFO - setup_rivers.output_names={'river_location__mask': 'river_mask', 'river__length': 'river_length', 'river__width': 'river_width', 'river_bank_water__depth': 'river_depth', 'river__slope': 'river_slope', 'river_bank_water__elevation': 'river_bank_elevation'}
# 2025-11-25 18:45:14,297 - hydromt.model.model - model - INFO - setup_rivers.hydrography_fn=merit_hydro
# 2025-11-25 18:45:14,297 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Preparing river maps.
# 2025-11-25 18:45:14,302 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading merit_hydro RasterDataset data from /home/test2/.hydromt/artifact_data/latest/merit_hydro/{variable}.tif
# 2025-11-25 18:45:14,401 - hydromt.hydromt_wflow.workflows.river - river - INFO - Set river mask (min uparea: 30 km2) and prepare flow dirs.
# 2025-11-25 18:45:14,613 - hydromt.hydromt_wflow.workflows.river - river - INFO - Derive river length.
# 2025-11-25 18:45:18,138 - hydromt.hydromt_wflow.workflows.river - river - INFO - Derive river slope.
# 2025-11-25 18:45:18,872 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading hydro_rivers_lin GeoDataFrame data from /home/test2/.hydromt/artifact_data/latest/rivers_lin2019_v1.gpkg
# 2025-11-25 18:45:19,081 - hydromt.hydromt_wflow.workflows.river - river - INFO - Derive ['rivwth', 'qbankfull'] from shapefile.
# 2025-11-25 18:45:19,132 - hydromt.hydromt_wflow.workflows.river - river - INFO - Valid for 381/655 river cells (max dist: 392 m).
# 2025-11-25 18:45:22,252 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Update wflow config model.river_routing="kinematic_wave"
# 2025-11-25 18:45:22,253 - hydromt.model.model - model - INFO - build: setup_reservoirs_simple_control
# 2025-11-25 18:45:22,253 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.timeseries_fn=gww
# 2025-11-25 18:45:22,253 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.overwrite_existing=False
# 2025-11-25 18:45:22,253 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.duplicate_id=error
# 2025-11-25 18:45:22,253 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.min_area=1.0
# 2025-11-25 18:45:22,253 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.output_names={'reservoir_area__count': 'reservoir_area_id', 'reservoir_location__count': 'reservoir_outlet_id', 'reservoir_surface__area': 'reservoir_area', 'reservoir_water_surface__initial_elevation': 'reservoir_initial_depth', 'reservoir_water__rating_curve_type_count': 'reservoir_rating_curve', 'reservoir_water__storage_curve_type_count': 'reservoir_storage_curve', 'reservoir_water__max_volume': 'reservoir_max_volume', 'reservoir_water__target_min_volume_fraction': 'reservoir_target_min_fraction', 'reservoir_water__target_full_volume_fraction': 'reservoir_target_full_fraction', 'reservoir_water_demand__required_downstream_volume_flow_rate': 'reservoir_demand', 'reservoir_water_release_below_spillway__max_volume_flow_rate': 'reservoir_max_release'}
# 2025-11-25 18:45:22,253 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.geom_name=meta_reservoirs_simple_control
# 2025-11-25 18:45:22,253 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.reservoirs_fn=hydro_reservoirs
# 2025-11-25 18:45:22,253 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing reservoir with simple control maps.
# 2025-11-25 18:45:22,254 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading hydro_reservoirs GeoDataFrame data from /home/test2/.hydromt/artifact_data/latest/hydro_reservoirs.gpkg
# 2025-11-25 18:45:22,278 - hydromt.hydromt_wflow.workflows.reservoirs - reservoirs - INFO - 0 reservoir(s) of sufficient size found within region.
# 2025-11-25 18:45:22,278 - hydromt.model.model - model - INFO - build: setup_reservoirs_no_control
# 2025-11-25 18:45:22,278 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.rating_curve_fns=None
# 2025-11-25 18:45:22,278 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.overwrite_existing=False
# 2025-11-25 18:45:22,279 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.duplicate_id=error
# 2025-11-25 18:45:22,279 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.min_area=10.0
# 2025-11-25 18:45:22,279 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.output_names={'reservoir_area__count': 'reservoir_area_id', 'reservoir_location__count': 'reservoir_outlet_id', 'reservoir_surface__area': 'reservoir_area', 'reservoir_water_surface__initial_elevation': 'reservoir_initial_depth', 'reservoir_water_flow_threshold_level__elevation': 'reservoir_outflow_threshold', 'reservoir_water__rating_curve_coefficient': 'reservoir_b', 'reservoir_water__rating_curve_exponent': 'reservoir_e', 'reservoir_water__rating_curve_type_count': 'reservoir_rating_curve', 'reservoir_water__storage_curve_type_count': 'reservoir_storage_curve', 'reservoir_lower_location__count': 'reservoir_lower_id'}
# 2025-11-25 18:45:22,279 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.geom_name=meta_reservoirs_no_control
# 2025-11-25 18:45:22,279 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.reservoirs_fn=hydro_lakes
# 2025-11-25 18:45:22,279 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing reservoir maps.
# 2025-11-25 18:45:22,279 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading hydro_lakes GeoDataFrame data from /home/test2/.hydromt/artifact_data/latest/hydro_lakes.gpkg
# 2025-11-25 18:45:22,295 - hydromt.hydromt_wflow.workflows.reservoirs - reservoirs - INFO - 0 reservoir(s) of sufficient size found within region.
# 2025-11-25 18:45:22,295 - hydromt.model.model - model - INFO - build: setup_glaciers
# 2025-11-25 18:45:22,295 - hydromt.model.model - model - INFO - setup_glaciers.min_area=0.0
# 2025-11-25 18:45:22,295 - hydromt.model.model - model - INFO - setup_glaciers.output_names={'glacier_surface__area_fraction': 'glacier_fraction', 'glacier_ice__initial_leq_depth': 'glacier_initial_leq_depth'}
# 2025-11-25 18:45:22,295 - hydromt.model.model - model - INFO - setup_glaciers.geom_name=glaciers
# 2025-11-25 18:45:22,295 - hydromt.model.model - model - INFO - setup_glaciers.glaciers_fn=rgi
# 2025-11-25 18:45:22,295 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing glacier maps.
# 2025-11-25 18:45:22,296 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading rgi GeoDataFrame data from /home/test2/.hydromt/artifact_data/latest/rgi.gpkg
# 2025-11-25 18:45:22,314 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - 38 glaciers of sufficient size found within region.
# 2025-11-25 18:45:23,644 - hydromt.model.model - model - INFO - build: setup_lulcmaps
# 2025-11-25 18:45:23,644 - hydromt.model.model - model - INFO - setup_lulcmaps.lulc_mapping_fn=globcover_mapping_default
# 2025-11-25 18:45:23,645 - hydromt.model.model - model - INFO - setup_lulcmaps.lulc_vars=['landuse', 'vegetation_kext', 'land_manning_n', 'soil_compacted_fraction', 'vegetation_root_depth', 'vegetation_leaf_storage', 'vegetation_wood_storage', 'land_water_fraction', 'vegetation_crop_factor', 'vegetation_feddes_alpha_h1', 'vegetation_feddes_h1', 'vegetation_feddes_h2', 'vegetation_feddes_h3_high', 'vegetation_feddes_h3_low', 'vegetation_feddes_h4']
# 2025-11-25 18:45:23,645 - hydromt.model.model - model - INFO - setup_lulcmaps.output_names_suffix=None
# 2025-11-25 18:45:23,645 - hydromt.model.model - model - INFO - setup_lulcmaps.lulc_fn=globcover_2009
# 2025-11-25 18:45:23,645 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Preparing LULC parameter maps.
# 2025-11-25 18:45:23,647 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading globcover_2009 RasterDataset data from /home/test2/.hydromt/artifact_data/latest/globcover.tif
# 2025-11-25 18:45:23,661 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading globcover_mapping_default DataFrame data from /opt/icpac-course/hydromt_wflow/hydromt_wflow/data/lulc/globcover_mapping.csv
# 2025-11-25 18:45:23,674 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving landuse using mode resampling (nodata=230).
# 2025-11-25 18:45:23,804 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_kext using average resampling (nodata=-999.0).
# 2025-11-25 18:45:23,828 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving land_manning_n using average resampling (nodata=-999.0).
# 2025-11-25 18:45:23,853 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving soil_compacted_fraction using average resampling (nodata=-999.0).
# 2025-11-25 18:45:23,877 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_root_depth using average resampling (nodata=-999.0).
# 2025-11-25 18:45:23,903 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_leaf_storage using average resampling (nodata=-999.0).
# 2025-11-25 18:45:23,928 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_wood_storage using average resampling (nodata=-999.0).
# 2025-11-25 18:45:23,953 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving land_water_fraction using average resampling (nodata=-999.0).
# 2025-11-25 18:45:23,977 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_crop_factor using average resampling (nodata=-999.0).
# 2025-11-25 18:45:24,001 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_alpha_h1 using mode resampling (nodata=-999).
# 2025-11-25 18:45:24,129 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h1 using average resampling (nodata=-999).
# 2025-11-25 18:45:24,156 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h2 using average resampling (nodata=-999).
# 2025-11-25 18:45:24,185 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h3_high using average resampling (nodata=-999).
# 2025-11-25 18:45:24,214 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h3_low using average resampling (nodata=-999).
# 2025-11-25 18:45:24,243 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h4 using average resampling (nodata=-999).
# 2025-11-25 18:45:24,308 - hydromt.model.model - model - INFO - build: setup_laimaps
# 2025-11-25 18:45:24,309 - hydromt.model.model - model - INFO - setup_laimaps.lulc_fn=None
# 2025-11-25 18:45:24,309 - hydromt.model.model - model - INFO - setup_laimaps.lulc_sampling_method=any
# 2025-11-25 18:45:24,309 - hydromt.model.model - model - INFO - setup_laimaps.lulc_zero_classes=[]
# 2025-11-25 18:45:24,309 - hydromt.model.model - model - INFO - setup_laimaps.buffer=2
# 2025-11-25 18:45:24,309 - hydromt.model.model - model - INFO - setup_laimaps.output_name=vegetation_leaf_area_index
# 2025-11-25 18:45:24,309 - hydromt.model.model - model - INFO - setup_laimaps.lai_fn=modis_lai
# 2025-11-25 18:45:24,309 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing LAI maps.
# 2025-11-25 18:45:24,312 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading modis_lai RasterDataset data from /home/test2/.hydromt/artifact_data/latest/modis_lai.nc
# 2025-11-25 18:45:25,950 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving LAI using average resampling (nodata=nan).
# 2025-11-25 18:45:26,063 - hydromt.model.model - model - INFO - build: setup_soilmaps
# 2025-11-25 18:45:26,063 - hydromt.model.model - model - INFO - setup_soilmaps.soil_fn=soilgrids
# 2025-11-25 18:45:26,063 - hydromt.model.model - model - INFO - setup_soilmaps.ptf_ksatver=brakensiek
# 2025-11-25 18:45:26,063 - hydromt.model.model - model - INFO - setup_soilmaps.wflow_thicknesslayers=[100, 300, 800]
# 2025-11-25 18:45:26,063 - hydromt.model.model - model - INFO - setup_soilmaps.output_names={'soil_water__saturated_volume_fraction': 'soil_theta_s', 'soil_water__residual_volume_fraction': 'soil_theta_r', 'soil_surface_water__vertical_saturated_hydraulic_conductivity': 'soil_ksat_vertical', 'soil__thickness': 'soil_thickness', 'soil_water__vertical_saturated_hydraulic_conductivity_scale_parameter': 'soil_f', 'soil_layer_water__brooks_corey_exponent': 'soil_brooks_corey_c'}
# 2025-11-25 18:45:26,063 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing soil parameter maps.
# 2025-11-25 18:45:26,066 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading soilgrids RasterDataset data from /home/test2/.hydromt/artifact_data/latest/soilgrids/{variable}.tif
# 2025-11-25 18:45:26,818 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - calculate and resample theta_s
# 2025-11-25 18:45:27,161 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - calculate and resample theta_r
# 2025-11-25 18:45:27,509 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - calculate and resample ksat_vertical
# 2025-11-25 18:45:27,604 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - calculate and resample pore size distribution index
# 2025-11-25 18:45:28,290 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - fit z - log(ksat_vertical ) with numpy linalg regression (y = b*x) -> M_
# 2025-11-25 18:45:28,897 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - fit zi - Ksat with curve_fit (scipy.optimize) -> M
# 2025-11-25 18:45:32,970 - hydromt.gis.raster - raster - WARNING - No numerical nodata value found, skipping set_nodata
# 2025-11-25 18:45:33,669 - hydromt.gis.raster - raster - WARNING - No numerical nodata value found, skipping set_nodata
# 2025-11-25 18:45:33,860 - hydromt.gis.raster - raster - WARNING - No numerical nodata value found, skipping set_nodata
# 2025-11-25 18:45:34,006 - hydromt.model.model - model - INFO - build: setup_outlets
# 2025-11-25 18:45:34,006 - hydromt.model.model - model - INFO - setup_outlets.river_only=True
# 2025-11-25 18:45:34,006 - hydromt.model.model - model - INFO - setup_outlets.toml_output=csv
# 2025-11-25 18:45:34,006 - hydromt.model.model - model - INFO - setup_outlets.gauge_toml_header=['river_q']
# 2025-11-25 18:45:34,006 - hydromt.model.model - model - INFO - setup_outlets.gauge_toml_param=['river_water__volume_flow_rate']
# 2025-11-25 18:45:34,006 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Gauges locations set based on river outlets.
# 2025-11-25 18:45:34,023 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Gauges map based on catchment river outlets added.
# 2025-11-25 18:45:34,023 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Adding ['river_water__volume_flow_rate'] to csv section of toml.
# 2025-11-25 18:45:34,023 - hydromt.model.model - model - INFO - build: setup_gauges
# 2025-11-25 18:45:34,023 - hydromt.model.model - model - INFO - setup_gauges.index_col=None
# 2025-11-25 18:45:34,023 - hydromt.model.model - model - INFO - setup_gauges.snap_to_river=True
# 2025-11-25 18:45:34,023 - hydromt.model.model - model - INFO - setup_gauges.mask=None
# 2025-11-25 18:45:34,023 - hydromt.model.model - model - INFO - setup_gauges.snap_uparea=False
# 2025-11-25 18:45:34,023 - hydromt.model.model - model - INFO - setup_gauges.max_dist=10000.0
# 2025-11-25 18:45:34,023 - hydromt.model.model - model - INFO - setup_gauges.wdw=3
# 2025-11-25 18:45:34,024 - hydromt.model.model - model - INFO - setup_gauges.rel_error=0.05
# 2025-11-25 18:45:34,024 - hydromt.model.model - model - INFO - setup_gauges.abs_error=50.0
# 2025-11-25 18:45:34,024 - hydromt.model.model - model - INFO - setup_gauges.fillna=False
# 2025-11-25 18:45:34,024 - hydromt.model.model - model - INFO - setup_gauges.derive_subcatch=False
# 2025-11-25 18:45:34,024 - hydromt.model.model - model - INFO - setup_gauges.basename=None
# 2025-11-25 18:45:34,024 - hydromt.model.model - model - INFO - setup_gauges.toml_output=csv
# 2025-11-25 18:45:34,024 - hydromt.model.model - model - INFO - setup_gauges.gauge_toml_header=['river_q', 'precip']
# 2025-11-25 18:45:34,024 - hydromt.model.model - model - INFO - setup_gauges.gauge_toml_param=['river_water__volume_flow_rate', 'atmosphere_water__precipitation_volume_flux']
# 2025-11-25 18:45:34,024 - hydromt.model.model - model - INFO - setup_gauges.gauges_fn=grdc
# 2025-11-25 18:45:34,024 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading grdc GeoDataFrame data from /home/test2/.hydromt/artifact_data/latest/grdc.csv
# 2025-11-25 18:45:34,034 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - 3 grdc gauge locations found within domain
# 2025-11-25 18:45:34,411 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Adding ['river_water__volume_flow_rate', 'atmosphere_water__precipitation_volume_flux'] to csv section of toml.
# 2025-11-25 18:45:34,412 - hydromt.model.model - model - INFO - build: setup_precip_forcing
# 2025-11-25 18:45:34,412 - hydromt.model.model - model - INFO - setup_precip_forcing.precip_clim_fn=None
# 2025-11-25 18:45:34,412 - hydromt.model.model - model - INFO - setup_precip_forcing.chunksize=None
# 2025-11-25 18:45:34,412 - hydromt.model.model - model - INFO - setup_precip_forcing.precip_fn=era5
# 2025-11-25 18:45:34,414 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading era5 RasterDataset data from /home/test2/.hydromt/artifact_data/latest/era5.nc
# 2025-11-25 18:45:34,517 - hydromt.model.model - model - INFO - build: setup_temp_pet_forcing
# 2025-11-25 18:45:34,517 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.pet_method=debruin
# 2025-11-25 18:45:34,517 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.press_correction=True
# 2025-11-25 18:45:34,517 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.temp_correction=True
# 2025-11-25 18:45:34,517 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.wind_correction=True
# 2025-11-25 18:45:34,517 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.wind_altitude=10
# 2025-11-25 18:45:34,517 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.reproj_method=nearest_index
# 2025-11-25 18:45:34,517 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.fillna_method=None
# 2025-11-25 18:45:34,517 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.dem_forcing_fn=era5_orography
# 2025-11-25 18:45:34,517 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.skip_pet=False
# 2025-11-25 18:45:34,517 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.chunksize=None
# 2025-11-25 18:45:34,517 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.temp_pet_fn=era5
# 2025-11-25 18:45:34,520 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading era5 RasterDataset data from /home/test2/.hydromt/artifact_data/latest/era5.nc
# 2025-11-25 18:45:34,579 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading era5_orography RasterDataset data from /home/test2/.hydromt/artifact_data/latest/era5_orography.nc
# 2025-11-25 18:45:34,884 - hydromt.model.model - model - INFO - build: setup_constant_pars
# 2025-11-25 18:45:34,884 - hydromt.model.model - model - INFO - setup_constant_pars.subsurface_water__horizontal_to_vertical_saturated_hydraulic_conductivity_ratio=100
# 2025-11-25 18:45:34,884 - hydromt.model.model - model - INFO - setup_constant_pars.snowpack__degree_day_coefficient=3.75653
# 2025-11-25 18:45:34,884 - hydromt.model.model - model - INFO - setup_constant_pars.soil_surface_water__infiltration_reduction_parameter=0.038
# 2025-11-25 18:45:34,884 - hydromt.model.model - model - INFO - setup_constant_pars.vegetation_canopy_water__mean_evaporation_to_mean_precipitation_ratio=0.11
# 2025-11-25 18:45:34,884 - hydromt.model.model - model - INFO - setup_constant_pars.compacted_soil_surface_water__infiltration_capacity=10
# 2025-11-25 18:45:34,884 - hydromt.model.model - model - INFO - setup_constant_pars.soil_water_saturated_zone_bottom__max_leakage_volume_flux=0
# 2025-11-25 18:45:34,884 - hydromt.model.model - model - INFO - setup_constant_pars.soil_wet_root__sigmoid_function_shape_parameter=-500
# 2025-11-25 18:45:34,884 - hydromt.model.model - model - INFO - setup_constant_pars.atmosphere_air__snowfall_temperature_threshold=0
# 2025-11-25 18:45:34,885 - hydromt.model.model - model - INFO - setup_constant_pars.atmosphere_air__snowfall_temperature_interval=2
# 2025-11-25 18:45:34,885 - hydromt.model.model - model - INFO - setup_constant_pars.snowpack__melting_temperature_threshold=0
# 2025-11-25 18:45:34,885 - hydromt.model.model - model - INFO - setup_constant_pars.snowpack__liquid_water_holding_capacity=0.1
# 2025-11-25 18:45:34,885 - hydromt.model.model - model - INFO - setup_constant_pars.glacier_ice__degree_day_coefficient=3
# 2025-11-25 18:45:34,885 - hydromt.model.model - model - INFO - setup_constant_pars.glacier_firn_accumulation__snowpack_dry_snow_leq_depth_fraction=0.001
# 2025-11-25 18:45:34,885 - hydromt.model.model - model - INFO - setup_constant_pars.glacier_ice__melting_temperature_threshold=0
# 2025-11-25 18:45:34,885 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Write model data to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/1_Hydrological_Model/wflow_models/first_wflow_model
# 2025-11-25 18:45:34,897 - hydromt.model.components.grid - grid - INFO - wflow_sbm.staticmaps: Writing grid data to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticmaps.nc.
# 2025-11-25 18:45:35,026 - hydromt.model.components.spatial - spatial - INFO - wflow_sbm.staticmaps: Writing region to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/region.geojson.
# 2025-11-25 18:45:35,061 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/basins_highres.geojson.
# 2025-11-25 18:45:35,084 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/basins.geojson.
# 2025-11-25 18:45:35,090 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/rivers.geojson.
# 2025-11-25 18:45:35,096 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/glaciers.geojson.
# 2025-11-25 18:45:35,140 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/outlets.geojson.
# 2025-11-25 18:45:35,143 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/gauges_grdc.geojson.
# 2025-11-25 18:45:35,147 - hydromt.hydromt_wflow.components.forcing - forcing - INFO - Write forcing file
# 2025-11-25 18:45:35,147 - hydromt.hydromt_wflow.components.forcing - forcing - WARNING - Start time 2010-01-01T00:00:00.000000 does not match the beginning of the data. Changing to start of the data: 2010-02-02T00:00:00.000000000.
# 2025-11-25 18:45:35,148 - hydromt.hydromt_wflow.components.forcing - forcing - WARNING - End time 2010-03-31T00:00:00.000000 does not match the end of the data. Changing to end of the data: 2010-02-15T00:00:00.000000000.
# 2025-11-25 18:45:35,150 - hydromt.hydromt_wflow.components.forcing - forcing - INFO - Writing file /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/inmaps-era5-2010.nc
# [########################################] | 100% Completed | 201.94 ms
# 2025-11-25 18:45:35,380 - hydromt.model.components.tables - tables - INFO - wflow_sbm.tables: No tables found, skip writing.
# 2025-11-25 18:45:35,380 - hydromt.model.components.grid - grid - INFO - wflow_sbm.states: No grid data found, skip writing.
# 2025-11-25 18:45:35,380 - hydromt.hydromt_wflow.components.config - config - INFO - Writing model config to /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/wflow_sbm.toml.

# %% [markdown]
# **Command breakdown**:
# - `wflow_sbm`: We're building a Wflow SBM model
# - `./wflow_models/first_wflow_model`: Output directory for the model
# - `-i ../model_build_files/wflow_build_first_model.yml`: Use this configuration file
# - `-d artifact_data`: Data catalog location
# - `-vv`: Maximum verbosity for logging
#
# **What happens during the build?**
#
# The build process executes several steps:
#
# 1. **Basin delineation**: Identifies the upstream catchment area
# 2. **DEM processing**: Processes digital elevation model for terrain analysis
# 3. **Flow direction**: Computes flow direction and accumulation
# 4. **River network**: Extracts river channels and calculates properties
# 5. **Land cover**: Processes land use/land cover to derive model parameters
# 6. **Soil data**: Incorporates soil properties (texture, depth, etc.)
# 7. **Forcing preparation**: Processes precipitation, temperature, and PET data
# 8. **Parameter derivation**: Calculates distributed hydrological parameters

# %% [markdown]
# ---
#
# ## Part 4: Exploring the Model Structure
#
# ### 4.1 Model Directory Organization
#
# After the build completes, your model directory contains several important files and folders:

# %%
# List the contents of the model directory
# !ls -lh ./wflow_models/first_wflow_model
# Out:
# total 3.5M
# -rw-r--r-- 1 test2 test2  47K Nov 25 18:45 hydromt.log
# -rw-r--r-- 1 test2 test2 7.0K Nov 25 18:45 hydromt_data.yml
# -rw-r--r-- 1 test2 test2 448K Nov 25 18:45 inmaps-era5-2010.nc
# drwxr-xr-x 2 test2 test2 4.0K Nov 25 18:45 staticgeoms
# -rw-r--r-- 1 test2 test2 3.0M Nov 25 18:45 staticmaps.nc
# -rw-r--r-- 1 test2 test2 5.0K Nov 25 18:45 wflow_sbm.toml

# %% [markdown]
# **Expected directory structure**:
#
# ```
# first_wflow_model/
# ├── staticmaps.nc        # Static spatial parameters (DEM, land use, soil, etc.)
# ├── staticgeoms/         # Vector geometries (rivers, lakes, gauges, subcatchments)
# ├── inmaps/              # Initial conditions and state maps
# ├── inmaps-era5-2010.nc  # Climate forcing data (precip, temp, PET)
# ├── wflow_sbm.toml       # Model configuration file
# ├── hydromt_data.yml     # Data catalog used during build
# └── hydromt.log          # Build process log file
# ```
#
# ### 4.2 Understanding Key Components
#
# #### Static Maps (`staticmaps.nc`)
# Contains gridded spatial parameters that don't change during simulation:
# - `wflow_dem.nc`: Digital elevation model
# - `wflow_ldd.nc`: Local drainage direction
# - `wflow_river.nc`: River mask and properties
# - `wflow_landuse.nc`: Land cover classification
# - `c_*.nc`: Soil parameters (various)
# - `theta_*.nc`: Soil moisture parameters
# - `ksat_*.nc`: Saturated hydraulic conductivity
#
# #### Static Geometries (`staticgeoms/`)
# Vector data for model features:
# - `rivers.geojson`: River network as lines
# - `basins.geojson`: Subcatchment polygons
# - `lakes.geojson`: Lake geometries (if present)
# - `gauges.geojson`: Observation locations (if added)
#
# #### Forcing Data
# Time-varying climate inputs:
# - `inmaps-era5-2010.nc.nc`: Contains precipitation, temperature, and PET timeseries
#
# #### Model Configuration (`wflow_sbm.toml`)
# The TOML file controls:
# - Simulation period
# - Output variables and frequency
# - Model component activation
# - Numerical settings

# %% [markdown]
# ### 4.3 Inspecting the Model with Python
#
# HydroMT provides a Python API to interact with the built model. This is useful for:
# - Inspecting model properties
# - Modifying parameters
# - Creating visualizations
# - Quality control

# %%
# Import necessary libraries
import numpy as np
import xarray as xr
import geopandas as gpd
from matplotlib import colors
import matplotlib.patches as mpatches
import cartopy.crs as ccrs
import cartopy.io.img_tiles as cimgt
import matplotlib.pyplot as plt
from hydromt_wflow import WflowSbmModel

# Load the model
model = WflowSbmModel(root="./wflow_models/first_wflow_model", mode="r")
model.read()
# Out:
# 2025-11-25 18:45:41,877 - hydromt.model.model - model - INFO - Initializing wflow_sbm model from hydromt_wflow (v1.0.0.dev0).
# 2025-11-25 18:45:41,878 - hydromt.data_catalog.data_catalog - data_catalog - INFO - Parsing data catalog from /opt/icpac-course/hydromt_wflow/hydromt_wflow/data/parameters_data.yml
# 2025-11-25 18:45:41,919 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Supported Wflow.jl version v1+
# 2025-11-25 18:45:41,920 - hydromt.hydromt_wflow.components.config - config - INFO - Reading model config file from /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/wflow_sbm.toml.
# 2025-11-25 18:45:41,922 - hydromt.hydromt_wflow.components.config - config - INFO - Reading model config file from /home/test2/Capacity-Building-ICPAC-for-climate-services/2_IBF_Flood_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/wflow_sbm.toml.
# 2025-11-25 18:45:42,592 - hydromt.hydromt_wflow.components.states - states - WARNING - CRS not found in states data, setting to model CRS.
# 2025-11-25 18:45:42,598 - hydromt.model.components.tables - tables - INFO - Reading model table files.

# %%
# Display basic model information
print(f"Model region: {model.region}")
print(f"Model CRS: {model.crs}")
# Out:
# Model region:                                             geometry
# 0  POLYGON ((12.745 45.80667, 12.745 46.69, 11.77...
# Model CRS: EPSG:4326

# %% [markdown]
# ### 4.4 Visualizing Model Components
#
# Let's create some basic visualizations to understand our model domain:

# %%
# read and mask the model elevation
da = model.staticmaps.data["land_elevation"].raster.mask_nodata()
da.attrs.update(long_name="elevation", units="m")
# read/derive river geometries
gdf_riv = model.rivers
# read/derive model basin boundary
gdf_bas = model.basins

# we assume the model maps are in the geographic CRS EPSG:4326
proj = ccrs.PlateCarree()
# adjust zoomlevel and figure size to your basis size & aspect
zoom_level = 10
figsize = (10, 8)
shaded = False  # shaded elevation (looks nicer with more pixels (e.g.: larger basins))!

# initialize image with geoaxes
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(projection=proj)
bbox = da.raster.box.to_crs(3857).buffer(5e3).to_crs(da.raster.crs).total_bounds
extent = np.array(bbox)[[0, 2, 1, 3]]
ax.set_extent(extent, crs=proj)

# add sat background image
ax.add_image(cimgt.QuadtreeTiles(), zoom_level, alpha=0.5)

## plot elevation\
# create nice colormap
vmin, vmax = da.quantile([0.0, 0.98]).compute()
c_dem = plt.cm.terrain(np.linspace(0.25, 1, 256))
cmap = colors.LinearSegmentedColormap.from_list("dem", c_dem)
norm = colors.Normalize(vmin=vmin, vmax=vmax)
kwargs = dict(cmap=cmap, norm=norm)
# plot 'normal' elevation
da.plot(
    transform=proj, ax=ax, zorder=1, cbar_kwargs=dict(aspect=30, shrink=0.8), **kwargs
)
# plot elevation with shades
if shaded:
    ls = colors.LightSource(azdeg=315, altdeg=45)
    dx, dy = da.raster.res
    _rgb = ls.shade(
        da.fillna(0).values,
        norm=kwargs["norm"],
        cmap=kwargs["cmap"],
        blend_mode="soft",
        dx=dx,
        dy=dy,
        vert_exag=200,
    )
    rgb = xr.DataArray(dims=("y", "x", "rgb"), data=_rgb, coords=da.raster.coords)
    rgb = xr.where(np.isnan(da), np.nan, rgb)
    rgb.plot.imshow(transform=proj, ax=ax, zorder=2)

# plot rivers with increasing width with stream order
gdf_riv.plot(
    ax=ax, linewidth=gdf_riv["strord"] / 2, color="blue", zorder=3, label="river"
)
# plot the basin boundary
gdf_bas.boundary.plot(ax=ax, color="k", linewidth=0.3)
# plot various vector layers if present
if "outlets" in model.geoms.data:
    model.geoms.data["outlets"].plot(
        ax=ax, marker="d", markersize=25, facecolor="k", zorder=5, label="outlets"
    )
patches = []  # manual patches for legend, see https://github.com/geopandas/geopandas/issues/660
if "meta_reservoirs_no_control" in model.geoms.data:
    kwargs = dict(facecolor="lightblue", edgecolor="black", linewidth=1, label="reservoirs (natural lakes)")
    model.geoms.data["meta_reservoirs_no_control"].plot(ax=ax, zorder=4, **kwargs)
    patches.append(mpatches.Patch(**kwargs))
if "meta_reservoirs_simple_control" in model.geoms.data:
    kwargs = dict(facecolor="blue", edgecolor="black", linewidth=1, label="reservoirs (simple control)")
    model.geoms.data["meta_reservoirs_simple_control"].plot(ax=ax, zorder=4, **kwargs)
    patches.append(mpatches.Patch(**kwargs))
if "glaciers" in model.geoms.data:
    kwargs = dict(facecolor="grey", edgecolor="grey", linewidth=1, label="glaciers")
    model.geoms.data["glaciers"].plot(ax=ax, zorder=4, **kwargs)
    patches.append(mpatches.Patch(**kwargs))

ax.xaxis.set_visible(True)
ax.yaxis.set_visible(True)
ax.set_ylabel(f"latitude [degree north]")
ax.set_xlabel(f"longitude [degree east]")
_ = ax.set_title(f"wflow base map")
legend = ax.legend(
    handles=[*ax.get_legend_handles_labels()[0], *patches],
    title="Legend",
    loc="lower right",
    frameon=True,
    framealpha=0.7,
    edgecolor="k",
    facecolor="white",
)

# %%
# Create a figure with multiple subplots
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# Plot 1: Elevation
model.staticmaps.data['land_elevation'].plot(ax=axes[0, 0], cmap='terrain')
axes[0, 0].set_title('Digital Elevation Model', fontsize=12, fontweight='bold')
axes[0, 0].set_xlabel('Longitude')
axes[0, 0].set_ylabel('Latitude')

# Plot 2: River network
model.staticmaps.data['river_mask'].plot(ax=axes[0, 1], cmap='Blues')
axes[0, 1].set_title('River Network', fontsize=12, fontweight='bold')
axes[0, 1].set_xlabel('Longitude')
axes[0, 1].set_ylabel('Latitude')

# Plot 3: Land use
model.staticmaps.data['meta_landuse'].plot(ax=axes[1, 0], cmap='tab20')
axes[1, 0].set_title('Land Use Classification', fontsize=12, fontweight='bold')
axes[1, 0].set_xlabel('Longitude')
axes[1, 0].set_ylabel('Latitude')

# Plot 4: Land slope
model.staticmaps.data['vegetation_root_depth'].plot(ax=axes[1, 1], cmap='tab20')
axes[1, 1].set_title('Vegetation Rooting Depth', fontsize=12, fontweight='bold')
axes[1, 1].set_xlabel('Longitude')
axes[1, 1].set_ylabel('Latitude')

plt.tight_layout()
plt.show()

# %% [markdown]
# Now lets visualize the meteorological forcing and apply some simple statistics:

# %%
model.forcing.data.precip.isel(time=5).plot()

# %% [markdown]
# Calculate the average forcing accros the watershed:

# %%
ds_forcing = model.forcing.data
ds_forcing = ds_forcing.mean(dim=[ds_forcing.raster.x_dim, ds_forcing.raster.y_dim])

# plot axes labels
_ATTRS = {
    "precip": {
        "standard_name": "precipitation",
        "unit": "mm.day-1",
        "color": "darkblue",
    },
    "pet": {
        "standard_name": "potential evapotranspiration",
        "unit": "mm.day-1",
        "color": "purple",
    },
    "temp": {"standard_name": "temperature", "unit": "degree C", "color": "orange"},
}

n = len(ds_forcing.data_vars)
kwargs0 = dict(sharex=True, figsize=(6, n * 3))

fig, axes = plt.subplots(n, 1, **kwargs0)
axes = [axes] if n == 1 else axes
for i, name in enumerate(ds_forcing.data_vars):
    df = ds_forcing[name].squeeze().to_series()
    attrs = _ATTRS[name]
    longname = attrs.get("standard_name", "")
    unit = attrs.get("unit", "")
    if name == "precip":
        axes[i].bar(df.index, df.values, facecolor=attrs["color"])
    else:
        df.plot.line(ax=axes[i], x="time", color=attrs["color"])
    axes[i].set_title(longname)
    axes[i].set_ylabel(f"{longname}\n[{unit}]")

# %% [markdown]
# ---
#
# ## Part 5: Model Configuration and Settings
#
# ### 5.1 Understanding the TOML Configuration
#
# The `wflow_sbm.toml` file controls how the model runs. Let's examine key sections:

# %%
# Read and display the first 50 lines of the TOML configuration
# !head -n 50 ./wflow_models/first_wflow_model/wflow_sbm.toml
# Out:
# dir_output = "run_default"
#
# [time]
# calendar = "proleptic_gregorian"
# starttime = "2010-02-02T00:00:00"
# endtime = "2010-02-15T00:00:00"
# time_units = "days since 1900-01-01 00:00:00"
# timestepsecs = 86400
#
# [logging]
# loglevel = "info"
#
# [model]
# type = "sbm"
# snow_gravitational_transport__flag = true
# snow__flag = true
# cold_start__flag = true
# reservoir__flag = false
# glacier__flag = true
# kinematic_wave__adaptive_time_step_flag = false
# river_kinematic_wave__time_step = 900
# land_kinematic_wave__time_step = 3600
# river_routing = "kinematic_wave"
# soil_layer__thickness = [
#     100,
#     300,
#     800,
# ]
#
# [state]
# path_input = "instate/instates.nc"
# path_output = "outstate/outstates.nc"
#
# [state.variables]
# vegetation_canopy_water__depth = "vegetation_water_depth"
# soil_water_saturated_zone__depth = "soil_saturated_depth"
# soil_layer_water_unsaturated_zone__depth = "soil_unsaturated_depth"
# soil_surface__temperature = "soil_temp"
# snowpack_dry_snow__leq_depth = "snow_leq_depth"
# snowpack_liquid_water__depth = "snow_water_depth"
# land_surface_water__instantaneous_volume_flow_rate = "land_instantaneous_q"
# land_surface_water__depth = "land_h"
# subsurface_water__volume_flow_rate = "subsurface_q"
# river_water__instantaneous_volume_flow_rate = "river_instantaneous_q"
# river_water__depth = "river_h"
# glacier_ice__leq_depth = "glacier_leq_depth"
#
# [input]
# path_forcing = "inmaps-era5-2010.nc"
# path_static = "staticmaps.nc"

# %% [markdown]
# **Key configuration sections**:
#
# #### `[model]`
# Defines model type and core settings:
# ```toml
# [model]
# type = "sbm"
# masswasting = true
# snow = false
# reinit = true
# reservoirs = false
# lakes = false
# glacier = false
# ```
#
# #### `[state]`
# Specifies initial condition files:
# ```toml
# [state]
# path_input = "inmaps/instates.nc"
# path_output = "output/outstates.nc"
# ```
#
# #### `[input]`
# Points to static maps and forcing data:
# ```toml
# [input]
# path_forcing = "forcing/inmaps.nc"
# path_static = "staticmaps/staticmaps.nc"
# ```
#
# #### `[output]`
# Controls what variables to save and at what frequency:
# ```toml
# [output]
# path = "output/output.nc"
# ```

# %% [markdown]
# ### 5.2 Customizing Output Variables
#
# You can modify which variables are saved by editing the TOML file. Common output variables include:
#
# **Water balance components**:
# - `q_river`: River discharge [m³/s]
# - `q_land`: Lateral flow [mm/day]
# - `actevap`: Actual evapotranspiration [mm/day]
# - `snow`: Snow water equivalent [mm]
#
# **Storage variables**:
# - `ustorelayerdepth`: Unsaturated zone storage [mm]
# - `satwaterdepth`: Saturated zone storage [mm]
# - `canopystorage`: Canopy interception storage [mm]
#
# **Fluxes**:
# - `infiltration`: Infiltration rate [mm/day]
# - `recharge`: Groundwater recharge [mm/day]
# - `runoff`: Surface runoff [mm/day]

# %% [markdown]
# ---
#
# ## Part 6: Running the Model
#
# ### 6.1 Execute the Wflow Simulation
#
# Now that the model is built and configured, we can run the simulation. Wflow uses the Julia-based Wflow.jl backend for efficient computation.

# %%
# Install the model (once)
# !julia -e 'using Pkg; Pkg.add(url="https://github.com/Deltares/Wflow.jl", subdir="Wflow")'
# Out:
#     Updating git-repo `https://github.com/Deltares/Wflow.jl`
#    Resolving package versions...=================>    ]  87.8 %
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [d48b7d99] ~ Wflow v1.0.0-dev `https://github.com/Deltares/Wflow.jl:Wflow#master` ⇒ v1.0.0-dev `https://github.com/Deltares/Wflow.jl:Wflow#master`
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [d48b7d99] ~ Wflow v1.0.0-dev `https://github.com/Deltares/Wflow.jl:Wflow#master` ⇒ v1.0.0-dev `https://github.com/Deltares/Wflow.jl:Wflow#master`
# Precompiling project...
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [>                                        ]  0/1
#   ◓ Wflow
#   Progress [>                                        ]  0/1
#   ◑ Wflow
#   Progress [>                                        ]  0/1
#   ◒ Wflow
#   Progress [>                                        ]  0/1
#   ◐ Wflow
#   Progress [========================================>]  1/1
#   1 dependency successfully precompiled in 14 seconds. 126 already precompiled.

# %%
# Run the Wflow model
# Note: This assumes you have Julia and Wflow.jl installed
# !julia -e 'using Wflow; Wflow.run("./wflow_models/first_wflow_model/wflow_sbm.toml")'
# Out:
# [ Info: Wflow version v1.0.0-dev
# [ Info: Initialize model variables for model type sbm.
# ┌ Info: Cyclic parameters are provided by
# └ wflow_models/first_wflow_model/staticmaps.nc.
# ┌ Info: Forcing parameters are provided by
# └ wflow_models/first_wflow_model/inmaps-era5-2010.nc.
# ┌ Info: Set atmosphere_water__precipitation_volume_flux using netCDF variable
# └ precip as forcing parameter.
# ┌ Info: Set atmosphere_air__temperature using netCDF variable temp as forcing
# └ parameter.
# ┌ Info: Set land_surface_water__potential_evaporation_volume_flux using
# └ netCDF variable pet as forcing parameter.
# ┌ Info: Set vegetation__leaf_area_index using netCDF variable
# └ vegetation_leaf_area_index as cyclic parameter, with 12 timesteps.
# ┌ Info: General model settings
# │   snow = true
# │   gravitational_snow_transport = true
# │   glacier = true
# │   reservoirs = false
# │   pits = false
# └   water_demand = false
# [ Info: Set subbasin_location__count using netCDF variable subcatchment.
# ┌ Info: Set basin__local_drain_direction using netCDF variable
# └ local_drain_direction.
# [ Info: Set land_surface__slope using netCDF variable land_slope.
# [ Info: Set river_location__mask using netCDF variable river_mask.
# ┌ Info: Set land_water_covered__area_fraction using netCDF variable
# └ land_water_fraction.
# [ Info: Set river__length using netCDF variable river_length.
# [ Info: Set river__width using netCDF variable river_width.
# [ Info: Set river__slope using netCDF variable river_slope.
# ┌ Info: Set vegetation_root__depth using netCDF variable
# └ vegetation_root_depth.
# ┌ Info: Set vegetation__crop_factor using netCDF variable
# └ vegetation_crop_factor.
# ┌ Info: Set vegetation__specific_leaf_storage using netCDF variable
# └ vegetation_leaf_storage.
# ┌ Info: Set vegetation_wood_water__storage_capacity using netCDF variable
# └ vegetation_wood_storage.
# ┌ Info: Set vegetation_canopy__light_extinction_coefficient using netCDF
# └ variable vegetation_kext.
# ┌ Info: Set
# │ vegetation_canopy_water__mean_evaporation_to_mean_precipitation_ratio
# └ using uniform value 0.11 from TOML file.
# ┌ Info: Set snowpack__degree_day_coefficient using uniform value 3.75653 from
# └ TOML file.
# ┌ Info: Set atmosphere_air__snowfall_temperature_threshold using uniform
# └ value 0 from TOML file.
# ┌ Info: Set atmosphere_air__snowfall_temperature_interval using uniform value
# └ 2 from TOML file.
# ┌ Info: Set snowpack__melting_temperature_threshold using uniform value 0
# └ from TOML file.
# ┌ Info: Set snowpack__liquid_water_holding_capacity using uniform value 0.1
# └ from TOML file.
# ┌ Info: Set glacier_ice__melting_temperature_threshold using uniform value 0
# └ from TOML file.
# ┌ Info: Set glacier_ice__degree_day_coefficient using uniform value 3 from
# └ TOML file.
# ┌ Info: Set glacier_firn_accumulation__snowpack_dry_snow_leq_depth_fraction
# └ using uniform value 0.001 from TOML file.
# ┌ Info: Set glacier_surface__area_fraction using netCDF variable
# └ glacier_fraction.
# ┌ Info: Set glacier_ice__initial_leq_depth using netCDF variable
# └ glacier_initial_leq_depth.
# [ Info: Using 3 soil layers with the following thickness: [100, 300, 800]
# ┌ Info: Set soil_surface_temperature__weight_coefficient using default value
# └ 0.1125.
# ┌ Info: Set soil_surface_water__infiltration_reduction_parameter using
# └ uniform value 0.038 from TOML file.
# ┌ Info: Set soil_water__saturated_volume_fraction using netCDF variable
# └ soil_theta_s.
# ┌ Info: Set soil_water__residual_volume_fraction using netCDF variable
# └ soil_theta_r.
# ┌ Info: Set soil_surface_water__vertical_saturated_hydraulic_conductivity
# └ using netCDF variable soil_ksat_vertical.
# ┌ Info: Set
# │ soil_water__vertical_saturated_hydraulic_conductivity_scale_parameter
# └ using netCDF variable soil_f.
# [ Info: Set soil_water__air_entry_pressure_head using default value -10.0.
# ┌ Info: Set vegetation_root__feddes_critical_pressure_head_h1 using netCDF
# └ variable vegetation_feddes_h1.
# ┌ Info: Set vegetation_root__feddes_critical_pressure_head_h2 using netCDF
# └ variable vegetation_feddes_h2.
# ┌ Info: Set vegetation_root__feddes_critical_pressure_head_h3_high using
# └ netCDF variable vegetation_feddes_h3_high.
# ┌ Info: Set vegetation_root__feddes_critical_pressure_head_h3_low using
# └ netCDF variable vegetation_feddes_h3_low.
# ┌ Info: Set vegetation_root__feddes_critical_pressure_head_h4 using netCDF
# └ variable vegetation_feddes_h4.
# ┌ Info: Set
# │ vegetation_root__feddes_critical_pressure_head_h1_reduction_coefficient
# └ using netCDF variable vegetation_feddes_alpha_h1.
# [ Info: Set soil__thickness using netCDF variable soil_thickness.
# ┌ Info: Set compacted_soil_surface_water__infiltration_capacity using uniform
# └ value 10 from TOML file.
# ┌ Info: Set soil_water_saturated_zone_bottom__max_leakage_volume_flux using
# └ uniform value 0 from TOML file.
# ┌ Info: Set soil_layer_water__brooks_corey_exponent using netCDF variable
# └ soil_brooks_corey_c.
# ┌ Info: Set
# │ soil_layer_water__vertical_saturated_hydraulic_conductivity_factor using
# └ default value 1.0.
# ┌ Info: Set compacted_soil__area_fraction using netCDF variable
# └ soil_compacted_fraction.
# ┌ Info: Set soil_wet_root__sigmoid_function_shape_parameter using uniform
# └ value -500 from TOML file.
# ┌ Info: Set
# │ soil_water_saturated_zone_top__capillary_rise_max_water_table_depth using
# └ default value 2000.0.
# ┌ Info: Set soil_water_saturated_zone_top__capillary_rise_averianov_exponent
# └ using default value 2.0.
# ┌ Info: Set
# │ subsurface_water__horizontal_to_vertical_saturated_hydraulic_conductivity_ratio
# └ using uniform value 100 from TOML file.
# ┌ Info: Set land_surface_water_flow__manning_n_parameter using netCDF
# └ variable land_manning_n.
# ┌ Info: Kinematic wave approach is used for land flow, adaptive timestepping
# └ = false.
# ┌ Info: Using a fixed internal timestep (seconds) 3600.0 for kinematic wave
# └ land flow.
# ┌ Info: Kinematic wave approach is used for river flow, adaptive timestepping
# └ = false.
# ┌ Info: Using a fixed internal timestep (seconds) 900.0 for kinematic wave
# └ river flow.
# [ Info: Set river_water_flow__manning_n_parameter using default value 0.036.
# [ Info: Set river_bank_water__depth using netCDF variable river_depth.
# ┌ Info: Set river_water__external_inflow_volume_flow_rate using default value
# └ 0.0.
# ┌ Info: Create an output netCDF file
# │ wflow_models/first_wflow_model/run_default/output.nc for grid data, using
# └ compression level 1.
# ┌ Info: Create a state output netCDF file
# └ wflow_models/first_wflow_model/run_default/outstate/outstates.nc.
# ┌ Info: Create an output CSV file
# └ wflow_models/first_wflow_model/run_default/output.csv for scalar data.
# [ Info: Set outlets using netCDF variable outlets.
# [ Info: Set gauges_grdc using netCDF variable gauges_grdc.
# [ Info: Set gauges_grdc using netCDF variable gauges_grdc.
# ┌ Info: Adding scalar output for a map with a reducer function.
# │   fileformat = "CSV"
# │   param = "river_water__volume_flow_rate"
# │   mapname = "outlets"
# └   reducer_name = "only"
# ┌ Info: Adding scalar output for a map with a reducer function.
# │   fileformat = "CSV"
# │   param = "river_water__volume_flow_rate"
# │   mapname = "gauges_grdc"
# └   reducer_name = "only"
# ┌ Info: Adding scalar output for a map with a reducer function.
# │   fileformat = "CSV"
# │   param = "atmosphere_water__precipitation_volume_flux"
# │   mapname = "gauges_grdc"
# └   reducer_name = "only"
# [ Info: Set initial conditions from default values.
# [ Info: Initialized model
# ┌ Info: Run information
# │   model_type = "sbm"
# │   starttime = CFTime.DateTimeProlepticGregorian(2010-02-02T00:00:00)
# │   dt = 86400 seconds
# │   endtime = CFTime.DateTimeProlepticGregorian(2010-02-15T00:00:00)
# └   nthreads() = 1
#
# Progress:   0%|                                         |  ETA: N/AProgress:   8%|███▏                                     |  ETA: 0:02:42Progress:  15%|██████▎                                  |  ETA: 0:01:15Progress:  23%|█████████▌                               |  ETA: 0:00:45Progress:  31%|████████████▋                            |  ETA: 0:00:31Progress:  38%|███████████████▊                         |  ETA: 0:00:22Progress:  46%|██████████████████▉                      |  ETA: 0:00:16Progress:  54%|██████████████████████▏                  |  ETA: 0:00:12Progress:  62%|█████████████████████████▎               |  ETA: 0:00:09Progress:  69%|████████████████████████████▍            |  ETA: 0:00:06Progress:  77%|███████████████████████████████▌         |  ETA: 0:00:04Progress:  85%|██████████████████████████████████▊      |  ETA: 0:00:03Progress:  92%|█████████████████████████████████████▉   |  ETA: 0:00:01Progress: 100%|█████████████████████████████████████████| Time: 0:00:14Progress: 100%|█████████████████████████████████████████| Time: 0:00:14
# [ Info: Simulation duration: 15 seconds, 288 milliseconds
# ┌ Info: Write output states to netCDF file
# └ wflow_models/first_wflow_model/run_default/outstate/outstates.nc.

# %% [markdown]
# **What happens during the run?**
#
# 1. **Initialization**: Model reads configuration and loads static maps
# 2. **State loading**: Initial conditions are loaded from `inmaps/`
# 3. **Time loop**: For each timestep:
#    - Read forcing data (precipitation, temperature, PET)
#    - Compute interception and snow processes
#    - Calculate soil moisture dynamics
#    - Simulate runoff generation
#    - Route water through river network
#    - Write outputs at specified frequency
# 4. **Finalization**: Save final state for future runs
#
# **Runtime**: Depending on:
# - Simulation period length
# - Grid resolution and catchment size
# - Time step (daily, hourly, etc.)
# - Computer specifications
#
# Expect 1-30 minutes for typical daily simulations of 1-5 years.

# %% [markdown]
# ### 6.2 Monitoring Model Progress
#
# During the run, watch for:
# - **Water balance errors**: Should be < 0.1% per timestep
# - **Convergence issues**: Indicates potential parameter problems
# - **Memory usage**: Large models may need optimization
# - **Progress updates**: Shows current date being simulated

# %% [markdown]
# ---
#
# ## Part 7: Analyzing Model Results
#
# ### 7.1 Load and Inspect Output Files

# %%
# Load model outputs
output_file = "./wflow_models/first_wflow_model/run_default/output.nc"
ds = xr.open_dataset(output_file)

# Display dataset information
print("Output dataset contents:")
print(ds)
print("\nTime range:")
print(f"Start: {ds.time[0].values}")
print(f"End: {ds.time[-1].values}")
print(f"Total timesteps: {len(ds.time)}")
# Out:
# Output dataset contents:
# <xarray.Dataset> Size: 641kB
# Dimensions:  (time: 13, lat: 106, lon: 116, layer: 4)
# Coordinates:
#   * time     (time) datetime64[ns] 104B 2010-02-03 2010-02-04 ... 2010-02-15
#   * lat      (lat) float64 848B 45.81 45.82 45.83 45.84 ... 46.67 46.68 46.69
#   * lon      (lon) float64 928B 11.78 11.79 11.8 11.81 ... 12.72 12.73 12.74
#   * layer    (layer) float64 32B 1.0 2.0 3.0 4.0
# Data variables:
#     q_av     (time, lat, lon) float32 639kB ...
#
# Time range:
# Start: 2010-02-03T00:00:00.000000000
# End: 2010-02-15T00:00:00.000000000
# Total timesteps: 13

# %% [markdown]
# ### 7.2 Visualize Discharge Time Series
#
# Let's plot the simulated discharge at the basin outlet:

# %%
# Extract discharge at the outlet

# Get outlet location (typically where river has maximum upstream area)
discharge = ds['q_av'].max(dim=['lon', 'lat'])  # Adjust dimensions as needed

# Create discharge plot
fig, ax = plt.subplots(figsize=(14, 6))
discharge.plot(ax=ax, linewidth=1.5, color='steelblue')
ax.set_title('Simulated Discharge at Basin Outlet', fontsize=14, fontweight='bold')
ax.set_xlabel('Date', fontsize=12)
ax.set_ylabel('Discharge (m³/s)', fontsize=12)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.3 Spatial Visualization of Model Results
#
# Create spatial maps of outputs:

# %%
ds['q_av'].isel(time=6).plot()

# %% [markdown]
# ---
#
# ## Part 8: Best Practices and Troubleshooting
#
# ### 8.1 Common Issues and Solutions
#
# **Problem**: Model build fails with "No data found for region"
# - **Solution**: Check your region coordinates are correct (lon, lat order)
# - Verify data catalog has coverage for your area
# - Try a slightly larger bounding box
#
# **Problem**: Very high or low discharge values
# - **Solution**: Check forcing data units (mm/day vs mm/hour)
# - Verify DEM and river network are realistic
# - Inspect parameter maps for outliers
#
# **Problem**: Model runs slowly
# - **Solution**: Reduce grid resolution in build configuration
# - Use coarser timestep if appropriate
# - Limit output variables to essentials
#
# **Problem**: Large water balance errors
# - **Solution**: Check for missing or corrupted forcing data
# - Verify static maps have no missing values
# - Review numerical stability settings
#
# ### 8.2 Quality Control Checklist
#
# Before running your model, verify:
# - ✓ DEM has no sinks or anomalies
# - ✓ River network matches expected topology
# - ✓ Land use classes are reasonable
# - ✓ Soil parameters within physical ranges
# - ✓ Forcing data covers simulation period
# - ✓ No missing values in critical maps
# - ✓ Output directory has write permissions
#
# ### 8.3 Performance Optimization Tips
#
# 1. **Grid resolution**: Start coarse (500m-1km), refine if needed
# 2. **Timestep**: Use daily timestep unless sub-daily processes are critical
# 3. **Output frequency**: Write only what you need for analysis
# 4. **Spatial extent**: Model only the catchment of interest
# 5. **Warmup period**: Use 1-2 years to initialize states properly

# %% [markdown]
# ---
#
# ## Summary and Next Steps
#
# ### What We've Learned
#
# In this tutorial, you've learned the complete workflow for building and running your first Wflow model:
# 1. ✓ Set up and verify HydroMT installation
# 2. ✓ Build a complete Wflow model from scratch using example data
# 3. ✓ Visualize model components (topography, rivers, land use)
# 4. ✓ Understand model structure and key files
# 5. ✓ Run hydrological simulations
# 6. ✓ Analyze and visualize model outputs
#
# ### Additional Resources
#
# **Documentation**:
# - HydroMT docs: https://deltares.github.io/hydromt/
# - HydroMT-Wflow plugin: https://deltares.github.io/hydromt_wflow/
# - Wflow documentation: https://deltares.github.io/Wflow.jl/
#
# **Community**:
# - GitHub discussions: https://github.com/Deltares/hydromt/discussions
# - Issue tracker: https://github.com/Deltares/hydromt_wflow/issues
#
# ---

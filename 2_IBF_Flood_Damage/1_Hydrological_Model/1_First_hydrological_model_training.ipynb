# %% [markdown]
# # Building Your First Wflow Hydrological Model
#
# ## Overview
#
# This notebook provides a comprehensive, step-by-step guide to building a **Wflow hydrological model** from scratch using **HydroMT** (Hydrological Model Tools). By the end of this tutorial, you will understand how to set up and configure a distributed hydrological model.
#
# ### What is Wflow?
#
# Wflow is an open-source distributed hydrological modeling framework developed by Deltares. It simulates hydrological processes at high spatial and temporal resolution, making it ideal for:
# - Flood forecasting and early warning systems
# - Water resources management
# - Climate impact assessments
# - Catchment-scale water balance studies
#
# ### What is HydroMT?
#
# HydroMT is a Python package that automates and standardizes the setup of various hydrological models. It:
# - Automates data collection from multiple sources
# - Handles spatial data processing and resampling
# - Provides consistent workflows across different model types
# - Reduces manual preprocessing work significantly
#
# ---
#
# ## Learning Objectives
#
# By completing this notebook, you will be able to:
#
# 1. **Verify** that HydroMT recognizes the Wflow model plugin
# 2. **Build** a complete Wflow model using the HydroMT CLI and example data
# 3. **Visualize** the model components (DEM, rivers, land use, etc.)
# 4. **Understand** the structure and key files of a Wflow model
# 5. **Run** the Wflow model simulation
# 6. **Analyze and visualize** model outputs (discharge, spatial patterns)
#
# ---
#
# ## Important Note on Command Execution
#
# All lines in this notebook starting with `!` are executed from the command line. Within the notebook environment, logging messages appear after execution completes.
#
# **Tip**: You can copy these commands (without the `!`) and paste them directly into your terminal for real-time feedback during execution.

# %% [markdown]
# ---
#
# ## Part 1: Environment Setup and Verification
#
# ### 1.1 Select the Correct Kernel
#
# **⚠️ IMPORTANT**: Before running any code, ensure you have selected the correct kernel:
#
# 1. Go to **Kernel** → **Change Kernel** in the Jupyter menu in the top right corner of this notebook
# 2. Select **"HydroMT wflow (pixi)"** or the kernel that contains your HydroMT installation
#
# The kernel name should appear in the top-right corner of this notebook. If you see a different kernel name, click on it to change it.

# %% [markdown]
# ### 1.2 Verify HydroMT Installation
#
# Let's verify that HydroMT is properly installed and can recognize the Wflow model plugin. This command lists all available model plugins in your HydroMT installation.
#
# **Expected output**: You should see `wflow_sbm` and `wflow_sediment` listed among the available model plugins.

# %%
# List all available HydroMT model plugins
# !hydromt --models
# Out:
# Model plugins:
# 	- model (hydromt 1.3.0rc5)
# 	- example_model (hydromt 1.3.0rc5)
# 	- wflow_sbm (hydromt_wflow 1.0.0.dev0)
# 	- wflow_sediment (hydromt_wflow 1.0.0.dev0)

# %% [markdown]
# **Understanding the output**:
# - `model` and `example_model`: Base HydroMT classes
# - `wflow_sbm`: Wflow model using the SBM (Soil-Based Modeling) concept
# - `wflow_sediment`: Wflow sediment transport model (extension)

# %% [markdown]
# ---
#
# ## Part 2: Understanding the HydroMT Build Interface
#
# ### 2.1 The `hydromt build` Command
#
# The `hydromt build` command is the primary tool for creating new models. Its general syntax is:
#
# ```bash
# hydromt build MODEL_TYPE MODEL_ROOT -r REGION -i DATA_CATALOG -d DESTINATION [options]
# ```
#
# **Key arguments**:
# - `MODEL_TYPE`: The model to build (e.g., `wflow_sbm`)
# - `MODEL_ROOT`: Output directory where the model will be saved
# - `-r / --region`: Defines the geographic extent of your model
# - `-i / --config`: Configuration file (YAML) specifying build steps
# - `-d / --data`: Data catalog(s) containing input datasets
#
# ### 2.2 Region Definition Options
#
# You can define your study region in several ways:
#
# 1. **Basin outlets**: `{basin: [lon, lat]}` - Delineates upstream catchment
# 2. **Bounding box**: `{bbox: [xmin, ymin, xmax, ymax]}` - Rectangular area
# 3. **Geometry file**: `{geom: 'path/to/shapefile.shp'}` - Custom boundary
# 4. **Existing basins**: `{basin_index: id}` - Use predefined basin ID
#
# ### 2.3 Configuration File Structure
#
# The configuration file (YAML format) contains a sequence of setup methods that HydroMT executes. Common methods include:
#
# - `setup_basemaps`: Prepares topography, land use, and soil data
# - `setup_rivers`: Delineates river network
# - `setup_reservoirs`: Adds reservoir locations and parameters
# - `setup_lakes`: Includes lake geometries and characteristics
# - `setup_glaciers`: Incorporates glacier coverage (if applicable)
# - `setup_lulcmaps`: Processes land use/land cover data
# - `setup_laimaps`: Sets up leaf area index data
# - `setup_precip_forcing`: Prepares precipitation input
# - `setup_temp_pet_forcing`: Prepares temperature and potential evapotranspiration

# %% [markdown]
# ---
#
# ## Part 3: Building the Model
#
# ### 3.1 Prepare the Build Configuration
#
# Before running the build command, you need to prepare two key files:
#
# 1. **Configuration file** (`./model_build_files/wflow_build_first_model.yaml`): Defines what data to use and how to process it
# 2. **Data catalog** (optional): Specifies data sources if not using defaults
#
# Below is an example configuration file structure:

# %%
# Example: View a sample configuration file structure
sample_config = """
setup_basemaps:
  hydrography_fn: merit_hydro
  basin_index_fn: merit_hydro_index
  
setup_rivers:
  hydrography_fn: merit_hydro
  river_geom_fn: rivers_lin2019_v1
  river_upa: 30  # minimum upstream area in km2
  
setup_lakes:
  lakes_fn: hydrolakes
  min_area: 1.0  # minimum lake area in km2
  
setup_lulcmaps:
  lulc_fn: vito
  
setup_laimaps:
  lai_fn: modis_lai
  
setup_precip_forcing:
  precip_fn: era5_daily
  starttime: 2010-01-01
  endtime: 2015-12-31
  
setup_temp_pet_forcing:
  temp_pet_fn: era5_daily
  starttime: 2010-01-01
  endtime: 2015-12-31
"""

print(sample_config)
# Out:
# setup_basemaps:
#   hydrography_fn: merit_hydro
#   basin_index_fn: merit_hydro_index
#
# setup_rivers:
#   hydrography_fn: merit_hydro
#   river_geom_fn: rivers_lin2019_v1
#   river_upa: 30  # minimum upstream area in km2
#
# setup_lakes:
#   lakes_fn: hydrolakes
#   min_area: 1.0  # minimum lake area in km2
#
# setup_lulcmaps:
#   lulc_fn: vito
#
# setup_laimaps:
#   lai_fn: modis_lai
#
# setup_precip_forcing:
#   precip_fn: era5_daily
#   starttime: 2010-01-01
#   endtime: 2015-12-31
#
# setup_temp_pet_forcing:
#   temp_pet_fn: era5_daily
#   starttime: 2010-01-01
#   endtime: 2015-12-31

# %% [markdown]
# ### 3.2 Execute the Build Command
#
# Now we'll build the actual model. This process:
# 1. Downloads and processes required datasets
# 2. Delineates the catchment boundary
# 3. Creates the model grid
# 4. Derives hydrological parameters
# 5. Prepares forcing data
# 6. Sets up initial model state
#
# **Note**: The first build can take 1-60 minutes depending on:
# - Catchment size
# - Number of forcing years
# - Internet connection speed (for data downloads)
# - Computer processing power

# %%
# Build a Wflow model
# !hydromt build wflow_sbm ./wflow_models/first_wflow_model \
  -i ../model_build_files/wflow_build_first_model.yml \
  -d artifact_data \
  --fo \
  -vv  # Very verbose output for detailed logging
# Out:
# 2025-11-25 05:01:11,891 - hydromt - log - INFO - HydroMT version: 1.3.0-rc5
# Downloading file 'v1.0.0/data_catalog.yml' from 'https://raw.githubusercontent.com/Deltares/hydromt/main/data/catalogs/artifact_data/v1.0.0/data_catalog.yml' to '/home/thomasstolp/.hydromt/artifact_data'.
# 2025-11-25 05:01:12,441 - hydromt.data_catalog.data_catalog - data_catalog - INFO - Reading data catalog artifact_data latest
# 2025-11-25 05:01:12,441 - hydromt.data_catalog.data_catalog - data_catalog - INFO - Parsing data catalog from /home/thomasstolp/.hydromt/artifact_data/v1.0.0/data_catalog.yml
# Downloading data from 'https://github.com/DirkEilander/hydromt-artifacts/releases/download/v0.0.9/data.tar.gz' to file '/home/thomasstolp/.hydromt/artifact_data/latest/data.tar.gz'.
# SHA256 hash of downloaded file: 32de5b95c171628547f303d7f65d53cbb1b9da9af4834717c8efff93fe55aad4
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Untarring contents of '/home/thomasstolp/.hydromt/artifact_data/latest/data.tar.gz' to '/home/thomasstolp/.hydromt/artifact_data/latest'
# 2025-11-25 05:01:15,363 - hydromt.model.model - model - INFO - Initializing wflow_sbm model from hydromt_wflow (v1.0.0.dev0).
# 2025-11-25 05:01:15,363 - hydromt.data_catalog.data_catalog - data_catalog - INFO - Parsing data catalog from /opt/icpac-course/hydromt_wflow/hydromt_wflow/data/parameters_data.yml
# 2025-11-25 05:01:15,379 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Supported Wflow.jl version v1+
# 2025-11-25 05:01:15,380 - hydromt.hydromt_wflow.components.config - config - INFO - Reading default config file from /opt/icpac-course/hydromt_wflow/hydromt_wflow/data/wflow_sbm/wflow_sbm.toml.
# 2025-11-25 05:01:15,381 - hydromt - log - INFO - HydroMT version: 1.3.0-rc5
# 2025-11-25 05:01:15,382 - hydromt.model.model - model - INFO - build: setup_config
# 2025-11-25 05:01:15,382 - hydromt.model.model - model - INFO - setup_config.data={'time.starttime': datetime.datetime(2010, 1, 1, 0, 0), 'time.endtime': datetime.datetime(2010, 3, 31, 0, 0), 'time.timestepsecs': 86400, 'input.path_forcing': 'inmaps-era5-2010.nc', 'output.netcdf_grid.path': 'output.nc', 'output.netcdf_grid.compressionlevel': 1, 'output.netcdf_grid.variables.river_water__volume_flow_rate': 'q_av'}
# 2025-11-25 05:01:15,382 - hydromt.model.model - model - INFO - build: setup_basemaps
# 2025-11-25 05:01:15,382 - hydromt.model.model - model - INFO - setup_basemaps.basin_index_fn=merit_hydro_index
# 2025-11-25 05:01:15,382 - hydromt.model.model - model - INFO - setup_basemaps.res=0.00833
# 2025-11-25 05:01:15,382 - hydromt.model.model - model - INFO - setup_basemaps.upscale_method=ihu
# 2025-11-25 05:01:15,382 - hydromt.model.model - model - INFO - setup_basemaps.output_names={'basin__local_drain_direction': 'local_drain_direction', 'subbasin_location__count': 'subcatchment', 'land_surface__slope': 'land_slope'}
# 2025-11-25 05:01:15,382 - hydromt.model.model - model - INFO - setup_basemaps.hydrography_fn=merit_hydro
# 2025-11-25 05:01:15,382 - hydromt.model.model - model - INFO - setup_basemaps.region={'subbasin': [12.2051, 45.8331], 'strord': 4, 'bounds': [11.7, 45.35, 12.95, 46.7]}
# 2025-11-25 05:01:15,382 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Preparing base hydrography basemaps.
# 2025-11-25 05:01:15,382 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading merit_hydro RasterDataset data from /home/thomasstolp/.hydromt/artifact_data/latest/merit_hydro/{variable}.tif
# 2025-11-25 05:01:15,569 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading merit_hydro_index GeoDataFrame data from /home/thomasstolp/.hydromt/artifact_data/latest/merit_hydro_index.gpkg
# 2025-11-25 05:01:19,018 - hydromt.model.processes.basin_mask - basin_mask - INFO - subbasin bbox: [11.7750, 45.8042, 12.7450, 46.6900]
# 2025-11-25 05:01:19,104 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - (Sub)basin at original resolution has 664756 cells.
# 2025-11-25 05:01:19,299 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Upscale flow direction data: 10x, ihu method.
# 2025-11-25 05:01:33,172 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Derive stream order.
# 2025-11-25 05:01:33,357 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Map shape: (106, 116); active cells: 6637.
# 2025-11-25 05:01:33,358 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Outlet coordinates (1/1): (12.20750,45.83583).
# 2025-11-25 05:01:33,383 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Adding basin shape to staticgeoms.
# 2025-11-25 05:01:33,399 - hydromt.hydromt_wflow.workflows.basemaps - basemaps - INFO - Derive elevation and slope.
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - build: setup_rivers
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - setup_rivers.river_geom_fn=hydro_rivers_lin
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - setup_rivers.river_upa=30
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - setup_rivers.rivdph_method=powlaw
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - setup_rivers.slope_len=2000
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - setup_rivers.min_rivlen_ratio=0.0
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - setup_rivers.min_rivdph=1
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - setup_rivers.min_rivwth=30
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - setup_rivers.smooth_len=5000
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - setup_rivers.elevtn_map=land_elevation
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - setup_rivers.river_routing=kinematic_wave
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - setup_rivers.connectivity=8
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - setup_rivers.output_names={'river_location__mask': 'river_mask', 'river__length': 'river_length', 'river__width': 'river_width', 'river_bank_water__depth': 'river_depth', 'river__slope': 'river_slope', 'river_bank_water__elevation': 'river_bank_elevation'}
# 2025-11-25 05:01:33,664 - hydromt.model.model - model - INFO - setup_rivers.hydrography_fn=merit_hydro
# 2025-11-25 05:01:33,664 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Preparing river maps.
# 2025-11-25 05:01:33,671 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading merit_hydro RasterDataset data from /home/thomasstolp/.hydromt/artifact_data/latest/merit_hydro/{variable}.tif
# 2025-11-25 05:01:33,770 - hydromt.hydromt_wflow.workflows.river - river - INFO - Set river mask (min uparea: 30 km2) and prepare flow dirs.
# 2025-11-25 05:01:34,022 - hydromt.hydromt_wflow.workflows.river - river - INFO - Derive river length.
# 2025-11-25 05:01:37,434 - hydromt.hydromt_wflow.workflows.river - river - INFO - Derive river slope.
# 2025-11-25 05:01:38,181 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading hydro_rivers_lin GeoDataFrame data from /home/thomasstolp/.hydromt/artifact_data/latest/rivers_lin2019_v1.gpkg
# 2025-11-25 05:01:38,374 - hydromt.hydromt_wflow.workflows.river - river - INFO - Derive ['rivwth', 'qbankfull'] from shapefile.
# 2025-11-25 05:01:38,431 - hydromt.hydromt_wflow.workflows.river - river - INFO - Valid for 381/655 river cells (max dist: 392 m).
# 2025-11-25 05:01:41,502 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Update wflow config model.river_routing="kinematic_wave"
# 2025-11-25 05:01:41,502 - hydromt.model.model - model - INFO - build: setup_reservoirs_simple_control
# 2025-11-25 05:01:41,502 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.timeseries_fn=gww
# 2025-11-25 05:01:41,502 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.overwrite_existing=False
# 2025-11-25 05:01:41,502 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.duplicate_id=error
# 2025-11-25 05:01:41,502 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.min_area=1.0
# 2025-11-25 05:01:41,502 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.output_names={'reservoir_area__count': 'reservoir_area_id', 'reservoir_location__count': 'reservoir_outlet_id', 'reservoir_surface__area': 'reservoir_area', 'reservoir_water_surface__initial_elevation': 'reservoir_initial_depth', 'reservoir_water__rating_curve_type_count': 'reservoir_rating_curve', 'reservoir_water__storage_curve_type_count': 'reservoir_storage_curve', 'reservoir_water__max_volume': 'reservoir_max_volume', 'reservoir_water__target_min_volume_fraction': 'reservoir_target_min_fraction', 'reservoir_water__target_full_volume_fraction': 'reservoir_target_full_fraction', 'reservoir_water_demand__required_downstream_volume_flow_rate': 'reservoir_demand', 'reservoir_water_release_below_spillway__max_volume_flow_rate': 'reservoir_max_release'}
# 2025-11-25 05:01:41,503 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.geom_name=meta_reservoirs_simple_control
# 2025-11-25 05:01:41,503 - hydromt.model.model - model - INFO - setup_reservoirs_simple_control.reservoirs_fn=hydro_reservoirs
# 2025-11-25 05:01:41,503 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing reservoir with simple control maps.
# 2025-11-25 05:01:41,503 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading hydro_reservoirs GeoDataFrame data from /home/thomasstolp/.hydromt/artifact_data/latest/hydro_reservoirs.gpkg
# 2025-11-25 05:01:41,526 - hydromt.hydromt_wflow.workflows.reservoirs - reservoirs - INFO - 0 reservoir(s) of sufficient size found within region.
# 2025-11-25 05:01:41,526 - hydromt.model.model - model - INFO - build: setup_reservoirs_no_control
# 2025-11-25 05:01:41,527 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.rating_curve_fns=None
# 2025-11-25 05:01:41,527 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.overwrite_existing=False
# 2025-11-25 05:01:41,527 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.duplicate_id=error
# 2025-11-25 05:01:41,527 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.min_area=10.0
# 2025-11-25 05:01:41,527 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.output_names={'reservoir_area__count': 'reservoir_area_id', 'reservoir_location__count': 'reservoir_outlet_id', 'reservoir_surface__area': 'reservoir_area', 'reservoir_water_surface__initial_elevation': 'reservoir_initial_depth', 'reservoir_water_flow_threshold_level__elevation': 'reservoir_outflow_threshold', 'reservoir_water__rating_curve_coefficient': 'reservoir_b', 'reservoir_water__rating_curve_exponent': 'reservoir_e', 'reservoir_water__rating_curve_type_count': 'reservoir_rating_curve', 'reservoir_water__storage_curve_type_count': 'reservoir_storage_curve', 'reservoir_lower_location__count': 'reservoir_lower_id'}
# 2025-11-25 05:01:41,527 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.geom_name=meta_reservoirs_no_control
# 2025-11-25 05:01:41,527 - hydromt.model.model - model - INFO - setup_reservoirs_no_control.reservoirs_fn=hydro_lakes
# 2025-11-25 05:01:41,527 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing reservoir maps.
# 2025-11-25 05:01:41,527 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading hydro_lakes GeoDataFrame data from /home/thomasstolp/.hydromt/artifact_data/latest/hydro_lakes.gpkg
# 2025-11-25 05:01:41,538 - hydromt.hydromt_wflow.workflows.reservoirs - reservoirs - INFO - 0 reservoir(s) of sufficient size found within region.
# 2025-11-25 05:01:41,538 - hydromt.model.model - model - INFO - build: setup_glaciers
# 2025-11-25 05:01:41,539 - hydromt.model.model - model - INFO - setup_glaciers.min_area=0.0
# 2025-11-25 05:01:41,539 - hydromt.model.model - model - INFO - setup_glaciers.output_names={'glacier_surface__area_fraction': 'glacier_fraction', 'glacier_ice__initial_leq_depth': 'glacier_initial_leq_depth'}
# 2025-11-25 05:01:41,539 - hydromt.model.model - model - INFO - setup_glaciers.geom_name=glaciers
# 2025-11-25 05:01:41,539 - hydromt.model.model - model - INFO - setup_glaciers.glaciers_fn=rgi
# 2025-11-25 05:01:41,539 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing glacier maps.
# 2025-11-25 05:01:41,539 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading rgi GeoDataFrame data from /home/thomasstolp/.hydromt/artifact_data/latest/rgi.gpkg
# 2025-11-25 05:01:41,551 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - 38 glaciers of sufficient size found within region.
# 2025-11-25 05:01:42,872 - hydromt.model.model - model - INFO - build: setup_lulcmaps
# 2025-11-25 05:01:42,873 - hydromt.model.model - model - INFO - setup_lulcmaps.lulc_mapping_fn=globcover_mapping_default
# 2025-11-25 05:01:42,873 - hydromt.model.model - model - INFO - setup_lulcmaps.lulc_vars=['landuse', 'vegetation_kext', 'land_manning_n', 'soil_compacted_fraction', 'vegetation_root_depth', 'vegetation_leaf_storage', 'vegetation_wood_storage', 'land_water_fraction', 'vegetation_crop_factor', 'vegetation_feddes_alpha_h1', 'vegetation_feddes_h1', 'vegetation_feddes_h2', 'vegetation_feddes_h3_high', 'vegetation_feddes_h3_low', 'vegetation_feddes_h4']
# 2025-11-25 05:01:42,873 - hydromt.model.model - model - INFO - setup_lulcmaps.output_names_suffix=None
# 2025-11-25 05:01:42,873 - hydromt.model.model - model - INFO - setup_lulcmaps.lulc_fn=globcover_2009
# 2025-11-25 05:01:42,873 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Preparing LULC parameter maps.
# 2025-11-25 05:01:42,875 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading globcover_2009 RasterDataset data from /home/thomasstolp/.hydromt/artifact_data/latest/globcover.tif
# 2025-11-25 05:01:42,888 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading globcover_mapping_default DataFrame data from /opt/icpac-course/hydromt_wflow/hydromt_wflow/data/lulc/globcover_mapping.csv
# 2025-11-25 05:01:42,902 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving landuse using mode resampling (nodata=230).
# 2025-11-25 05:01:43,026 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_kext using average resampling (nodata=-999.0).
# 2025-11-25 05:01:43,050 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving land_manning_n using average resampling (nodata=-999.0).
# 2025-11-25 05:01:43,074 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving soil_compacted_fraction using average resampling (nodata=-999.0).
# 2025-11-25 05:01:43,098 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_root_depth using average resampling (nodata=-999.0).
# 2025-11-25 05:01:43,122 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_leaf_storage using average resampling (nodata=-999.0).
# 2025-11-25 05:01:43,147 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_wood_storage using average resampling (nodata=-999.0).
# 2025-11-25 05:01:43,171 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving land_water_fraction using average resampling (nodata=-999.0).
# 2025-11-25 05:01:43,194 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_crop_factor using average resampling (nodata=-999.0).
# 2025-11-25 05:01:43,219 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_alpha_h1 using mode resampling (nodata=-999).
# 2025-11-25 05:01:43,349 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h1 using average resampling (nodata=-999).
# 2025-11-25 05:01:43,376 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h2 using average resampling (nodata=-999).
# 2025-11-25 05:01:43,404 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h3_high using average resampling (nodata=-999).
# 2025-11-25 05:01:43,432 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h3_low using average resampling (nodata=-999).
# 2025-11-25 05:01:43,461 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving vegetation_feddes_h4 using average resampling (nodata=-999).
# 2025-11-25 05:01:43,524 - hydromt.model.model - model - INFO - build: setup_laimaps
# 2025-11-25 05:01:43,525 - hydromt.model.model - model - INFO - setup_laimaps.lulc_fn=None
# 2025-11-25 05:01:43,525 - hydromt.model.model - model - INFO - setup_laimaps.lulc_sampling_method=any
# 2025-11-25 05:01:43,525 - hydromt.model.model - model - INFO - setup_laimaps.lulc_zero_classes=[]
# 2025-11-25 05:01:43,525 - hydromt.model.model - model - INFO - setup_laimaps.buffer=2
# 2025-11-25 05:01:43,525 - hydromt.model.model - model - INFO - setup_laimaps.output_name=vegetation_leaf_area_index
# 2025-11-25 05:01:43,525 - hydromt.model.model - model - INFO - setup_laimaps.lai_fn=modis_lai
# 2025-11-25 05:01:43,525 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing LAI maps.
# 2025-11-25 05:01:43,527 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading modis_lai RasterDataset data from /home/thomasstolp/.hydromt/artifact_data/latest/modis_lai.nc
# 2025-11-25 05:01:45,451 - hydromt.hydromt_wflow.workflows.landuse - landuse - INFO - Deriving LAI using average resampling (nodata=nan).
# 2025-11-25 05:01:45,560 - hydromt.model.model - model - INFO - build: setup_soilmaps
# 2025-11-25 05:01:45,560 - hydromt.model.model - model - INFO - setup_soilmaps.soil_fn=soilgrids
# 2025-11-25 05:01:45,561 - hydromt.model.model - model - INFO - setup_soilmaps.ptf_ksatver=brakensiek
# 2025-11-25 05:01:45,561 - hydromt.model.model - model - INFO - setup_soilmaps.wflow_thicknesslayers=[100, 300, 800]
# 2025-11-25 05:01:45,561 - hydromt.model.model - model - INFO - setup_soilmaps.output_names={'soil_water__saturated_volume_fraction': 'soil_theta_s', 'soil_water__residual_volume_fraction': 'soil_theta_r', 'soil_surface_water__vertical_saturated_hydraulic_conductivity': 'soil_ksat_vertical', 'soil__thickness': 'soil_thickness', 'soil_water__vertical_saturated_hydraulic_conductivity_scale_parameter': 'soil_f', 'soil_layer_water__brooks_corey_exponent': 'soil_brooks_corey_c'}
# 2025-11-25 05:01:45,561 - hydromt.hydromt_wflow.wflow_sbm - wflow_sbm - INFO - Preparing soil parameter maps.
# 2025-11-25 05:01:45,564 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading soilgrids RasterDataset data from /home/thomasstolp/.hydromt/artifact_data/latest/soilgrids/{variable}.tif
# 2025-11-25 05:01:46,249 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - calculate and resample theta_s
# 2025-11-25 05:01:46,561 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - calculate and resample theta_r
# 2025-11-25 05:01:46,926 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - calculate and resample ksat_vertical
# 2025-11-25 05:01:47,011 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - calculate and resample pore size distribution index
# 2025-11-25 05:01:48,007 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - fit z - log(ksat_vertical ) with numpy linalg regression (y = b*x) -> M_
# 2025-11-25 05:01:48,577 - hydromt.hydromt_wflow.workflows.soilgrids - soilgrids - INFO - fit zi - Ksat with curve_fit (scipy.optimize) -> M
# 2025-11-25 05:01:52,368 - hydromt.gis.raster - raster - WARNING - No numerical nodata value found, skipping set_nodata
# 2025-11-25 05:01:53,059 - hydromt.gis.raster - raster - WARNING - No numerical nodata value found, skipping set_nodata
# 2025-11-25 05:01:53,249 - hydromt.gis.raster - raster - WARNING - No numerical nodata value found, skipping set_nodata
# 2025-11-25 05:01:53,396 - hydromt.model.model - model - INFO - build: setup_outlets
# 2025-11-25 05:01:53,397 - hydromt.model.model - model - INFO - setup_outlets.river_only=True
# 2025-11-25 05:01:53,397 - hydromt.model.model - model - INFO - setup_outlets.toml_output=csv
# 2025-11-25 05:01:53,397 - hydromt.model.model - model - INFO - setup_outlets.gauge_toml_header=['river_q']
# 2025-11-25 05:01:53,397 - hydromt.model.model - model - INFO - setup_outlets.gauge_toml_param=['river_water__volume_flow_rate']
# 2025-11-25 05:01:53,397 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Gauges locations set based on river outlets.
# 2025-11-25 05:01:53,414 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Gauges map based on catchment river outlets added.
# 2025-11-25 05:01:53,414 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Adding ['river_water__volume_flow_rate'] to csv section of toml.
# 2025-11-25 05:01:53,414 - hydromt.model.model - model - INFO - build: setup_gauges
# 2025-11-25 05:01:53,414 - hydromt.model.model - model - INFO - setup_gauges.index_col=None
# 2025-11-25 05:01:53,414 - hydromt.model.model - model - INFO - setup_gauges.snap_to_river=True
# 2025-11-25 05:01:53,414 - hydromt.model.model - model - INFO - setup_gauges.mask=None
# 2025-11-25 05:01:53,414 - hydromt.model.model - model - INFO - setup_gauges.snap_uparea=False
# 2025-11-25 05:01:53,414 - hydromt.model.model - model - INFO - setup_gauges.max_dist=10000.0
# 2025-11-25 05:01:53,414 - hydromt.model.model - model - INFO - setup_gauges.wdw=3
# 2025-11-25 05:01:53,414 - hydromt.model.model - model - INFO - setup_gauges.rel_error=0.05
# 2025-11-25 05:01:53,414 - hydromt.model.model - model - INFO - setup_gauges.abs_error=50.0
# 2025-11-25 05:01:53,414 - hydromt.model.model - model - INFO - setup_gauges.fillna=False
# 2025-11-25 05:01:53,414 - hydromt.model.model - model - INFO - setup_gauges.derive_subcatch=False
# 2025-11-25 05:01:53,414 - hydromt.model.model - model - INFO - setup_gauges.basename=None
# 2025-11-25 05:01:53,414 - hydromt.model.model - model - INFO - setup_gauges.toml_output=csv
# 2025-11-25 05:01:53,415 - hydromt.model.model - model - INFO - setup_gauges.gauge_toml_header=['river_q', 'precip']
# 2025-11-25 05:01:53,415 - hydromt.model.model - model - INFO - setup_gauges.gauge_toml_param=['river_water__volume_flow_rate', 'atmosphere_water__precipitation_volume_flux']
# 2025-11-25 05:01:53,415 - hydromt.model.model - model - INFO - setup_gauges.gauges_fn=grdc
# 2025-11-25 05:01:53,415 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading grdc GeoDataFrame data from /home/thomasstolp/.hydromt/artifact_data/latest/grdc.csv
# 2025-11-25 05:01:53,426 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - 3 grdc gauge locations found within domain
# 2025-11-25 05:01:53,808 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Adding ['river_water__volume_flow_rate', 'atmosphere_water__precipitation_volume_flux'] to csv section of toml.
# 2025-11-25 05:01:53,809 - hydromt.model.model - model - INFO - build: setup_precip_forcing
# 2025-11-25 05:01:53,809 - hydromt.model.model - model - INFO - setup_precip_forcing.precip_clim_fn=None
# 2025-11-25 05:01:53,809 - hydromt.model.model - model - INFO - setup_precip_forcing.chunksize=None
# 2025-11-25 05:01:53,809 - hydromt.model.model - model - INFO - setup_precip_forcing.precip_fn=era5
# 2025-11-25 05:01:53,812 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading era5 RasterDataset data from /home/thomasstolp/.hydromt/artifact_data/latest/era5.nc
# 2025-11-25 05:01:53,913 - hydromt.model.model - model - INFO - build: setup_temp_pet_forcing
# 2025-11-25 05:01:53,913 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.pet_method=debruin
# 2025-11-25 05:01:53,913 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.press_correction=True
# 2025-11-25 05:01:53,913 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.temp_correction=True
# 2025-11-25 05:01:53,913 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.wind_correction=True
# 2025-11-25 05:01:53,913 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.wind_altitude=10
# 2025-11-25 05:01:53,913 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.reproj_method=nearest_index
# 2025-11-25 05:01:53,913 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.fillna_method=None
# 2025-11-25 05:01:53,913 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.dem_forcing_fn=era5_orography
# 2025-11-25 05:01:53,913 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.skip_pet=False
# 2025-11-25 05:01:53,913 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.chunksize=None
# 2025-11-25 05:01:53,913 - hydromt.model.model - model - INFO - setup_temp_pet_forcing.temp_pet_fn=era5
# 2025-11-25 05:01:53,916 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading era5 RasterDataset data from /home/thomasstolp/.hydromt/artifact_data/latest/era5.nc
# 2025-11-25 05:01:53,977 - hydromt.data_catalog.sources.data_source - data_source - INFO - Reading era5_orography RasterDataset data from /home/thomasstolp/.hydromt/artifact_data/latest/era5_orography.nc
# 2025-11-25 05:01:54,284 - hydromt.model.model - model - INFO - build: setup_constant_pars
# 2025-11-25 05:01:54,284 - hydromt.model.model - model - INFO - setup_constant_pars.subsurface_water__horizontal_to_vertical_saturated_hydraulic_conductivity_ratio=100
# 2025-11-25 05:01:54,284 - hydromt.model.model - model - INFO - setup_constant_pars.snowpack__degree_day_coefficient=3.75653
# 2025-11-25 05:01:54,284 - hydromt.model.model - model - INFO - setup_constant_pars.soil_surface_water__infiltration_reduction_parameter=0.038
# 2025-11-25 05:01:54,284 - hydromt.model.model - model - INFO - setup_constant_pars.vegetation_canopy_water__mean_evaporation_to_mean_precipitation_ratio=0.11
# 2025-11-25 05:01:54,284 - hydromt.model.model - model - INFO - setup_constant_pars.compacted_soil_surface_water__infiltration_capacity=10
# 2025-11-25 05:01:54,284 - hydromt.model.model - model - INFO - setup_constant_pars.soil_water_saturated_zone_bottom__max_leakage_volume_flux=0
# 2025-11-25 05:01:54,285 - hydromt.model.model - model - INFO - setup_constant_pars.soil_wet_root__sigmoid_function_shape_parameter=-500
# 2025-11-25 05:01:54,285 - hydromt.model.model - model - INFO - setup_constant_pars.atmosphere_air__snowfall_temperature_threshold=0
# 2025-11-25 05:01:54,285 - hydromt.model.model - model - INFO - setup_constant_pars.atmosphere_air__snowfall_temperature_interval=2
# 2025-11-25 05:01:54,285 - hydromt.model.model - model - INFO - setup_constant_pars.snowpack__melting_temperature_threshold=0
# 2025-11-25 05:01:54,285 - hydromt.model.model - model - INFO - setup_constant_pars.snowpack__liquid_water_holding_capacity=0.1
# 2025-11-25 05:01:54,285 - hydromt.model.model - model - INFO - setup_constant_pars.glacier_ice__degree_day_coefficient=3
# 2025-11-25 05:01:54,285 - hydromt.model.model - model - INFO - setup_constant_pars.glacier_firn_accumulation__snowpack_dry_snow_leq_depth_fraction=0.001
# 2025-11-25 05:01:54,285 - hydromt.model.model - model - INFO - setup_constant_pars.glacier_ice__melting_temperature_threshold=0
# 2025-11-25 05:01:54,285 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Write model data to /home/thomasstolp/Capacity-Building-ICPAC-for-climate-services/2_IBF_Floo_Damage/1_Hydrological_Model/wflow_models/first_wflow_model
# 2025-11-25 05:01:54,300 - hydromt.model.components.grid - grid - INFO - wflow_sbm.staticmaps: Writing grid data to /home/thomasstolp/Capacity-Building-ICPAC-for-climate-services/2_IBF_Floo_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticmaps.nc.
# 2025-11-25 05:01:54,433 - hydromt.model.components.spatial - spatial - INFO - wflow_sbm.staticmaps: Writing region to /home/thomasstolp/Capacity-Building-ICPAC-for-climate-services/2_IBF_Floo_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/region.geojson.
# 2025-11-25 05:01:54,476 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/thomasstolp/Capacity-Building-ICPAC-for-climate-services/2_IBF_Floo_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/basins_highres.geojson.
# 2025-11-25 05:01:54,499 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/thomasstolp/Capacity-Building-ICPAC-for-climate-services/2_IBF_Floo_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/basins.geojson.
# 2025-11-25 05:01:54,505 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/thomasstolp/Capacity-Building-ICPAC-for-climate-services/2_IBF_Floo_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/rivers.geojson.
# 2025-11-25 05:01:54,511 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/thomasstolp/Capacity-Building-ICPAC-for-climate-services/2_IBF_Floo_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/glaciers.geojson.
# 2025-11-25 05:01:54,556 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/thomasstolp/Capacity-Building-ICPAC-for-climate-services/2_IBF_Floo_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/outlets.geojson.
# 2025-11-25 05:01:54,559 - hydromt.model.components.geoms - geoms - INFO - wflow_sbm.geoms: Writing geoms to /home/thomasstolp/Capacity-Building-ICPAC-for-climate-services/2_IBF_Floo_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/staticgeoms/gauges_grdc.geojson.
# 2025-11-25 05:01:54,563 - hydromt.hydromt_wflow.components.forcing - forcing - INFO - Write forcing file
# 2025-11-25 05:01:54,564 - hydromt.hydromt_wflow.components.forcing - forcing - WARNING - Start time 2010-01-01T00:00:00.000000 does not match the beginning of the data. Changing to start of the data: 2010-02-02T00:00:00.000000000.
# 2025-11-25 05:01:54,564 - hydromt.hydromt_wflow.components.forcing - forcing - WARNING - End time 2010-03-31T00:00:00.000000 does not match the end of the data. Changing to end of the data: 2010-02-15T00:00:00.000000000.
# 2025-11-25 05:01:54,567 - hydromt.hydromt_wflow.components.forcing - forcing - INFO - Writing file /home/thomasstolp/Capacity-Building-ICPAC-for-climate-services/2_IBF_Floo_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/inmaps-era5-2010.nc
# [########################################] | 100% Completed | 201.02 ms
# 2025-11-25 05:01:54,794 - hydromt.model.components.tables - tables - INFO - wflow_sbm.tables: No tables found, skip writing.
# 2025-11-25 05:01:54,795 - hydromt.model.components.grid - grid - INFO - wflow_sbm.states: No grid data found, skip writing.
# 2025-11-25 05:01:54,795 - hydromt.hydromt_wflow.components.config - config - INFO - Writing model config to /home/thomasstolp/Capacity-Building-ICPAC-for-climate-services/2_IBF_Floo_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/wflow_sbm.toml.

# %% [markdown]
# **Command breakdown**:
# - `wflow_sbm`: We're building a Wflow SBM model
# - `./wflow_models/first_wflow_model`: Output directory for the model
# - `-i ../model_build_files/wflow_build_first_model.yml`: Use this configuration file
# - `-d artifact_data`: Data catalog location
# - `-vv`: Maximum verbosity for logging
#
# **What happens during the build?**
#
# The build process executes several steps:
#
# 1. **Basin delineation**: Identifies the upstream catchment area
# 2. **DEM processing**: Processes digital elevation model for terrain analysis
# 3. **Flow direction**: Computes flow direction and accumulation
# 4. **River network**: Extracts river channels and calculates properties
# 5. **Land cover**: Processes land use/land cover to derive model parameters
# 6. **Soil data**: Incorporates soil properties (texture, depth, etc.)
# 7. **Forcing preparation**: Processes precipitation, temperature, and PET data
# 8. **Parameter derivation**: Calculates distributed hydrological parameters

# %% [markdown]
# ---
#
# ## Part 4: Exploring the Model Structure
#
# ### 4.1 Model Directory Organization
#
# After the build completes, your model directory contains several important files and folders:

# %%
# List the contents of the model directory
# !ls -lh ./wflow_models/first_wflow_model
# Out:
# total 3.5M
# -rw-r--r-- 1 thomasstolp thomasstolp  47K Nov 25 05:01 hydromt.log
# -rw-r--r-- 1 thomasstolp thomasstolp 7.0K Nov 25 05:01 hydromt_data.yml
# -rw-r--r-- 1 thomasstolp thomasstolp 448K Nov 25 05:01 inmaps-era5-2010.nc
# drwxr-xr-x 2 thomasstolp thomasstolp 4.0K Nov 25 05:01 staticgeoms
# -rw-r--r-- 1 thomasstolp thomasstolp 3.0M Nov 25 05:01 staticmaps.nc
# -rw-r--r-- 1 thomasstolp thomasstolp 5.0K Nov 25 05:01 wflow_sbm.toml

# %% [markdown]
# **Expected directory structure**:
#
# ```
# first_wflow_model/
# ├── staticmaps.nc        # Static spatial parameters (DEM, land use, soil, etc.)
# ├── staticgeoms/         # Vector geometries (rivers, lakes, gauges, subcatchments)
# ├── inmaps/              # Initial conditions and state maps
# ├── inmaps-era5-2010.nc  # Climate forcing data (precip, temp, PET)
# ├── wflow_sbm.toml       # Model configuration file
# ├── hydromt_data.yml     # Data catalog used during build
# └── hydromt.log          # Build process log file
# ```
#
# ### 4.2 Understanding Key Components
#
# #### Static Maps (`staticmaps.nc`)
# Contains gridded spatial parameters that don't change during simulation:
# - `wflow_dem.nc`: Digital elevation model
# - `wflow_ldd.nc`: Local drainage direction
# - `wflow_river.nc`: River mask and properties
# - `wflow_landuse.nc`: Land cover classification
# - `c_*.nc`: Soil parameters (various)
# - `theta_*.nc`: Soil moisture parameters
# - `ksat_*.nc`: Saturated hydraulic conductivity
#
# #### Static Geometries (`staticgeoms/`)
# Vector data for model features:
# - `rivers.geojson`: River network as lines
# - `basins.geojson`: Subcatchment polygons
# - `lakes.geojson`: Lake geometries (if present)
# - `gauges.geojson`: Observation locations (if added)
#
# #### Forcing Data
# Time-varying climate inputs:
# - `inmaps-era5-2010.nc.nc`: Contains precipitation, temperature, and PET timeseries
#
# #### Model Configuration (`wflow_sbm.toml`)
# The TOML file controls:
# - Simulation period
# - Output variables and frequency
# - Model component activation
# - Numerical settings

# %% [markdown]
# ### 4.3 Inspecting the Model with Python
#
# HydroMT provides a Python API to interact with the built model. This is useful for:
# - Inspecting model properties
# - Modifying parameters
# - Creating visualizations
# - Quality control

# %%
# Import necessary libraries
import numpy as np
import xarray as xr
import geopandas as gpd
from matplotlib import colors
import matplotlib.patches as mpatches
import cartopy.crs as ccrs
import cartopy.io.img_tiles as cimgt
import matplotlib.pyplot as plt
from hydromt_wflow import WflowSbmModel

# Load the model
model = WflowSbmModel(root="./wflow_models/first_wflow_model", mode="r")
model.read()
# Out:
# 2025-11-25 05:02:30,936 - hydromt.model.model - model - INFO - Initializing wflow_sbm model from hydromt_wflow (v1.0.0.dev0).
# 2025-11-25 05:02:30,937 - hydromt.data_catalog.data_catalog - data_catalog - INFO - Parsing data catalog from /opt/icpac-course/hydromt_wflow/hydromt_wflow/data/parameters_data.yml
# 2025-11-25 05:02:30,976 - hydromt.hydromt_wflow.wflow_base - wflow_base - INFO - Supported Wflow.jl version v1+
# 2025-11-25 05:02:30,977 - hydromt.hydromt_wflow.components.config - config - INFO - Reading model config file from /home/thomasstolp/Capacity-Building-ICPAC-for-climate-services/2_IBF_Floo_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/wflow_sbm.toml.
# 2025-11-25 05:02:30,979 - hydromt.hydromt_wflow.components.config - config - INFO - Reading model config file from /home/thomasstolp/Capacity-Building-ICPAC-for-climate-services/2_IBF_Floo_Damage/1_Hydrological_Model/wflow_models/first_wflow_model/wflow_sbm.toml.
# 2025-11-25 05:02:31,654 - hydromt.hydromt_wflow.components.states - states - WARNING - CRS not found in states data, setting to model CRS.
# 2025-11-25 05:02:31,660 - hydromt.model.components.tables - tables - INFO - Reading model table files.

# %%
# Display basic model information
print(f"Model region: {model.region}")
print(f"Model CRS: {model.crs}")
# Out:
# Model region:                                             geometry
# 0  POLYGON ((12.745 45.80667, 12.745 46.69, 11.77...
# Model CRS: EPSG:4326

# %% [markdown]
# ### 4.4 Visualizing Model Components
#
# Let's create some basic visualizations to understand our model domain:

# %%
# read and mask the model elevation
da = model.staticmaps.data["land_elevation"].raster.mask_nodata()
da.attrs.update(long_name="elevation", units="m")
# read/derive river geometries
gdf_riv = model.rivers
# read/derive model basin boundary
gdf_bas = model.basins

# we assume the model maps are in the geographic CRS EPSG:4326
proj = ccrs.PlateCarree()
# adjust zoomlevel and figure size to your basis size & aspect
zoom_level = 10
figsize = (10, 8)
shaded = False  # shaded elevation (looks nicer with more pixels (e.g.: larger basins))!

# initialize image with geoaxes
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(projection=proj)
bbox = da.raster.box.to_crs(3857).buffer(5e3).to_crs(da.raster.crs).total_bounds
extent = np.array(bbox)[[0, 2, 1, 3]]
ax.set_extent(extent, crs=proj)

# add sat background image
ax.add_image(cimgt.QuadtreeTiles(), zoom_level, alpha=0.5)

## plot elevation\
# create nice colormap
vmin, vmax = da.quantile([0.0, 0.98]).compute()
c_dem = plt.cm.terrain(np.linspace(0.25, 1, 256))
cmap = colors.LinearSegmentedColormap.from_list("dem", c_dem)
norm = colors.Normalize(vmin=vmin, vmax=vmax)
kwargs = dict(cmap=cmap, norm=norm)
# plot 'normal' elevation
da.plot(
    transform=proj, ax=ax, zorder=1, cbar_kwargs=dict(aspect=30, shrink=0.8), **kwargs
)
# plot elevation with shades
if shaded:
    ls = colors.LightSource(azdeg=315, altdeg=45)
    dx, dy = da.raster.res
    _rgb = ls.shade(
        da.fillna(0).values,
        norm=kwargs["norm"],
        cmap=kwargs["cmap"],
        blend_mode="soft",
        dx=dx,
        dy=dy,
        vert_exag=200,
    )
    rgb = xr.DataArray(dims=("y", "x", "rgb"), data=_rgb, coords=da.raster.coords)
    rgb = xr.where(np.isnan(da), np.nan, rgb)
    rgb.plot.imshow(transform=proj, ax=ax, zorder=2)

# plot rivers with increasing width with stream order
gdf_riv.plot(
    ax=ax, linewidth=gdf_riv["strord"] / 2, color="blue", zorder=3, label="river"
)
# plot the basin boundary
gdf_bas.boundary.plot(ax=ax, color="k", linewidth=0.3)
# plot various vector layers if present
if "outlets" in model.geoms.data:
    model.geoms.data["outlets"].plot(
        ax=ax, marker="d", markersize=25, facecolor="k", zorder=5, label="outlets"
    )
patches = []  # manual patches for legend, see https://github.com/geopandas/geopandas/issues/660
if "meta_reservoirs_no_control" in model.geoms.data:
    kwargs = dict(facecolor="lightblue", edgecolor="black", linewidth=1, label="reservoirs (natural lakes)")
    model.geoms.data["meta_reservoirs_no_control"].plot(ax=ax, zorder=4, **kwargs)
    patches.append(mpatches.Patch(**kwargs))
if "meta_reservoirs_simple_control" in model.geoms.data:
    kwargs = dict(facecolor="blue", edgecolor="black", linewidth=1, label="reservoirs (simple control)")
    model.geoms.data["meta_reservoirs_simple_control"].plot(ax=ax, zorder=4, **kwargs)
    patches.append(mpatches.Patch(**kwargs))
if "glaciers" in model.geoms.data:
    kwargs = dict(facecolor="grey", edgecolor="grey", linewidth=1, label="glaciers")
    model.geoms.data["glaciers"].plot(ax=ax, zorder=4, **kwargs)
    patches.append(mpatches.Patch(**kwargs))

ax.xaxis.set_visible(True)
ax.yaxis.set_visible(True)
ax.set_ylabel(f"latitude [degree north]")
ax.set_xlabel(f"longitude [degree east]")
_ = ax.set_title(f"wflow base map")
legend = ax.legend(
    handles=[*ax.get_legend_handles_labels()[0], *patches],
    title="Legend",
    loc="lower right",
    frameon=True,
    framealpha=0.7,
    edgecolor="k",
    facecolor="white",
)

# %%
# Create a figure with multiple subplots
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# Plot 1: Elevation
model.staticmaps.data['land_elevation'].plot(ax=axes[0, 0], cmap='terrain')
axes[0, 0].set_title('Digital Elevation Model', fontsize=12, fontweight='bold')
axes[0, 0].set_xlabel('Longitude')
axes[0, 0].set_ylabel('Latitude')

# Plot 2: River network
model.staticmaps.data['river_mask'].plot(ax=axes[0, 1], cmap='Blues')
axes[0, 1].set_title('River Network', fontsize=12, fontweight='bold')
axes[0, 1].set_xlabel('Longitude')
axes[0, 1].set_ylabel('Latitude')

# Plot 3: Land use
model.staticmaps.data['meta_landuse'].plot(ax=axes[1, 0], cmap='tab20')
axes[1, 0].set_title('Land Use Classification', fontsize=12, fontweight='bold')
axes[1, 0].set_xlabel('Longitude')
axes[1, 0].set_ylabel('Latitude')

# Plot 4: Land slope
model.staticmaps.data['vegetation_root_depth'].plot(ax=axes[1, 1], cmap='tab20')
axes[1, 1].set_title('Vegetation Rooting Depth', fontsize=12, fontweight='bold')
axes[1, 1].set_xlabel('Longitude')
axes[1, 1].set_ylabel('Latitude')

plt.tight_layout()
plt.show()

# %% [markdown]
# Now lets visualize the meteorological forcing and apply some simple statistics:

# %%
model.forcing.data.precip.isel(time=5).plot()

# %% [markdown]
# Calculate the average forcing accros the watershed:

# %%
ds_forcing = model.forcing.data
ds_forcing = ds_forcing.mean(dim=[ds_forcing.raster.x_dim, ds_forcing.raster.y_dim])

# plot axes labels
_ATTRS = {
    "precip": {
        "standard_name": "precipitation",
        "unit": "mm.day-1",
        "color": "darkblue",
    },
    "pet": {
        "standard_name": "potential evapotranspiration",
        "unit": "mm.day-1",
        "color": "purple",
    },
    "temp": {"standard_name": "temperature", "unit": "degree C", "color": "orange"},
}

n = len(ds_forcing.data_vars)
kwargs0 = dict(sharex=True, figsize=(6, n * 3))

fig, axes = plt.subplots(n, 1, **kwargs0)
axes = [axes] if n == 1 else axes
for i, name in enumerate(ds_forcing.data_vars):
    df = ds_forcing[name].squeeze().to_series()
    attrs = _ATTRS[name]
    longname = attrs.get("standard_name", "")
    unit = attrs.get("unit", "")
    if name == "precip":
        axes[i].bar(df.index, df.values, facecolor=attrs["color"])
    else:
        df.plot.line(ax=axes[i], x="time", color=attrs["color"])
    axes[i].set_title(longname)
    axes[i].set_ylabel(f"{longname}\n[{unit}]")

# %% [markdown]
# ---
#
# ## Part 5: Model Configuration and Settings
#
# ### 5.1 Understanding the TOML Configuration
#
# The `wflow_sbm.toml` file controls how the model runs. Let's examine key sections:

# %%
# Read and display the first 50 lines of the TOML configuration
# !head -n 50 ./wflow_models/first_wflow_model/wflow_sbm.toml
# Out:
# dir_output = "run_default"
#
# [time]
# calendar = "proleptic_gregorian"
# starttime = "2010-02-02T00:00:00"
# endtime = "2010-02-15T00:00:00"
# time_units = "days since 1900-01-01 00:00:00"
# timestepsecs = 86400
#
# [logging]
# loglevel = "info"
#
# [model]
# type = "sbm"
# snow_gravitational_transport__flag = true
# snow__flag = true
# cold_start__flag = true
# reservoir__flag = false
# glacier__flag = true
# kinematic_wave__adaptive_time_step_flag = false
# river_kinematic_wave__time_step = 900
# land_kinematic_wave__time_step = 3600
# river_routing = "kinematic_wave"
# soil_layer__thickness = [
#     100,
#     300,
#     800,
# ]
#
# [state]
# path_input = "instate/instates.nc"
# path_output = "outstate/outstates.nc"
#
# [state.variables]
# vegetation_canopy_water__depth = "vegetation_water_depth"
# soil_water_saturated_zone__depth = "soil_saturated_depth"
# soil_layer_water_unsaturated_zone__depth = "soil_unsaturated_depth"
# soil_surface__temperature = "soil_temp"
# snowpack_dry_snow__leq_depth = "snow_leq_depth"
# snowpack_liquid_water__depth = "snow_water_depth"
# land_surface_water__instantaneous_volume_flow_rate = "land_instantaneous_q"
# land_surface_water__depth = "land_h"
# subsurface_water__volume_flow_rate = "subsurface_q"
# river_water__instantaneous_volume_flow_rate = "river_instantaneous_q"
# river_water__depth = "river_h"
# glacier_ice__leq_depth = "glacier_leq_depth"
#
# [input]
# path_forcing = "inmaps-era5-2010.nc"
# path_static = "staticmaps.nc"

# %% [markdown]
# **Key configuration sections**:
#
# #### `[model]`
# Defines model type and core settings:
# ```toml
# [model]
# type = "sbm"
# masswasting = true
# snow = false
# reinit = true
# reservoirs = false
# lakes = false
# glacier = false
# ```
#
# #### `[state]`
# Specifies initial condition files:
# ```toml
# [state]
# path_input = "inmaps/instates.nc"
# path_output = "output/outstates.nc"
# ```
#
# #### `[input]`
# Points to static maps and forcing data:
# ```toml
# [input]
# path_forcing = "forcing/inmaps.nc"
# path_static = "staticmaps/staticmaps.nc"
# ```
#
# #### `[output]`
# Controls what variables to save and at what frequency:
# ```toml
# [output]
# path = "output/output.nc"
# ```

# %% [markdown]
# ### 5.2 Customizing Output Variables
#
# You can modify which variables are saved by editing the TOML file. Common output variables include:
#
# **Water balance components**:
# - `q_river`: River discharge [m³/s]
# - `q_land`: Lateral flow [mm/day]
# - `actevap`: Actual evapotranspiration [mm/day]
# - `snow`: Snow water equivalent [mm]
#
# **Storage variables**:
# - `ustorelayerdepth`: Unsaturated zone storage [mm]
# - `satwaterdepth`: Saturated zone storage [mm]
# - `canopystorage`: Canopy interception storage [mm]
#
# **Fluxes**:
# - `infiltration`: Infiltration rate [mm/day]
# - `recharge`: Groundwater recharge [mm/day]
# - `runoff`: Surface runoff [mm/day]

# %% [markdown]
# ---
#
# ## Part 6: Running the Model
#
# ### 6.1 Execute the Wflow Simulation
#
# Now that the model is built and configured, we can run the simulation. Wflow uses the Julia-based Wflow.jl backend for efficient computation.

# %%
# Install the model (once)
# !julia -e 'using Pkg; Pkg.add(url="https://github.com/Deltares/Wflow.jl", subdir="Wflow")'
# Out:
#     Updating git-repo `https://github.com/Deltares/Wflow.jl`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed libaec_jll ─────────────────────── v1.1.4+0
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.6
#    Installed Blosc_jll ──────────────────────── v1.21.7+0
#    Installed Adapt ──────────────────────────── v4.4.0
#    Installed LRUCache ───────────────────────── v1.6.2
#    Installed MPICH_jll ──────────────────────── v4.3.2+0
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed OffsetArrays ───────────────────── v1.17.0
#    Installed StrideArraysCore ───────────────── v0.5.8
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed XML2_jll ───────────────────────── v2.13.9+0
#    Installed libzip_jll ─────────────────────── v1.11.3+0
#    Installed Xorg_libpciaccess_jll ──────────── v0.18.1+0
#    Installed LayoutPointers ─────────────────── v0.1.17
#    Installed SciMLPublic ────────────────────── v1.0.0
#    Installed ArnoldiMethod ──────────────────── v0.4.0
#    Installed Preferences ────────────────────── v1.5.0
#    Installed Accessors ──────────────────────── v0.1.42
#    Installed Zstd_jll ───────────────────────── v1.5.7+1
#    Installed OpenSSL_jll ────────────────────── v3.5.4+0
#    Installed Inflate ────────────────────────── v0.1.5
#    Installed LoggingExtras ──────────────────── v1.2.0
#    Installed Hwloc_jll ──────────────────────── v2.12.2+0
#    Installed BasicModelInterface ────────────── v0.1.1
#    Installed Bzip2_jll ──────────────────────── v1.0.9+0
#    Installed ProgressLogging ────────────────── v0.1.6
#    Installed XZ_jll ─────────────────────────── v5.8.1+0
#    Installed CPUSummary ─────────────────────── v0.2.7
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed MicrosoftMPI_jll ───────────────── v10.1.4+3
#    Installed StaticArrays ───────────────────── v1.9.15
#    Installed JLLWrappers ────────────────────── v1.7.1
#    Installed Polyester ──────────────────────── v0.7.18
#    Installed Libiconv_jll ───────────────────── v1.18.0+0
#    Installed StaticArraysCore ───────────────── v1.4.4
#    Installed ConstructionBase ───────────────── v1.6.0
#    Installed PrecompileTools ────────────────── v1.2.1
#    Installed OpenMPI_jll ────────────────────── v5.0.9+0
#    Installed AbstractTrees ──────────────────── v0.4.5
#    Installed OrderedCollections ─────────────── v1.8.1
#    Installed Graphs ─────────────────────────── v1.13.1
#    Installed EnumX ──────────────────────────── v1.0.5
#    Installed ThreadingUtilities ─────────────── v0.5.5
#    Installed DelimitedFiles ─────────────────── v1.9.1
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed NCDatasets ─────────────────────── v0.14.10
#    Installed PolyesterWeave ─────────────────── v0.2.2
#    Installed ArrayInterface ─────────────────── v7.22.0
#    Installed FillArrays ─────────────────────── v1.15.0
#    Installed MPIPreferences ─────────────────── v0.1.11
#    Installed TerminalLoggers ────────────────── v0.1.7
#    Installed Lz4_jll ────────────────────────── v1.10.1+0
#    Installed MPItrampoline_jll ──────────────── v5.5.4+0
#    Installed Requires ───────────────────────── v1.3.1
#    Installed Statistics ─────────────────────── v1.11.1
#    Installed CommonDataModel ────────────────── v0.4.1
#    Installed DataStructures ─────────────────── v0.19.3
#    Installed CloseOpenIntervals ─────────────── v0.1.13
#    Installed MacroTools ─────────────────────── v0.5.16
#    Installed CFTime ─────────────────────────── v0.2.4
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed CommonWorldInvalidations ───────── v1.0.0
#    Installed CompositionsBase ───────────────── v0.1.2
#    Installed Compat ─────────────────────────── v4.18.1
#    Installed Static ─────────────────────────── v1.3.1
#    Installed LeftChildRightSiblingTrees ─────── v0.2.1
#    Installed Parameters ─────────────────────── v0.12.3
#    Installed NetCDF_jll ─────────────────────── v401.900.300+0
#    Installed Glob ───────────────────────────── v1.3.1
#    Installed InverseFunctions ───────────────── v0.1.17
#    Installed StaticArrayInterface ───────────── v1.8.0
#    Installed SimpleTraits ───────────────────── v0.9.5
#    Installed HDF5_jll ───────────────────────── v1.14.6+0
#    Installed DiskArrays ─────────────────────── v0.4.18
#    Installed PropertyDicts ──────────────────── v0.2.1
#  Downloading artifact: Blosc]  75/75
#   Downloaded artifact: Blosc                  ]  0.0 %
#  Downloading artifact: MPICH
#   Downloaded artifact: MPICH            ]  5.2 % 0.0 %
#  Downloading artifact: libaec
#   Downloaded artifact: libaec================>]  100.0 %
#  Downloading artifact: libzip
#   Downloaded artifact: libzip================>]  98.7 %
#  Downloading artifact: XML2
#   Downloaded artifact: XML2             ]  7.0 % 0.0 %
#  Downloading artifact: Xorg_libpciaccess
#   Downloaded artifact: Xorg_libpciaccess=====>]  100.0 %
#  Downloading artifact: Zstd
#   Downloaded artifact: Zstd                   ]  27.1 %
#  Downloading artifact: OpenSSL
#   Downloaded artifact: OpenSSL                ]  4.6 %
#  Downloading artifact: Hwloc
#   Downloaded artifact: Hwloc            ]  4.9 % 0.0 %
#  Downloading artifact: Bzip2
#   Downloaded artifact: Bzip2                  ]  0.0 %
#  Downloading artifact: XZ
#   Downloaded artifact: XZ                     ]  11.4 %
#  Downloading artifact: Libiconv
#   Downloaded artifact: Libiconv               ]  9.0 %
#  Downloading artifact: Lz4
#   Downloaded artifact: Lz4=========>          ]  73.2 %
#  Downloading artifact: NetCDF
#   Downloaded artifact: NetCDF                 ]  18.7 %
#  Downloading artifact: HDF5
#   Downloaded artifact: HDF5                   ]  3.0 %
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [d48b7d99] + Wflow v1.0.0-dev `https://github.com/Deltares/Wflow.jl:Wflow#master`
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [1520ce14] + AbstractTrees v0.4.5
#   [7d9f7c33] + Accessors v0.1.42
#   [79e6a3ab] + Adapt v4.4.0
#   [ec485272] + ArnoldiMethod v0.4.0
#   [4fba245c] + ArrayInterface v7.22.0
#   [59605e27] + BasicModelInterface v0.1.1
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.6
#   [179af706] + CFTime v0.2.4
#   [2a0fbf3d] + CPUSummary v0.2.7
#   [fb6a15b2] + CloseOpenIntervals v0.1.13
#   [1fbeeb36] + CommonDataModel v0.4.1
#   [f70d9fcc] + CommonWorldInvalidations v1.0.0
#   [34da2185] + Compat v4.18.1
#   [a33af91c] + CompositionsBase v0.1.2
#   [187b0558] + ConstructionBase v1.6.0
#   [adafc99b] + CpuId v0.3.1
#   [864edb3b] + DataStructures v0.19.3
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [3c3547ce] + DiskArrays v0.4.18
#   [4e289a0a] + EnumX v1.0.5
#   [1a297f60] + FillArrays v1.15.0
#   [c27321d9] + Glob v1.3.1
#   [86223c79] + Graphs v1.13.1
#   [615f187c] + IfElse v0.1.1
#   [d25df0c9] + Inflate v0.1.5
#   [3587e190] + InverseFunctions v0.1.17
#   [692b3bcd] + JLLWrappers v1.7.1
#   [8ac3fa9e] + LRUCache v1.6.2
#   [10f19ff3] + LayoutPointers v0.1.17
#   [1d6d02ad] + LeftChildRightSiblingTrees v0.2.1
#   [e6f89c97] + LoggingExtras v1.2.0
#   [3da0fdf6] + MPIPreferences v0.1.11
#   [1914dd2f] + MacroTools v0.5.16
#   [d125e4d3] + ManualMemory v0.1.8
#   [85f8d34a] + NCDatasets v0.14.10
#   [6fe1bfb0] + OffsetArrays v1.17.0
#   [bac558e1] + OrderedCollections v1.8.1
#   [d96e819e] + Parameters v0.12.3
#   [f517fe37] + Polyester v0.7.18
#   [1d0040c9] + PolyesterWeave v0.2.2
# ⌅ [aea7be01] + PrecompileTools v1.2.1
#   [21216c6a] + Preferences v1.5.0
#   [33c8b6b6] + ProgressLogging v0.1.6
#   [f8a19df8] + PropertyDicts v0.2.1
#   [ae029012] + Requires v1.3.1
#   [94e857df] + SIMDTypes v0.1.0
#   [431bcebd] + SciMLPublic v1.0.0
#   [699a6c99] + SimpleTraits v0.9.5
#   [aedffcd0] + Static v1.3.1
#   [0d7ed370] + StaticArrayInterface v1.8.0
#   [90137ffa] + StaticArrays v1.9.15
#   [1e83bf80] + StaticArraysCore v1.4.4
#   [10745b16] + Statistics v1.11.1
#   [7792a7ef] + StrideArraysCore v0.5.8
#   [5d786b92] + TerminalLoggers v0.1.7
#   [8290d209] + ThreadingUtilities v0.5.5
#   [3a884ed6] + UnPack v1.0.2
#   [d48b7d99] + Wflow v1.0.0-dev `https://github.com/Deltares/Wflow.jl:Wflow#master`
#   [0b7ba130] + Blosc_jll v1.21.7+0
#   [6e34b625] + Bzip2_jll v1.0.9+0
#   [0234f1f7] + HDF5_jll v1.14.6+0
#   [e33a78d0] + Hwloc_jll v2.12.2+0
#   [94ce4f54] + Libiconv_jll v1.18.0+0
#   [5ced341a] + Lz4_jll v1.10.1+0
#   [7cb0a576] + MPICH_jll v4.3.2+0
#   [f1f71cc9] + MPItrampoline_jll v5.5.4+0
#   [9237b28f] + MicrosoftMPI_jll v10.1.4+3
#   [7243133f] + NetCDF_jll v401.900.300+0
#   [fe0851c0] + OpenMPI_jll v5.0.9+0
#   [458c3c95] + OpenSSL_jll v3.5.4+0
# ⌅ [02c8fc9c] + XML2_jll v2.13.9+0
#   [ffd25f8a] + XZ_jll v5.8.1+0
#   [a65dc6b1] + Xorg_libpciaccess_jll v0.18.1+0
#   [3161d3a3] + Zstd_jll v1.5.7+1
#   [477f73a3] + libaec_jll v1.1.4+0
#   [337d8026] + libzip_jll v1.11.3+0
#   [0dad84c5] + ArgTools v1.1.2
#   [56f22d72] + Artifacts v1.11.0
#   [2a0f44e3] + Base64 v1.11.0
#   [ade2ca70] + Dates v1.11.0
#   [8ba89e20] + Distributed v1.11.0
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching v1.11.0
#   [b77e0a4c] + InteractiveUtils v1.11.0
#   [4af54fe1] + LazyArtifacts v1.11.0
#   [b27032c2] + LibCURL v0.6.4
#   [76f85450] + LibGit2 v1.11.0
#   [8f399da3] + Libdl v1.11.0
#   [37e2e46d] + LinearAlgebra v1.11.0
#   [56ddb016] + Logging v1.11.0
#   [d6f4376e] + Markdown v1.11.0
#   [a63ad114] + Mmap v1.11.0
#   [ca575930] + NetworkOptions v1.2.0
#   [44cfe95a] + Pkg v1.11.0
#   [de0858da] + Printf v1.11.0
#   [9a3f8284] + Random v1.11.0
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization v1.11.0
#   [1a1011a3] + SharedArrays v1.11.0
#   [6462fe0b] + Sockets v1.11.0
#   [2f01184e] + SparseArrays v1.11.0
#   [fa267f1f] + TOML v1.0.3
#   [a4e569a6] + Tar v1.10.0
#   [cf7118a7] + UUIDs v1.11.0
#   [4ec0a83e] + Unicode v1.11.0
#   [e66e0078] + CompilerSupportLibraries_jll v1.1.1+0
#   [deac9b47] + LibCURL_jll v8.6.0+0
#   [e37daf67] + LibGit2_jll v1.7.2+0
#   [29816b5a] + LibSSH2_jll v1.11.0+1
#   [c8ffd9c3] + MbedTLS_jll v2.28.6+0
#   [14a3606d] + MozillaCACerts_jll v2023.12.12
#   [4536629a] + OpenBLAS_jll v0.3.27+1
#   [bea87d4a] + SuiteSparse_jll v7.7.0+0
#   [83775a58] + Zlib_jll v1.2.13+1
#   [8e850b90] + libblastrampoline_jll v5.11.0+0
#   [8e850ede] + nghttp2_jll v1.59.0+0
#   [3f19e933] + p7zip_jll v17.4.0+2
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   Progress [>                                        ]  0/95
#   ◓ PropertyDicts
#   ◐ OrderedCollections
#   ◑ UnPack
#   ◒ FillArrays
#   ◑ EnumX
#   ◑ InverseFunctions
#   ◓ LRUCache
#   ◐ SIMDTypes
#   ◑ Inflate
#
#   ◑ PropertyDicts
#   ◓ OrderedCollections
#   ◒ UnPack
#   ◐ FillArrays
#   ◒ EnumX
#   ◒ InverseFunctions
#   ◑ LRUCache
#   ◓ SIMDTypes
#   ◒ Inflate
#   Progress [>                                        ]  0/95
#   ◒ PropertyDicts
#   ◑ OrderedCollections
#   ◐ UnPack
#   ◓ FillArrays
#   ◐ EnumX
#   ◐ InverseFunctions
#   ◒ LRUCache
#   ◑ SIMDTypes
#   ◐ Inflate
#   Progress [>                                        ]  0/95
#   ◐ PropertyDicts
#   ◒ OrderedCollections
#   ◓ UnPack
#   ◑ FillArrays
#   ◓ EnumX
#   ◓ InverseFunctions
#   ◐ LRUCache
#   ◒ SIMDTypes
#   ◓ Inflate
#   Progress [>                                        ]  0/95
#   ◓ PropertyDicts
#   ◐ OrderedCollections
#   ◑ UnPack
#   ◒ FillArrays
#   ◑ EnumX
#   ◑ InverseFunctions
#   ◓ LRUCache
#   ◐ SIMDTypes
#   ◑ Inflate
#   Progress [>                                        ]  0/95
#   ◑ PropertyDicts
#   ◓ OrderedCollections
#   ◒ UnPack
#   ◐ FillArrays
#   ◒ EnumX
#   ◒ InverseFunctions
#   ◑ LRUCache
#   ◓ SIMDTypes
#   ◒ Inflate
#   Progress [=>                                       ]  2/95
#   ◒ PropertyDicts
#   ◑ OrderedCollections
#   ✓ UnPack
#   ◓ FillArrays
#   ✓ EnumX
#   ◐ InverseFunctions
#   ◒ LRUCache
#   ◑ SIMDTypes
#   ◐ Inflate
#   ◐ AbstractTrees
#   ◑ Glob
#   Progress [==>                                      ]  3/95
#   ✓ PropertyDicts
#   ◒ OrderedCollections
#   ✓ UnPack
#   ◑ FillArrays
#   ✓ EnumX
#   ◓ InverseFunctions
#   ◐ LRUCache
#   ◒ SIMDTypes
#   ◓ Inflate
#   ◓ AbstractTrees
#   ◒ Glob
#   ◒ Statistics
#   Progress [===>                                     ]  5/95
#   ✓ PropertyDicts
#   ◐ OrderedCollections
#   ✓ UnPack
#   ◒ FillArrays
#   ✓ EnumX
#   ✓ InverseFunctions
#   ◓ LRUCache
#   ✓ SIMDTypes
#   ◑ Inflate
#   ◑ AbstractTrees
#   ◐ Glob
#   ◐ Statistics
#   ◑ IfElse
#   ◐ ConstructionBase
#   Progress [===>                                     ]  5/95
#   ✓ PropertyDicts
#   ◓ OrderedCollections
#   ✓ UnPack
#   ◐ FillArrays
#   ✓ EnumX
#   ✓ InverseFunctions
#   ◑ LRUCache
#   ✓ SIMDTypes
#   ◒ Inflate
#   ◒ AbstractTrees
#   ◓ Glob
#   ◓ Statistics
#   ◒ IfElse
#   ◓ ConstructionBase
#   Progress [===>                                     ]  7/95
#   ✓ PropertyDicts
#   ✓ OrderedCollections
#   ✓ UnPack
#   ◓ FillArrays
#   ✓ EnumX
#   ✓ InverseFunctions
#   ✓ LRUCache
#   ✓ SIMDTypes
#   ◐ Inflate
#   ◐ AbstractTrees
#   ◑ Glob
#   ◑ Statistics
#   ◐ IfElse
#   ◑ ConstructionBase
#   ◑ CommonWorldInvalidations
#   ◒ ProgressLogging
#   Progress [====>                                    ]  8/95
#   ✓ PropertyDicts
#   ✓ OrderedCollections
#   ✓ UnPack
#   ◑ FillArrays
#   ✓ EnumX
#   ✓ InverseFunctions
#   ✓ LRUCache
#   ✓ SIMDTypes
#   ✓ Inflate
#   ◓ AbstractTrees
#   ◒ Glob
#   ◒ Statistics
#   ◓ IfElse
#   ◒ ConstructionBase
#   ◒ CommonWorldInvalidations
#   ◐ ProgressLogging
#   ◓ MacroTools
#   Progress [====>                                    ]  8/95
#   ✓ PropertyDicts
#   ✓ OrderedCollections
#   ✓ UnPack
#   ◒ FillArrays
#   ✓ EnumX
#   ✓ InverseFunctions
#   ✓ LRUCache
#   ✓ SIMDTypes
#   ✓ Inflate
#   ◑ AbstractTrees
#   ◐ Glob
#   ◐ Statistics
#   ◑ IfElse
#   ◐ ConstructionBase
#   ◐ CommonWorldInvalidations
#   ◓ ProgressLogging
#   ◑ MacroTools
#   Progress [====>                                    ]  9/95
#   ✓ PropertyDicts
#   ✓ OrderedCollections
#   ✓ UnPack
#   ◐ FillArrays
#   ✓ EnumX
#   ✓ InverseFunctions
#   ✓ LRUCache
#   ✓ SIMDTypes
#   ✓ Inflate
#   ◒ AbstractTrees
#   ✓ Glob
#   ◓ Statistics
#   ◒ IfElse
#   ◓ ConstructionBase
#   ◓ CommonWorldInvalidations
#   ◑ ProgressLogging
#   ◒ MacroTools
#   ◓ CompositionsBase
#   Progress [=====>                                   ]  10/95
#   ✓ PropertyDicts
#   ✓ OrderedCollections
#   ✓ UnPack
#   ◓ FillArrays
#   ✓ EnumX
#   ✓ InverseFunctions
#   ✓ LRUCache
#   ✓ SIMDTypes
#   ✓ Inflate
#   ◐ AbstractTrees
#   ✓ Glob
#   ◑ Statistics
#   ✓ IfElse
#   ◑ ConstructionBase
#   ◑ CommonWorldInvalidations
#   ◒ ProgressLogging
#   ◐ MacroTools
#   ◑ CompositionsBase
#   ◓ BasicModelInterface
#   Progress [=====>                                   ]  11/95
#   ✓ PropertyDicts
#   ✓ OrderedCollections
#   ✓ UnPack
#   ◑ FillArrays
#   ✓ EnumX
#   ✓ InverseFunctions
#   ✓ LRUCache
#   ✓ SIMDTypes
#   ✓ Inflate
#   ✓ AbstractTrees
#   ✓ Glob
#   ◒ Statistics
#   ✓ IfElse
#   ◒ ConstructionBase
#   ◒ CommonWorldInvalidations
#   ◐ ProgressLogging
#   ◓ MacroTools
#   ◒ CompositionsBase
#   ◑ BasicModelInterface
#   ◒ SciMLPublic
#   Progress [======>                                  ]  13/95
#   ✓ PropertyDicts
#   ✓ OrderedCollections
#   ◒ FillArrays
#   ✓ InverseFunctions
#   ✓ LRUCache
#   ✓ SIMDTypes
#   ✓ Inflate
#   ✓ AbstractTrees
#   ✓ Glob
#   ◐ Statistics
#   ✓ IfElse
#   ✓ ConstructionBase
#   ✓ CommonWorldInvalidations
#   ◓ ProgressLogging
#   ◑ MacroTools
#   ◐ CompositionsBase
#   ◒ BasicModelInterface
#   ◐ SciMLPublic
#   ◐ StaticArraysCore
#   ◐ OffsetArrays
#   Progress [======>                                  ]  14/95
#   ✓ OrderedCollections
#   ✓ FillArrays
#   ✓ InverseFunctions
#   ✓ LRUCache
#   ✓ SIMDTypes
#   ✓ Inflate
#   ✓ AbstractTrees
#   ✓ Glob
#   ◓ Statistics
#   ✓ IfElse
#   ✓ ConstructionBase
#   ✓ CommonWorldInvalidations
#   ◑ ProgressLogging
#   ◒ MacroTools
#   ◓ CompositionsBase
#   ◐ BasicModelInterface
#   ◓ SciMLPublic
#   ◓ StaticArraysCore
#   ◓ OffsetArrays
#   ◒ ManualMemory
#   Progress [=======>                                 ]  16/95
#   ✓ OrderedCollections
#   ✓ FillArrays
#   ✓ LRUCache
#   ✓ Inflate
#   ✓ AbstractTrees
#   ✓ Glob
#   ✓ Statistics
#   ✓ IfElse
#   ✓ ConstructionBase
#   ✓ CommonWorldInvalidations
#   ✓ ProgressLogging
#   ◐ MacroTools
#   ◑ CompositionsBase
#   ◓ BasicModelInterface
#   ◑ SciMLPublic
#   ◑ StaticArraysCore
#   ◑ OffsetArrays
#   ◐ ManualMemory
#   ◓ Requires
#   ◑ CpuId
#   Progress [========>                                ]  17/95
#   ✓ OrderedCollections
#   ✓ FillArrays
#   ✓ LRUCache
#   ✓ Inflate
#   ✓ AbstractTrees
#   ✓ Glob
#   ✓ Statistics
#   ✓ IfElse
#   ✓ ConstructionBase
#   ✓ CommonWorldInvalidations
#   ✓ ProgressLogging
#   ◓ MacroTools
#   ✓ CompositionsBase
#   ◑ BasicModelInterface
#   ◒ SciMLPublic
#   ◒ StaticArraysCore
#   ◒ OffsetArrays
#   ◓ ManualMemory
#   ◑ Requires
#   ◒ CpuId
#   ◐ DelimitedFiles
#   Progress [========>                                ]  17/95
#   ✓ FillArrays
#   ✓ Inflate
#   ✓ AbstractTrees
#   ✓ Glob
#   ✓ Statistics
#   ✓ IfElse
#   ✓ ConstructionBase
#   ✓ CommonWorldInvalidations
#   ✓ ProgressLogging
#   ◑ MacroTools
#   ✓ CompositionsBase
#   ◒ BasicModelInterface
#   ◐ SciMLPublic
#   ◐ StaticArraysCore
#   ◐ OffsetArrays
#   ◑ ManualMemory
#   ◒ Requires
#   ◐ CpuId
#   ◓ DelimitedFiles
#   Progress [========>                                ]  18/95
#   ✓ FillArrays
#   ✓ AbstractTrees
#   ✓ Glob
#   ✓ Statistics
#   ✓ IfElse
#   ✓ ConstructionBase
#   ✓ CommonWorldInvalidations
#   ✓ ProgressLogging
#   ◒ MacroTools
#   ✓ CompositionsBase
#   ✓ BasicModelInterface
#   ◓ SciMLPublic
#   ◓ StaticArraysCore
#   ◓ OffsetArrays
#   ◒ ManualMemory
#   ◐ Requires
#   ◓ CpuId
#   ◑ DelimitedFiles
#   ◓ CFTime
#   Progress [========>                                ]  18/95
#   ✓ FillArrays
#   ✓ AbstractTrees
#   ✓ Glob
#   ✓ Statistics
#   ✓ IfElse
#   ✓ ConstructionBase
#   ✓ CommonWorldInvalidations
#   ✓ ProgressLogging
#   ◐ MacroTools
#   ✓ CompositionsBase
#   ✓ BasicModelInterface
#   ◑ SciMLPublic
#   ◑ StaticArraysCore
#   ◑ OffsetArrays
#   ◐ ManualMemory
#   ◓ Requires
#   ◑ CpuId
#   ◒ DelimitedFiles
#   ◑ CFTime
#   Progress [=========>                               ]  20/95
#   ✓ FillArrays
#   ✓ AbstractTrees
#   ✓ Statistics
#   ✓ IfElse
#   ✓ ConstructionBase
#   ✓ CommonWorldInvalidations
#   ✓ ProgressLogging
#   ◓ MacroTools
#   ✓ CompositionsBase
#   ✓ BasicModelInterface
#   ✓ SciMLPublic
#   ◒ StaticArraysCore
#   ◒ OffsetArrays
#   ✓ ManualMemory
#   ◑ Requires
#   ◒ CpuId
#   ◐ DelimitedFiles
#   ◒ CFTime
#   ◐ LoggingExtras
#   ◒ Compat
#   Progress [=========>                               ]  21/95
#   ✓ FillArrays
#   ✓ AbstractTrees
#   ✓ Statistics
#   ✓ ConstructionBase
#   ✓ CommonWorldInvalidations
#   ✓ ProgressLogging
#   ◑ MacroTools
#   ✓ CompositionsBase
#   ✓ BasicModelInterface
#   ✓ SciMLPublic
#   ✓ StaticArraysCore
#   ◐ OffsetArrays
#   ✓ ManualMemory
#   ◒ Requires
#   ◐ CpuId
#   ◓ DelimitedFiles
#   ◐ CFTime
#   ◓ LoggingExtras
#   ◐ Compat
#   ◓ Preferences
#   Progress [=========>                               ]  21/95
#   ✓ FillArrays
#   ✓ Statistics
#   ✓ ConstructionBase
#   ✓ CommonWorldInvalidations
#   ✓ ProgressLogging
#   ◒ MacroTools
#   ✓ CompositionsBase
#   ✓ BasicModelInterface
#   ✓ SciMLPublic
#   ✓ StaticArraysCore
#   ◓ OffsetArrays
#   ✓ ManualMemory
#   ◐ Requires
#   ◓ CpuId
#   ◑ DelimitedFiles
#   ◓ CFTime
#   ◑ LoggingExtras
#   ◓ Compat
#   ◑ Preferences
#   Progress [=========>                               ]  21/95
#   ✓ FillArrays
#   ✓ Statistics
#   ✓ ProgressLogging
#   ◐ MacroTools
#   ✓ CompositionsBase
#   ✓ BasicModelInterface
#   ✓ SciMLPublic
#   ✓ StaticArraysCore
#   ◑ OffsetArrays
#   ✓ ManualMemory
#   ◓ Requires
#   ◑ CpuId
#   ◒ DelimitedFiles
#   ◑ CFTime
#   ◒ LoggingExtras
#   ◑ Compat
#   ◒ Preferences
#   Progress [=========>                               ]  21/95
#   ✓ FillArrays
#   ✓ Statistics
#   ✓ ProgressLogging
#   ◓ MacroTools
#   ✓ CompositionsBase
#   ✓ BasicModelInterface
#   ✓ SciMLPublic
#   ✓ StaticArraysCore
#   ◒ OffsetArrays
#   ✓ ManualMemory
#   ◑ Requires
#   ◒ CpuId
#   ◐ DelimitedFiles
#   ◒ CFTime
#   ◐ LoggingExtras
#   ◒ Compat
#   ◐ Preferences
#   Progress [==========>                              ]  22/95
#   ✓ Statistics
#   ✓ ProgressLogging
#   ◑ MacroTools
#   ✓ CompositionsBase
#   ✓ BasicModelInterface
#   ✓ SciMLPublic
#   ✓ StaticArraysCore
#   ◐ OffsetArrays
#   ✓ ManualMemory
#   ◒ Requires
#   ◐ CpuId
#   ✓ DelimitedFiles
#   ◐ CFTime
#   ◓ LoggingExtras
#   ◐ Compat
#   ◓ Preferences
#   ◑ InverseFunctions → InverseFunctionsDatesExt
#   Progress [===========>                             ]  24/95
#   ◒ MacroTools
#   ✓ BasicModelInterface
#   ✓ SciMLPublic
#   ✓ StaticArraysCore
#   ◓ OffsetArrays
#   ✓ ManualMemory
#   ✓ Requires
#   ✓ CpuId
#   ✓ DelimitedFiles
#   ◓ CFTime
#   ◑ LoggingExtras
#   ◓ Compat
#   ◑ Preferences
#   ◒ InverseFunctions → InverseFunctionsDatesExt
#   ◓ LRUCache → SerializationExt
#   ◑ DataStructures
#   Progress [===========>                             ]  25/95
#   ◐ MacroTools
#   ✓ SciMLPublic
#   ✓ StaticArraysCore
#   ◑ OffsetArrays
#   ✓ ManualMemory
#   ✓ Requires
#   ✓ CpuId
#   ✓ DelimitedFiles
#   ◑ CFTime
#   ✓ LoggingExtras
#   ◑ Compat
#   ◒ Preferences
#   ◐ InverseFunctions → InverseFunctionsDatesExt
#   ◑ LRUCache → SerializationExt
#   ◒ DataStructures
#   ◒ Parameters
#   Progress [===========>                             ]  25/95
#   ◓ MacroTools
#   ✓ SciMLPublic
#   ✓ StaticArraysCore
#   ◒ OffsetArrays
#   ✓ ManualMemory
#   ✓ Requires
#   ✓ CpuId
#   ✓ DelimitedFiles
#   ◒ CFTime
#   ✓ LoggingExtras
#   ◒ Compat
#   ◐ Preferences
#   ◓ InverseFunctions → InverseFunctionsDatesExt
#   ◒ LRUCache → SerializationExt
#   ◐ DataStructures
#   ◐ Parameters
#   Progress [===========>                             ]  25/95
#   ◑ MacroTools
#   ✓ StaticArraysCore
#   ◐ OffsetArrays
#   ✓ Requires
#   ✓ CpuId
#   ✓ DelimitedFiles
#   ◐ CFTime
#   ✓ LoggingExtras
#   ◐ Compat
#   ◓ Preferences
#   ◑ InverseFunctions → InverseFunctionsDatesExt
#   ◐ LRUCache → SerializationExt
#   ◓ DataStructures
#   ◓ Parameters
#   Progress [============>                            ]  27/95
#   ◒ MacroTools
#   ✓ OffsetArrays
#   ✓ Requires
#   ✓ CpuId
#   ✓ DelimitedFiles
#   ◓ CFTime
#   ✓ LoggingExtras
#   ✓ Compat
#   ◑ Preferences
#   ◒ InverseFunctions → InverseFunctionsDatesExt
#   ◓ LRUCache → SerializationExt
#   ◑ DataStructures
#   ◑ Parameters
#   ◑ LeftChildRightSiblingTrees
#   ◓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   Progress [============>                            ]  27/95
#   ◐ MacroTools
#   ✓ OffsetArrays
#   ✓ Requires
#   ✓ CpuId
#   ✓ DelimitedFiles
#   ◑ CFTime
#   ✓ LoggingExtras
#   ✓ Compat
#   ◒ Preferences
#   ◐ InverseFunctions → InverseFunctionsDatesExt
#   ◑ LRUCache → SerializationExt
#   ◒ DataStructures
#   ◒ Parameters
#   ◒ LeftChildRightSiblingTrees
#   ◑ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   Progress [============>                            ]  27/95
#   ◓ MacroTools
#   ✓ OffsetArrays
#   ✓ Requires
#   ✓ CpuId
#   ✓ DelimitedFiles
#   ◒ CFTime
#   ✓ LoggingExtras
#   ✓ Compat
#   ◐ Preferences
#   ◓ InverseFunctions → InverseFunctionsDatesExt
#   ◒ LRUCache → SerializationExt
#   ◐ DataStructures
#   ◐ Parameters
#   ◐ LeftChildRightSiblingTrees
#   ◒ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   Progress [============>                            ]  27/95
#   ◑ MacroTools
#   ✓ OffsetArrays
#   ✓ Requires
#   ✓ CpuId
#   ✓ DelimitedFiles
#   ◐ CFTime
#   ✓ LoggingExtras
#   ✓ Compat
#   ◓ Preferences
#   ◑ InverseFunctions → InverseFunctionsDatesExt
#   ◐ LRUCache → SerializationExt
#   ◓ DataStructures
#   ◓ Parameters
#   ◓ LeftChildRightSiblingTrees
#   ◐ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   Progress [============>                            ]  28/95
#   ◒ MacroTools
#   ✓ OffsetArrays
#   ✓ Requires
#   ✓ CpuId
#   ✓ DelimitedFiles
#   ◓ CFTime
#   ✓ LoggingExtras
#   ✓ Compat
#   ◑ Preferences
#   ◒ InverseFunctions → InverseFunctionsDatesExt
#   ✓ LRUCache → SerializationExt
#   ◑ DataStructures
#   ◑ Parameters
#   ◑ LeftChildRightSiblingTrees
#   ◓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ◐ FillArrays → FillArraysSparseArraysExt
#   Progress [==============>                          ]  31/95
#   ◐ MacroTools
#   ✓ OffsetArrays
#   ✓ Requires
#   ✓ CpuId
#   ◑ CFTime
#   ✓ LoggingExtras
#   ✓ Compat
#   ✓ Preferences
#   ✓ InverseFunctions → InverseFunctionsDatesExt
#   ✓ LRUCache → SerializationExt
#   ◒ DataStructures
#   ✓ Parameters
#   ◒ LeftChildRightSiblingTrees
#   ◑ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ◓ FillArrays → FillArraysSparseArraysExt
#   ◑ Statistics → SparseArraysExt
#   ◓ FillArrays → FillArraysStatisticsExt
#   ◑ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   Progress [==============>                          ]  32/95
#   ◓ MacroTools
#   ✓ OffsetArrays
#   ✓ CFTime
#   ✓ LoggingExtras
#   ✓ Compat
#   ✓ Preferences
#   ✓ InverseFunctions → InverseFunctionsDatesExt
#   ✓ LRUCache → SerializationExt
#   ◐ DataStructures
#   ✓ Parameters
#   ◐ LeftChildRightSiblingTrees
#   ◒ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ◑ FillArrays → FillArraysSparseArraysExt
#   ◒ Statistics → SparseArraysExt
#   ◑ FillArrays → FillArraysStatisticsExt
#   ◒ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◐ ThreadingUtilities
#   Progress [==============>                          ]  32/95
#   ◑ MacroTools
#   ✓ OffsetArrays
#   ✓ CFTime
#   ✓ Compat
#   ✓ Preferences
#   ✓ InverseFunctions → InverseFunctionsDatesExt
#   ✓ LRUCache → SerializationExt
#   ◓ DataStructures
#   ✓ Parameters
#   ◓ LeftChildRightSiblingTrees
#   ◐ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ◒ FillArrays → FillArraysSparseArraysExt
#   ◐ Statistics → SparseArraysExt
#   ◒ FillArrays → FillArraysStatisticsExt
#   ◐ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◓ ThreadingUtilities
#   Progress [==============>                          ]  33/95
#   ◒ MacroTools
#   ✓ OffsetArrays
#   ✓ CFTime
#   ✓ Compat
#   ✓ Preferences
#   ✓ InverseFunctions → InverseFunctionsDatesExt
#   ✓ LRUCache → SerializationExt
#   ◑ DataStructures
#   ✓ Parameters
#   ✓ LeftChildRightSiblingTrees
#   ◓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ◐ FillArrays → FillArraysSparseArraysExt
#   ◓ Statistics → SparseArraysExt
#   ◐ FillArrays → FillArraysStatisticsExt
#   ◓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◑ ThreadingUtilities
#   ◒ Adapt
#   Progress [===============>                         ]  34/95
#   ◐ MacroTools
#   ✓ OffsetArrays
#   ✓ CFTime
#   ✓ Compat
#   ✓ Preferences
#   ✓ InverseFunctions → InverseFunctionsDatesExt
#   ✓ LRUCache → SerializationExt
#   ◒ DataStructures
#   ✓ Parameters
#   ✓ LeftChildRightSiblingTrees
#   ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ◓ FillArrays → FillArraysSparseArraysExt
#   ◑ Statistics → SparseArraysExt
#   ◓ FillArrays → FillArraysStatisticsExt
#   ◑ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◒ ThreadingUtilities
#   ◐ Adapt
#   ◑ Compat → CompatLinearAlgebraExt
#   Progress [===============>                         ]  34/95
#   ◓ MacroTools
#   ✓ CFTime
#   ✓ Preferences
#   ✓ InverseFunctions → InverseFunctionsDatesExt
#   ✓ LRUCache → SerializationExt
#   ◐ DataStructures
#   ✓ Parameters
#   ✓ LeftChildRightSiblingTrees
#   ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ◑ FillArrays → FillArraysSparseArraysExt
#   ◒ Statistics → SparseArraysExt
#   ◑ FillArrays → FillArraysStatisticsExt
#   ◒ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◐ ThreadingUtilities
#   ◓ Adapt
#   ◒ Compat → CompatLinearAlgebraExt
#   Progress [===============>                         ]  34/95
#   ◑ MacroTools
#   ✓ CFTime
#   ✓ Preferences
#   ✓ InverseFunctions → InverseFunctionsDatesExt
#   ✓ LRUCache → SerializationExt
#   ◓ DataStructures
#   ✓ Parameters
#   ✓ LeftChildRightSiblingTrees
#   ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ◒ FillArrays → FillArraysSparseArraysExt
#   ◐ Statistics → SparseArraysExt
#   ◒ FillArrays → FillArraysStatisticsExt
#   ◐ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◓ ThreadingUtilities
#   ◑ Adapt
#   ◐ Compat → CompatLinearAlgebraExt
#   Progress [===============>                         ]  34/95
#   ◒ MacroTools
#   ✓ CFTime
#   ✓ Preferences
#   ✓ InverseFunctions → InverseFunctionsDatesExt
#   ✓ LRUCache → SerializationExt
#   ◑ DataStructures
#   ✓ Parameters
#   ✓ LeftChildRightSiblingTrees
#   ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ◐ FillArrays → FillArraysSparseArraysExt
#   ◓ Statistics → SparseArraysExt
#   ◐ FillArrays → FillArraysStatisticsExt
#   ◓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◑ ThreadingUtilities
#   ◒ Adapt
#   ◓ Compat → CompatLinearAlgebraExt
#   Progress [===============>                         ]  34/95
#   ◐ MacroTools
#   ✓ CFTime
#   ✓ Preferences
#   ✓ InverseFunctions → InverseFunctionsDatesExt
#   ✓ LRUCache → SerializationExt
#   ◒ DataStructures
#   ✓ Parameters
#   ✓ LeftChildRightSiblingTrees
#   ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ◓ FillArrays → FillArraysSparseArraysExt
#   ◑ Statistics → SparseArraysExt
#   ◓ FillArrays → FillArraysStatisticsExt
#   ◑ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◒ ThreadingUtilities
#   ◐ Adapt
#   ◑ Compat → CompatLinearAlgebraExt
#   Progress [===============>                         ]  34/95
#   ◓ MacroTools
#   ✓ CFTime
#   ✓ Preferences
#   ✓ InverseFunctions → InverseFunctionsDatesExt
#   ◐ DataStructures
#   ✓ Parameters
#   ✓ LeftChildRightSiblingTrees
#   ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ◑ FillArrays → FillArraysSparseArraysExt
#   ◒ Statistics → SparseArraysExt
#   ◑ FillArrays → FillArraysStatisticsExt
#   ◒ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◐ ThreadingUtilities
#   ◓ Adapt
#   ◒ Compat → CompatLinearAlgebraExt
#   Progress [===============>                         ]  35/95
#   ◑ MacroTools
#   ✓ CFTime
#   ◓ DataStructures
#   ✓ LeftChildRightSiblingTrees
#   ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ◒ FillArrays → FillArraysSparseArraysExt
#   ◐ Statistics → SparseArraysExt
#   ◒ FillArrays → FillArraysStatisticsExt
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◓ ThreadingUtilities
#   ◑ Adapt
#   ◐ Compat → CompatLinearAlgebraExt
#   ◑ MPIPreferences
#   Progress [================>                        ]  36/95
#   ◒ MacroTools
#   ◑ DataStructures
#   ✓ LeftChildRightSiblingTrees
#   ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ◐ FillArrays → FillArraysSparseArraysExt
#   ◓ Statistics → SparseArraysExt
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◑ ThreadingUtilities
#   ◒ Adapt
#   ◓ Compat → CompatLinearAlgebraExt
#   ◒ MPIPreferences
#   ◑ PrecompileTools
#   Progress [=================>                       ]  39/95
#   ✓ MacroTools
#   ◒ DataStructures
#   ✓ LeftChildRightSiblingTrees
#   ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ✓ FillArrays → FillArraysSparseArraysExt
#   ◑ Statistics → SparseArraysExt
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◒ ThreadingUtilities
#   ◐ Adapt
#   ✓ Compat → CompatLinearAlgebraExt
#   ◐ MPIPreferences
#   ◒ PrecompileTools
#   ◓ JLLWrappers
#   ◒ TerminalLoggers
#   ◒ DiskArrays
#   Progress [==================>                      ]  41/95
#   ✓ MacroTools
#   ◐ DataStructures
#   ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#   ✓ FillArrays → FillArraysSparseArraysExt
#   ✓ Statistics → SparseArraysExt
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◐ ThreadingUtilities
#   ✓ Adapt
#   ✓ Compat → CompatLinearAlgebraExt
#   ◓ MPIPreferences
#   ◐ PrecompileTools
#   ◑ JLLWrappers
#   ◐ TerminalLoggers
#   ◐ DiskArrays
#   ◒ SimpleTraits
#   ◓ Accessors
#   Progress [==================>                      ]  41/95
#   ✓ MacroTools
#   ◓ DataStructures
#   ✓ FillArrays → FillArraysSparseArraysExt
#   ✓ Statistics → SparseArraysExt
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◓ ThreadingUtilities
#   ✓ Adapt
#   ✓ Compat → CompatLinearAlgebraExt
#   ◑ MPIPreferences
#   ◓ PrecompileTools
#   ◒ JLLWrappers
#   ◓ TerminalLoggers
#   ◓ DiskArrays
#   ◐ SimpleTraits
#   ◑ Accessors
#   Progress [==================>                      ]  41/95
#   ✓ MacroTools
#   ◑ DataStructures
#   ✓ FillArrays → FillArraysSparseArraysExt
#   ✓ Statistics → SparseArraysExt
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◑ ThreadingUtilities
#   ✓ Adapt
#   ✓ Compat → CompatLinearAlgebraExt
#   ◒ MPIPreferences
#   ◑ PrecompileTools
#   ◐ JLLWrappers
#   ◑ TerminalLoggers
#   ◑ DiskArrays
#   ◓ SimpleTraits
#   ◒ Accessors
#   Progress [==================>                      ]  41/95
#   ✓ MacroTools
#   ◒ DataStructures
#   ✓ FillArrays → FillArraysSparseArraysExt
#   ✓ Statistics → SparseArraysExt
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◒ ThreadingUtilities
#   ✓ Adapt
#   ✓ Compat → CompatLinearAlgebraExt
#   ◐ MPIPreferences
#   ◒ PrecompileTools
#   ◓ JLLWrappers
#   ◒ TerminalLoggers
#   ◒ DiskArrays
#   ◑ SimpleTraits
#   ◐ Accessors
#   Progress [==================>                      ]  41/95
#   ✓ MacroTools
#   ◐ DataStructures
#   ✓ FillArrays → FillArraysSparseArraysExt
#   ✓ Statistics → SparseArraysExt
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◐ ThreadingUtilities
#   ✓ Adapt
#   ✓ Compat → CompatLinearAlgebraExt
#   ◓ MPIPreferences
#   ◐ PrecompileTools
#   ◑ JLLWrappers
#   ◐ TerminalLoggers
#   ◐ DiskArrays
#   ◒ SimpleTraits
#   ◓ Accessors
#   Progress [==================>                      ]  41/95
#   ✓ MacroTools
#   ◓ DataStructures
#   ✓ FillArrays → FillArraysSparseArraysExt
#   ✓ Statistics → SparseArraysExt
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ◓ ThreadingUtilities
#   ✓ Adapt
#   ✓ Compat → CompatLinearAlgebraExt
#   ◑ MPIPreferences
#   ◓ PrecompileTools
#   ◒ JLLWrappers
#   ◓ TerminalLoggers
#   ◓ DiskArrays
#   ◐ SimpleTraits
#   ◑ Accessors
#   Progress [==================>                      ]  42/95
#   ✓ MacroTools
#   ◑ DataStructures
#   ✓ FillArrays → FillArraysSparseArraysExt
#   ✓ Statistics → SparseArraysExt
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ✓ ThreadingUtilities
#   ✓ Adapt
#   ✓ Compat → CompatLinearAlgebraExt
#   ◒ MPIPreferences
#   ◑ PrecompileTools
#   ◐ JLLWrappers
#   ◑ TerminalLoggers
#   ◑ DiskArrays
#   ◓ SimpleTraits
#   ◒ Accessors
#   ◒ Adapt → AdaptSparseArraysExt
#   Progress [===================>                     ]  44/95
#   ✓ MacroTools
#   ◒ DataStructures
#   ✓ FillArrays → FillArraysSparseArraysExt
#   ✓ Statistics → SparseArraysExt
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ ThreadingUtilities
#   ✓ Adapt
#   ✓ Compat → CompatLinearAlgebraExt
#   ✓ MPIPreferences
#   ✓ PrecompileTools
#   ◓ JLLWrappers
#   ◒ TerminalLoggers
#   ◒ DiskArrays
#   ◑ SimpleTraits
#   ◐ Accessors
#   ◐ Adapt → AdaptSparseArraysExt
#   ◐ ArrayInterface
#   ◑ OffsetArrays → OffsetArraysAdaptExt
#   Progress [====================>                    ]  46/95
#   ✓ MacroTools
#   ✓ DataStructures
#   ✓ FillArrays → FillArraysSparseArraysExt
#   ✓ Statistics → SparseArraysExt
#   ✓ ThreadingUtilities
#   ✓ Adapt
#   ✓ Compat → CompatLinearAlgebraExt
#   ✓ MPIPreferences
#   ✓ PrecompileTools
#   ✓ JLLWrappers
#   ◐ TerminalLoggers
#   ◐ DiskArrays
#   ◒ SimpleTraits
#   ◓ Accessors
#   ◓ Adapt → AdaptSparseArraysExt
#   ◓ ArrayInterface
#   ◒ OffsetArrays → OffsetArraysAdaptExt
#   ◒ StaticArrays
#   ◒ Static
#   Progress [====================>                    ]  46/95
#   ✓ DataStructures
#   ✓ Statistics → SparseArraysExt
#   ✓ ThreadingUtilities
#   ✓ Adapt
#   ✓ MPIPreferences
#   ✓ PrecompileTools
#   ✓ JLLWrappers
#   ◓ TerminalLoggers
#   ◓ DiskArrays
#   ◐ SimpleTraits
#   ◑ Accessors
#   ◑ Adapt → AdaptSparseArraysExt
#   ◑ ArrayInterface
#   ◐ OffsetArrays → OffsetArraysAdaptExt
#   ◐ StaticArrays
#   ◐ Static
#   Progress [====================>                    ]  46/95
#   ✓ DataStructures
#   ✓ ThreadingUtilities
#   ✓ MPIPreferences
#   ✓ PrecompileTools
#   ✓ JLLWrappers
#   ◑ TerminalLoggers
#   ◑ DiskArrays
#   ◓ SimpleTraits
#   ◒ Accessors
#   ◒ Adapt → AdaptSparseArraysExt
#   ◒ ArrayInterface
#   ◓ OffsetArrays → OffsetArraysAdaptExt
#   ◓ StaticArrays
#   ◓ Static
#   Progress [====================>                    ]  47/95
#   ✓ DataStructures
#   ✓ ThreadingUtilities
#   ✓ MPIPreferences
#   ✓ PrecompileTools
#   ✓ JLLWrappers
#   ✓ TerminalLoggers
#   ◒ DiskArrays
#   ◑ SimpleTraits
#   ◐ Accessors
#   ◐ Adapt → AdaptSparseArraysExt
#   ◐ ArrayInterface
#   ◑ OffsetArrays → OffsetArraysAdaptExt
#   ◑ StaticArrays
#   ◑ Static
#   ◑ OpenSSL_jll
#   Progress [====================>                    ]  47/95
#   ✓ DataStructures
#   ✓ ThreadingUtilities
#   ✓ MPIPreferences
#   ✓ PrecompileTools
#   ✓ JLLWrappers
#   ✓ TerminalLoggers
#   ◐ DiskArrays
#   ◒ SimpleTraits
#   ◓ Accessors
#   ◓ Adapt → AdaptSparseArraysExt
#   ◓ ArrayInterface
#   ◒ OffsetArrays → OffsetArraysAdaptExt
#   ◒ StaticArrays
#   ◒ Static
#   ◒ OpenSSL_jll
#   Progress [=====================>                   ]  48/95
#   ✓ DataStructures
#   ✓ ThreadingUtilities
#   ✓ MPIPreferences
#   ✓ PrecompileTools
#   ✓ JLLWrappers
#   ✓ TerminalLoggers
#   ◓ DiskArrays
#   ✓ SimpleTraits
#   ◑ Accessors
#   ◑ Adapt → AdaptSparseArraysExt
#   ◑ ArrayInterface
#   ◐ OffsetArrays → OffsetArraysAdaptExt
#   ◐ StaticArrays
#   ◐ Static
#   ◐ OpenSSL_jll
#   ◑ MicrosoftMPI_jll
#   Progress [=====================>                   ]  48/95
#   ✓ DataStructures
#   ✓ ThreadingUtilities
#   ✓ MPIPreferences
#   ✓ PrecompileTools
#   ✓ JLLWrappers
#   ✓ TerminalLoggers
#   ◑ DiskArrays
#   ✓ SimpleTraits
#   ◒ Accessors
#   ◒ Adapt → AdaptSparseArraysExt
#   ◒ ArrayInterface
#   ◓ OffsetArrays → OffsetArraysAdaptExt
#   ◓ StaticArrays
#   ◓ Static
#   ◓ OpenSSL_jll
#   ◒ MicrosoftMPI_jll
#   Progress [=====================>                   ]  48/95
#   ✓ DataStructures
#   ✓ ThreadingUtilities
#   ✓ MPIPreferences
#   ✓ PrecompileTools
#   ✓ JLLWrappers
#   ✓ TerminalLoggers
#   ◒ DiskArrays
#   ✓ SimpleTraits
#   ◐ Accessors
#   ◐ Adapt → AdaptSparseArraysExt
#   ◐ ArrayInterface
#   ◑ OffsetArrays → OffsetArraysAdaptExt
#   ◑ StaticArrays
#   ◑ Static
#   ◑ OpenSSL_jll
#   ◐ MicrosoftMPI_jll
#   Progress [=====================>                   ]  49/95
#   ✓ DataStructures
#   ✓ MPIPreferences
#   ✓ PrecompileTools
#   ✓ JLLWrappers
#   ✓ TerminalLoggers
#   ◐ DiskArrays
#   ✓ SimpleTraits
#   ◓ Accessors
#   ◓ Adapt → AdaptSparseArraysExt
#   ◓ ArrayInterface
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ◒ StaticArrays
#   ◒ Static
#   ◒ OpenSSL_jll
#   ◓ MicrosoftMPI_jll
#   ◐ XZ_jll
#   Progress [======================>                  ]  50/95
#   ✓ DataStructures
#   ✓ JLLWrappers
#   ✓ TerminalLoggers
#   ◓ DiskArrays
#   ✓ SimpleTraits
#   ◑ Accessors
#   ✓ Adapt → AdaptSparseArraysExt
#   ◑ ArrayInterface
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ◐ StaticArrays
#   ◐ Static
#   ◐ OpenSSL_jll
#   ◑ MicrosoftMPI_jll
#   ◓ XZ_jll
#   ◒ Zstd_jll
#   Progress [======================>                  ]  51/95
#   ✓ TerminalLoggers
#   ◑ DiskArrays
#   ✓ SimpleTraits
#   ◒ Accessors
#   ✓ Adapt → AdaptSparseArraysExt
#   ✓ ArrayInterface
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ◓ StaticArrays
#   ◓ Static
#   ◓ OpenSSL_jll
#   ◒ MicrosoftMPI_jll
#   ◑ XZ_jll
#   ◐ Zstd_jll
#   ◑ Libiconv_jll
#   Progress [======================>                  ]  51/95
#   ✓ TerminalLoggers
#   ◒ DiskArrays
#   ✓ SimpleTraits
#   ◐ Accessors
#   ✓ Adapt → AdaptSparseArraysExt
#   ✓ ArrayInterface
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ◑ StaticArrays
#   ◑ Static
#   ◑ OpenSSL_jll
#   ◐ MicrosoftMPI_jll
#   ◒ XZ_jll
#   ◓ Zstd_jll
#   ◒ Libiconv_jll
#   Progress [======================>                  ]  51/95
#   ✓ TerminalLoggers
#   ◐ DiskArrays
#   ✓ SimpleTraits
#   ◓ Accessors
#   ✓ Adapt → AdaptSparseArraysExt
#   ✓ ArrayInterface
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ◒ StaticArrays
#   ◒ Static
#   ◒ OpenSSL_jll
#   ◓ MicrosoftMPI_jll
#   ◐ XZ_jll
#   ◑ Zstd_jll
#   ◐ Libiconv_jll
#   Progress [======================>                  ]  51/95
#   ✓ TerminalLoggers
#   ◓ DiskArrays
#   ✓ SimpleTraits
#   ◑ Accessors
#   ✓ Adapt → AdaptSparseArraysExt
#   ✓ ArrayInterface
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ◐ StaticArrays
#   ◐ Static
#   ◐ OpenSSL_jll
#   ◑ MicrosoftMPI_jll
#   ◓ XZ_jll
#   ◒ Zstd_jll
#   ◓ Libiconv_jll
#   Progress [=======================>                 ]  53/95
#   ◑ DiskArrays
#   ✓ SimpleTraits
#   ◒ Accessors
#   ✓ Adapt → AdaptSparseArraysExt
#   ✓ ArrayInterface
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ◓ StaticArrays
#   ◓ Static
#   ✓ OpenSSL_jll
#   ✓ MicrosoftMPI_jll
#   ◑ XZ_jll
#   ◐ Zstd_jll
#   ◑ Libiconv_jll
#   ◐ Bzip2_jll
#   ◑ Lz4_jll
#   Progress [=======================>                 ]  54/95
#   ◒ DiskArrays
#   ◐ Accessors
#   ✓ Adapt → AdaptSparseArraysExt
#   ✓ ArrayInterface
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ◑ StaticArrays
#   ✓ Static
#   ✓ OpenSSL_jll
#   ✓ MicrosoftMPI_jll
#   ◒ XZ_jll
#   ◓ Zstd_jll
#   ◒ Libiconv_jll
#   ◓ Bzip2_jll
#   ◒ Lz4_jll
#   ◐ MPItrampoline_jll
#   Progress [=======================>                 ]  54/95
#   ◐ DiskArrays
#   ◓ Accessors
#   ✓ Adapt → AdaptSparseArraysExt
#   ✓ ArrayInterface
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ◒ StaticArrays
#   ✓ Static
#   ✓ OpenSSL_jll
#   ✓ MicrosoftMPI_jll
#   ◐ XZ_jll
#   ◑ Zstd_jll
#   ◐ Libiconv_jll
#   ◑ Bzip2_jll
#   ◐ Lz4_jll
#   ◓ MPItrampoline_jll
#   Progress [========================>                ]  55/95
#   ✓ DiskArrays
#   ◑ Accessors
#   ✓ Adapt → AdaptSparseArraysExt
#   ✓ ArrayInterface
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ◐ StaticArrays
#   ✓ Static
#   ✓ OpenSSL_jll
#   ✓ MicrosoftMPI_jll
#   ◓ XZ_jll
#   ◒ Zstd_jll
#   ◓ Libiconv_jll
#   ◒ Bzip2_jll
#   ◓ Lz4_jll
#   ◑ MPItrampoline_jll
#   ◓ Xorg_libpciaccess_jll
#   Progress [========================>                ]  55/95
#   ✓ DiskArrays
#   ◒ Accessors
#   ✓ Adapt → AdaptSparseArraysExt
#   ✓ ArrayInterface
#   ◓ StaticArrays
#   ✓ Static
#   ✓ OpenSSL_jll
#   ✓ MicrosoftMPI_jll
#   ◑ XZ_jll
#   ◐ Zstd_jll
#   ◑ Libiconv_jll
#   ◐ Bzip2_jll
#   ◑ Lz4_jll
#   ◒ MPItrampoline_jll
#   ◑ Xorg_libpciaccess_jll
#   Progress [========================>                ]  55/95
#   ✓ DiskArrays
#   ◐ Accessors
#   ✓ Adapt → AdaptSparseArraysExt
#   ✓ ArrayInterface
#   ◑ StaticArrays
#   ✓ Static
#   ✓ OpenSSL_jll
#   ✓ MicrosoftMPI_jll
#   ◒ XZ_jll
#   ◓ Zstd_jll
#   ◒ Libiconv_jll
#   ◓ Bzip2_jll
#   ◒ Lz4_jll
#   ◐ MPItrampoline_jll
#   ◒ Xorg_libpciaccess_jll
#   Progress [========================>                ]  56/95
#   ✓ DiskArrays
#   ◓ Accessors
#   ✓ ArrayInterface
#   ◒ StaticArrays
#   ✓ Static
#   ✓ OpenSSL_jll
#   ✓ MicrosoftMPI_jll
#   ◐ XZ_jll
#   ◑ Zstd_jll
#   ✓ Libiconv_jll
#   ◑ Bzip2_jll
#   ◐ Lz4_jll
#   ◓ MPItrampoline_jll
#   ◐ Xorg_libpciaccess_jll
#   ◐ libaec_jll
#   Progress [=========================>               ]  58/95
#   ✓ DiskArrays
#   ◑ Accessors
#   ◐ StaticArrays
#   ✓ Static
#   ✓ OpenSSL_jll
#   ✓ MicrosoftMPI_jll
#   ✓ XZ_jll
#   ✓ Zstd_jll
#   ✓ Libiconv_jll
#   ◒ Bzip2_jll
#   ◓ Lz4_jll
#   ◑ MPItrampoline_jll
#   ◓ Xorg_libpciaccess_jll
#   ◓ libaec_jll
#   ◑ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ◑ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   Progress [=========================>               ]  58/95
#   ✓ DiskArrays
#   ◒ Accessors
#   ◓ StaticArrays
#   ✓ Static
#   ✓ OpenSSL_jll
#   ✓ MicrosoftMPI_jll
#   ✓ XZ_jll
#   ✓ Zstd_jll
#   ✓ Libiconv_jll
#   ◐ Bzip2_jll
#   ◑ Lz4_jll
#   ◒ MPItrampoline_jll
#   ◑ Xorg_libpciaccess_jll
#   ◑ libaec_jll
#   ◒ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ◒ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   Progress [=========================>               ]  58/95
#   ✓ DiskArrays
#   ◐ Accessors
#   ◑ StaticArrays
#   ✓ Static
#   ✓ OpenSSL_jll
#   ✓ MicrosoftMPI_jll
#   ✓ XZ_jll
#   ✓ Zstd_jll
#   ✓ Libiconv_jll
#   ◓ Bzip2_jll
#   ◒ Lz4_jll
#   ◐ MPItrampoline_jll
#   ◒ Xorg_libpciaccess_jll
#   ◒ libaec_jll
#   ◐ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ◐ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   Progress [=========================>               ]  59/95
#   ✓ DiskArrays
#   ◓ Accessors
#   ◒ StaticArrays
#   ✓ Static
#   ✓ XZ_jll
#   ✓ Zstd_jll
#   ✓ Libiconv_jll
#   ✓ Bzip2_jll
#   ◐ Lz4_jll
#   ◓ MPItrampoline_jll
#   ◐ Xorg_libpciaccess_jll
#   ◐ libaec_jll
#   ◓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ◓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ◑ BitTwiddlingConvenienceFunctions
#   Progress [==========================>              ]  60/95
#   ✓ DiskArrays
#   ◑ Accessors
#   ◐ StaticArrays
#   ✓ XZ_jll
#   ✓ Zstd_jll
#   ✓ Libiconv_jll
#   ✓ Bzip2_jll
#   ✓ Lz4_jll
#   ◑ MPItrampoline_jll
#   ◓ Xorg_libpciaccess_jll
#   ◓ libaec_jll
#   ◑ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ◑ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ◒ BitTwiddlingConvenienceFunctions
#   ◐ CPUSummary
#   Progress [==========================>              ]  60/95
#   ✓ DiskArrays
#   ◒ Accessors
#   ◓ StaticArrays
#   ✓ XZ_jll
#   ✓ Zstd_jll
#   ✓ Libiconv_jll
#   ✓ Bzip2_jll
#   ✓ Lz4_jll
#   ◒ MPItrampoline_jll
#   ◑ Xorg_libpciaccess_jll
#   ◑ libaec_jll
#   ◒ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ◒ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ◐ BitTwiddlingConvenienceFunctions
#   ◓ CPUSummary
#   Progress [==========================>              ]  61/95
#   ✓ DiskArrays
#   ◐ Accessors
#   ◑ StaticArrays
#   ✓ XZ_jll
#   ✓ Zstd_jll
#   ✓ Libiconv_jll
#   ✓ Bzip2_jll
#   ✓ Lz4_jll
#   ◐ MPItrampoline_jll
#   ✓ Xorg_libpciaccess_jll
#   ◒ libaec_jll
#   ◐ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ◐ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ◓ BitTwiddlingConvenienceFunctions
#   ◑ CPUSummary
#   ◑ StaticArrayInterface
#   Progress [==========================>              ]  61/95
#   ◓ Accessors
#   ◒ StaticArrays
#   ✓ XZ_jll
#   ✓ Zstd_jll
#   ✓ Libiconv_jll
#   ✓ Bzip2_jll
#   ✓ Lz4_jll
#   ◓ MPItrampoline_jll
#   ✓ Xorg_libpciaccess_jll
#   ◐ libaec_jll
#   ◓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ◓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ◑ BitTwiddlingConvenienceFunctions
#   ◒ CPUSummary
#   ◒ StaticArrayInterface
#   Progress [===========================>             ]  62/95
#   ◑ Accessors
#   ◐ StaticArrays
#   ✓ XZ_jll
#   ✓ Zstd_jll
#   ✓ Libiconv_jll
#   ✓ Bzip2_jll
#   ✓ Lz4_jll
#   ◑ MPItrampoline_jll
#   ✓ Xorg_libpciaccess_jll
#   ◓ libaec_jll
#   ◑ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ◒ BitTwiddlingConvenienceFunctions
#   ◐ CPUSummary
#   ◐ StaticArrayInterface
#   ◐ CommonDataModel
#   Progress [===========================>             ]  62/95
#   ◒ Accessors
#   ◓ StaticArrays
#   ✓ XZ_jll
#   ✓ Zstd_jll
#   ✓ Bzip2_jll
#   ✓ Lz4_jll
#   ◒ MPItrampoline_jll
#   ✓ Xorg_libpciaccess_jll
#   ◑ libaec_jll
#   ◒ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ◐ BitTwiddlingConvenienceFunctions
#   ◓ CPUSummary
#   ◓ StaticArrayInterface
#   ◓ CommonDataModel
#   Progress [===========================>             ]  64/95
#   ◐ Accessors
#   ◑ StaticArrays
#   ✓ Bzip2_jll
#   ✓ Lz4_jll
#   ◐ MPItrampoline_jll
#   ✓ Xorg_libpciaccess_jll
#   ✓ libaec_jll
#   ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ◓ BitTwiddlingConvenienceFunctions
#   ◑ CPUSummary
#   ◑ StaticArrayInterface
#   ◑ CommonDataModel
#   ◒ XML2_jll
#   ◒ libzip_jll
#   Progress [===========================>             ]  64/95
#   ◓ Accessors
#   ◒ StaticArrays
#   ✓ Bzip2_jll
#   ✓ Lz4_jll
#   ◓ MPItrampoline_jll
#   ✓ Xorg_libpciaccess_jll
#   ✓ libaec_jll
#   ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ◑ BitTwiddlingConvenienceFunctions
#   ◒ CPUSummary
#   ◒ StaticArrayInterface
#   ◒ CommonDataModel
#   ◐ XML2_jll
#   ◐ libzip_jll
#   Progress [============================>            ]  65/95
#   ✓ Accessors
#   ◐ StaticArrays
#   ✓ Bzip2_jll
#   ✓ Lz4_jll
#   ◑ MPItrampoline_jll
#   ✓ Xorg_libpciaccess_jll
#   ✓ libaec_jll
#   ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ◒ BitTwiddlingConvenienceFunctions
#   ◐ CPUSummary
#   ◐ StaticArrayInterface
#   ◐ CommonDataModel
#   ◓ XML2_jll
#   ◓ libzip_jll
#   ◒ Blosc_jll
#   Progress [============================>            ]  66/95
#   ✓ Accessors
#   ◓ StaticArrays
#   ✓ Bzip2_jll
#   ✓ Lz4_jll
#   ◒ MPItrampoline_jll
#   ✓ Xorg_libpciaccess_jll
#   ✓ libaec_jll
#   ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ✓ BitTwiddlingConvenienceFunctions
#   ◓ CPUSummary
#   ◓ StaticArrayInterface
#   ◓ CommonDataModel
#   ◑ XML2_jll
#   ◑ libzip_jll
#   ◐ Blosc_jll
#   ◑ Accessors → LinearAlgebraExt
#   Progress [============================>            ]  66/95
#   ✓ Accessors
#   ◑ StaticArrays
#   ◐ MPItrampoline_jll
#   ✓ Xorg_libpciaccess_jll
#   ✓ libaec_jll
#   ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ✓ BitTwiddlingConvenienceFunctions
#   ◑ CPUSummary
#   ◑ StaticArrayInterface
#   ◑ CommonDataModel
#   ◒ XML2_jll
#   ◒ libzip_jll
#   ◓ Blosc_jll
#   ◒ Accessors → LinearAlgebraExt
#   Progress [============================>            ]  66/95
#   ✓ Accessors
#   ◒ StaticArrays
#   ◓ MPItrampoline_jll
#   ✓ Xorg_libpciaccess_jll
#   ✓ libaec_jll
#   ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ✓ BitTwiddlingConvenienceFunctions
#   ◒ CPUSummary
#   ◒ StaticArrayInterface
#   ◒ CommonDataModel
#   ◐ XML2_jll
#   ◐ libzip_jll
#   ◑ Blosc_jll
#   ◐ Accessors → LinearAlgebraExt
#   Progress [=============================>           ]  67/95
#   ✓ Accessors
#   ◐ StaticArrays
#   ✓ MPItrampoline_jll
#   ✓ Xorg_libpciaccess_jll
#   ✓ libaec_jll
#   ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ✓ BitTwiddlingConvenienceFunctions
#   ◐ CPUSummary
#   ◐ StaticArrayInterface
#   ◐ CommonDataModel
#   ◓ XML2_jll
#   ◓ libzip_jll
#   ◒ Blosc_jll
#   ◓ Accessors → LinearAlgebraExt
#   Progress [=============================>           ]  67/95
#   ✓ Accessors
#   ◓ StaticArrays
#   ✓ MPItrampoline_jll
#   ✓ libaec_jll
#   ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ✓ BitTwiddlingConvenienceFunctions
#   ◓ CPUSummary
#   ◓ StaticArrayInterface
#   ◓ CommonDataModel
#   ◑ XML2_jll
#   ◑ libzip_jll
#   ◐ Blosc_jll
#   ◑ Accessors → LinearAlgebraExt
#   Progress [=============================>           ]  67/95
#   ✓ Accessors
#   ◑ StaticArrays
#   ✓ MPItrampoline_jll
#   ✓ libaec_jll
#   ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ BitTwiddlingConvenienceFunctions
#   ◑ CPUSummary
#   ◑ StaticArrayInterface
#   ◑ CommonDataModel
#   ◒ XML2_jll
#   ◒ libzip_jll
#   ◓ Blosc_jll
#   ◒ Accessors → LinearAlgebraExt
#   Progress [=============================>           ]  67/95
#   ✓ Accessors
#   ◒ StaticArrays
#   ✓ MPItrampoline_jll
#   ✓ libaec_jll
#   ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ BitTwiddlingConvenienceFunctions
#   ◒ CPUSummary
#   ◒ StaticArrayInterface
#   ◒ CommonDataModel
#   ◐ XML2_jll
#   ◐ libzip_jll
#   ◑ Blosc_jll
#   ◐ Accessors → LinearAlgebraExt
#   Progress [=============================>           ]  67/95
#   ✓ Accessors
#   ◐ StaticArrays
#   ✓ MPItrampoline_jll
#   ✓ BitTwiddlingConvenienceFunctions
#   ◐ CPUSummary
#   ◐ StaticArrayInterface
#   ◐ CommonDataModel
#   ◓ XML2_jll
#   ◓ libzip_jll
#   ◒ Blosc_jll
#   ◓ Accessors → LinearAlgebraExt
#   Progress [=============================>           ]  68/95
#   ✓ Accessors
#   ◓ StaticArrays
#   ✓ MPItrampoline_jll
#   ✓ BitTwiddlingConvenienceFunctions
#   ◓ CPUSummary
#   ◓ StaticArrayInterface
#   ◓ CommonDataModel
#   ◑ XML2_jll
#   ✓ libzip_jll
#   ◐ Blosc_jll
#   ◑ Accessors → LinearAlgebraExt
#   Progress [==============================>          ]  69/95
#   ✓ Accessors
#   ◑ StaticArrays
#   ✓ MPItrampoline_jll
#   ✓ BitTwiddlingConvenienceFunctions
#   ◑ CPUSummary
#   ◑ StaticArrayInterface
#   ◑ CommonDataModel
#   ✓ XML2_jll
#   ✓ libzip_jll
#   ◓ Blosc_jll
#   ◒ Accessors → LinearAlgebraExt
#   ◒ Hwloc_jll
#   Progress [==============================>          ]  71/95
#   ◒ StaticArrays
#   ✓ MPItrampoline_jll
#   ✓ BitTwiddlingConvenienceFunctions
#   ◒ CPUSummary
#   ◒ StaticArrayInterface
#   ◒ CommonDataModel
#   ✓ XML2_jll
#   ✓ libzip_jll
#   ✓ Blosc_jll
#   ✓ Accessors → LinearAlgebraExt
#   ◐ Hwloc_jll
#   Progress [===============================>         ]  72/95
#   ◐ StaticArrays
#   ✓ MPItrampoline_jll
#   ✓ CPUSummary
#   ◐ StaticArrayInterface
#   ◐ CommonDataModel
#   ✓ XML2_jll
#   ✓ libzip_jll
#   ✓ Blosc_jll
#   ✓ Accessors → LinearAlgebraExt
#   ◓ Hwloc_jll
#   ◓ PolyesterWeave
#   Progress [===============================>         ]  72/95
#   ◓ StaticArrays
#   ✓ MPItrampoline_jll
#   ✓ CPUSummary
#   ◓ StaticArrayInterface
#   ◓ CommonDataModel
#   ✓ XML2_jll
#   ✓ libzip_jll
#   ✓ Blosc_jll
#   ✓ Accessors → LinearAlgebraExt
#   ◑ Hwloc_jll
#   ◑ PolyesterWeave
#   Progress [===============================>         ]  72/95
#   ◑ StaticArrays
#   ✓ MPItrampoline_jll
#   ✓ CPUSummary
#   ◑ StaticArrayInterface
#   ◑ CommonDataModel
#   ✓ XML2_jll
#   ✓ libzip_jll
#   ✓ Blosc_jll
#   ✓ Accessors → LinearAlgebraExt
#   ◒ Hwloc_jll
#   ◒ PolyesterWeave
#   Progress [===============================>         ]  72/95
#   ◒ StaticArrays
#   ✓ CPUSummary
#   ◒ StaticArrayInterface
#   ◒ CommonDataModel
#   ✓ XML2_jll
#   ✓ libzip_jll
#   ✓ Blosc_jll
#   ✓ Accessors → LinearAlgebraExt
#   ◐ Hwloc_jll
#   ◐ PolyesterWeave
#   Progress [===============================>         ]  72/95
#   ◐ StaticArrays
#   ✓ CPUSummary
#   ◐ StaticArrayInterface
#   ◐ CommonDataModel
#   ✓ XML2_jll
#   ✓ libzip_jll
#   ✓ Blosc_jll
#   ✓ Accessors → LinearAlgebraExt
#   ◓ Hwloc_jll
#   ◓ PolyesterWeave
#   Progress [===============================>         ]  73/95
#   ◓ StaticArrays
#   ✓ CPUSummary
#   ◓ StaticArrayInterface
#   ✓ CommonDataModel
#   ✓ XML2_jll
#   ✓ libzip_jll
#   ✓ Blosc_jll
#   ✓ Accessors → LinearAlgebraExt
#   ◑ Hwloc_jll
#   ◑ PolyesterWeave
#   Progress [================================>        ]  74/95
#   ◑ StaticArrays
#   ✓ CPUSummary
#   ◑ StaticArrayInterface
#   ✓ CommonDataModel
#   ✓ XML2_jll
#   ✓ libzip_jll
#   ✓ Blosc_jll
#   ✓ Accessors → LinearAlgebraExt
#   ✓ Hwloc_jll
#   ◒ PolyesterWeave
#   ◑ OpenMPI_jll
#   ◐ MPICH_jll
#   Progress [================================>        ]  75/95
#   ◒ StaticArrays
#   ✓ CPUSummary
#   ✓ StaticArrayInterface
#   ✓ CommonDataModel
#   ✓ XML2_jll
#   ✓ Blosc_jll
#   ✓ Accessors → LinearAlgebraExt
#   ✓ Hwloc_jll
#   ◐ PolyesterWeave
#   ◒ OpenMPI_jll
#   ◓ MPICH_jll
#   ◒ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ◒ CloseOpenIntervals
#   ◐ LayoutPointers
#   Progress [================================>        ]  75/95
#   ◐ StaticArrays
#   ✓ CPUSummary
#   ✓ StaticArrayInterface
#   ✓ CommonDataModel
#   ✓ Blosc_jll
#   ✓ Accessors → LinearAlgebraExt
#   ✓ Hwloc_jll
#   ◓ PolyesterWeave
#   ◐ OpenMPI_jll
#   ◑ MPICH_jll
#   ◐ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ◐ CloseOpenIntervals
#   ◓ LayoutPointers
#   Progress [================================>        ]  76/95
#   ◓ StaticArrays
#   ✓ CPUSummary
#   ✓ StaticArrayInterface
#   ✓ CommonDataModel
#   ✓ Hwloc_jll
#   ✓ PolyesterWeave
#   ◓ OpenMPI_jll
#   ◒ MPICH_jll
#   ◓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ◓ CloseOpenIntervals
#   ◑ LayoutPointers
#   Progress [================================>        ]  76/95
#   ◑ StaticArrays
#   ✓ CPUSummary
#   ✓ StaticArrayInterface
#   ✓ CommonDataModel
#   ✓ Hwloc_jll
#   ✓ PolyesterWeave
#   ◑ OpenMPI_jll
#   ◐ MPICH_jll
#   ◑ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ◑ CloseOpenIntervals
#   ◒ LayoutPointers
#   Progress [================================>        ]  76/95
#   ◒ StaticArrays
#   ✓ StaticArrayInterface
#   ✓ CommonDataModel
#   ✓ Hwloc_jll
#   ✓ PolyesterWeave
#   ◒ OpenMPI_jll
#   ◓ MPICH_jll
#   ◒ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ◒ CloseOpenIntervals
#   ◐ LayoutPointers

# %%
# Run the Wflow model
# Note: This assumes you have Julia and Wflow.jl installed
# !julia -e 'using Wflow; Wflow.run("./wflow_models/first_wflow_model/wflow_sbm.toml")'
# Out:
# [ Info: Wflow version v1.0.0-dev
# [ Info: Initialize model variables for model type sbm.
# ┌ Info: Cyclic parameters are provided by
# └ wflow_models/first_wflow_model/staticmaps.nc.
# ┌ Info: Forcing parameters are provided by
# └ wflow_models/first_wflow_model/inmaps-era5-2010.nc.
# ┌ Info: Set atmosphere_water__precipitation_volume_flux using netCDF variable
# └ precip as forcing parameter.
# ┌ Info: Set atmosphere_air__temperature using netCDF variable temp as forcing
# └ parameter.
# ┌ Info: Set land_surface_water__potential_evaporation_volume_flux using
# └ netCDF variable pet as forcing parameter.
# ┌ Info: Set vegetation__leaf_area_index using netCDF variable
# └ vegetation_leaf_area_index as cyclic parameter, with 12 timesteps.
# ┌ Info: General model settings
# │   snow = true
# │   gravitational_snow_transport = true
# │   glacier = true
# │   reservoirs = false
# │   pits = false
# └   water_demand = false
# [ Info: Set subbasin_location__count using netCDF variable subcatchment.
# ┌ Info: Set basin__local_drain_direction using netCDF variable
# └ local_drain_direction.
# [ Info: Set land_surface__slope using netCDF variable land_slope.
# [ Info: Set river_location__mask using netCDF variable river_mask.
# ┌ Info: Set land_water_covered__area_fraction using netCDF variable
# └ land_water_fraction.
# [ Info: Set river__length using netCDF variable river_length.
# [ Info: Set river__width using netCDF variable river_width.
# [ Info: Set river__slope using netCDF variable river_slope.
# ┌ Info: Set vegetation_root__depth using netCDF variable
# └ vegetation_root_depth.
# ┌ Info: Set vegetation__crop_factor using netCDF variable
# └ vegetation_crop_factor.
# ┌ Info: Set vegetation__specific_leaf_storage using netCDF variable
# └ vegetation_leaf_storage.
# ┌ Info: Set vegetation_wood_water__storage_capacity using netCDF variable
# └ vegetation_wood_storage.
# ┌ Info: Set vegetation_canopy__light_extinction_coefficient using netCDF
# └ variable vegetation_kext.
# ┌ Info: Set
# │ vegetation_canopy_water__mean_evaporation_to_mean_precipitation_ratio
# └ using uniform value 0.11 from TOML file.
# ┌ Info: Set snowpack__degree_day_coefficient using uniform value 3.75653 from
# └ TOML file.
# ┌ Info: Set atmosphere_air__snowfall_temperature_threshold using uniform
# └ value 0 from TOML file.
# ┌ Info: Set atmosphere_air__snowfall_temperature_interval using uniform value
# └ 2 from TOML file.
# ┌ Info: Set snowpack__melting_temperature_threshold using uniform value 0
# └ from TOML file.
# ┌ Info: Set snowpack__liquid_water_holding_capacity using uniform value 0.1
# └ from TOML file.
# ┌ Info: Set glacier_ice__melting_temperature_threshold using uniform value 0
# └ from TOML file.
# ┌ Info: Set glacier_ice__degree_day_coefficient using uniform value 3 from
# └ TOML file.
# ┌ Info: Set glacier_firn_accumulation__snowpack_dry_snow_leq_depth_fraction
# └ using uniform value 0.001 from TOML file.
# ┌ Info: Set glacier_surface__area_fraction using netCDF variable
# └ glacier_fraction.
# ┌ Info: Set glacier_ice__initial_leq_depth using netCDF variable
# └ glacier_initial_leq_depth.
# [ Info: Using 3 soil layers with the following thickness: [100, 300, 800]
# ┌ Info: Set soil_surface_temperature__weight_coefficient using default value
# └ 0.1125.
# ┌ Info: Set soil_surface_water__infiltration_reduction_parameter using
# └ uniform value 0.038 from TOML file.
# ┌ Info: Set soil_water__saturated_volume_fraction using netCDF variable
# └ soil_theta_s.
# ┌ Info: Set soil_water__residual_volume_fraction using netCDF variable
# └ soil_theta_r.
# ┌ Info: Set soil_surface_water__vertical_saturated_hydraulic_conductivity
# └ using netCDF variable soil_ksat_vertical.
# ┌ Info: Set
# │ soil_water__vertical_saturated_hydraulic_conductivity_scale_parameter
# └ using netCDF variable soil_f.
# [ Info: Set soil_water__air_entry_pressure_head using default value -10.0.
# ┌ Info: Set vegetation_root__feddes_critical_pressure_head_h1 using netCDF
# └ variable vegetation_feddes_h1.
# ┌ Info: Set vegetation_root__feddes_critical_pressure_head_h2 using netCDF
# └ variable vegetation_feddes_h2.
# ┌ Info: Set vegetation_root__feddes_critical_pressure_head_h3_high using
# └ netCDF variable vegetation_feddes_h3_high.
# ┌ Info: Set vegetation_root__feddes_critical_pressure_head_h3_low using
# └ netCDF variable vegetation_feddes_h3_low.
# ┌ Info: Set vegetation_root__feddes_critical_pressure_head_h4 using netCDF
# └ variable vegetation_feddes_h4.
# ┌ Info: Set
# │ vegetation_root__feddes_critical_pressure_head_h1_reduction_coefficient
# └ using netCDF variable vegetation_feddes_alpha_h1.
# [ Info: Set soil__thickness using netCDF variable soil_thickness.
# ┌ Info: Set compacted_soil_surface_water__infiltration_capacity using uniform
# └ value 10 from TOML file.
# ┌ Info: Set soil_water_saturated_zone_bottom__max_leakage_volume_flux using
# └ uniform value 0 from TOML file.
# ┌ Info: Set soil_layer_water__brooks_corey_exponent using netCDF variable
# └ soil_brooks_corey_c.
# ┌ Info: Set
# │ soil_layer_water__vertical_saturated_hydraulic_conductivity_factor using
# └ default value 1.0.
# ┌ Info: Set compacted_soil__area_fraction using netCDF variable
# └ soil_compacted_fraction.
# ┌ Info: Set soil_wet_root__sigmoid_function_shape_parameter using uniform
# └ value -500 from TOML file.
# ┌ Info: Set
# │ soil_water_saturated_zone_top__capillary_rise_max_water_table_depth using
# └ default value 2000.0.
# ┌ Info: Set soil_water_saturated_zone_top__capillary_rise_averianov_exponent
# └ using default value 2.0.
# ┌ Info: Set
# │ subsurface_water__horizontal_to_vertical_saturated_hydraulic_conductivity_ratio
# └ using uniform value 100 from TOML file.
# ┌ Info: Set land_surface_water_flow__manning_n_parameter using netCDF
# └ variable land_manning_n.
# ┌ Info: Kinematic wave approach is used for land flow, adaptive timestepping
# └ = false.
# ┌ Info: Using a fixed internal timestep (seconds) 3600.0 for kinematic wave
# └ land flow.
# ┌ Info: Kinematic wave approach is used for river flow, adaptive timestepping
# └ = false.
# ┌ Info: Using a fixed internal timestep (seconds) 900.0 for kinematic wave
# └ river flow.
# [ Info: Set river_water_flow__manning_n_parameter using default value 0.036.
# [ Info: Set river_bank_water__depth using netCDF variable river_depth.
# ┌ Info: Set river_water__external_inflow_volume_flow_rate using default value
# └ 0.0.
# ┌ Info: Create an output netCDF file
# │ wflow_models/first_wflow_model/run_default/output.nc for grid data, using
# └ compression level 1.
# ┌ Info: Create a state output netCDF file
# └ wflow_models/first_wflow_model/run_default/outstate/outstates.nc.
# ┌ Info: Create an output CSV file
# └ wflow_models/first_wflow_model/run_default/output.csv for scalar data.
# [ Info: Set outlets using netCDF variable outlets.
# [ Info: Set gauges_grdc using netCDF variable gauges_grdc.
# [ Info: Set gauges_grdc using netCDF variable gauges_grdc.
# ┌ Info: Adding scalar output for a map with a reducer function.
# │   fileformat = "CSV"
# │   param = "river_water__volume_flow_rate"
# │   mapname = "outlets"
# └   reducer_name = "only"
# ┌ Info: Adding scalar output for a map with a reducer function.
# │   fileformat = "CSV"
# │   param = "river_water__volume_flow_rate"
# │   mapname = "gauges_grdc"
# └   reducer_name = "only"
# ┌ Info: Adding scalar output for a map with a reducer function.
# │   fileformat = "CSV"
# │   param = "atmosphere_water__precipitation_volume_flux"
# │   mapname = "gauges_grdc"
# └   reducer_name = "only"
# [ Info: Set initial conditions from default values.
# [ Info: Initialized model
# ┌ Info: Run information
# │   model_type = "sbm"
# │   starttime = DateTimeProlepticGregorian(2010-02-02T00:00:00)
# │   dt = 86400 seconds
# │   endtime = DateTimeProlepticGregorian(2010-02-15T00:00:00)
# └   nthreads() = 1
#
# Progress:   0%|                                         |  ETA: N/AProgress:   8%|███▏                                     |  ETA: 0:02:37Progress:  15%|██████▎                                  |  ETA: 0:01:12Progress:  23%|█████████▌                               |  ETA: 0:00:44Progress:  31%|████████████▋                            |  ETA: 0:00:30Progress:  38%|███████████████▊                         |  ETA: 0:00:21Progress:  46%|██████████████████▉                      |  ETA: 0:00:16Progress:  54%|██████████████████████▏                  |  ETA: 0:00:12Progress:  62%|█████████████████████████▎               |  ETA: 0:00:08Progress:  69%|████████████████████████████▍            |  ETA: 0:00:06Progress:  77%|███████████████████████████████▌         |  ETA: 0:00:04Progress:  85%|██████████████████████████████████▊      |  ETA: 0:00:02Progress:  92%|█████████████████████████████████████▉   |  ETA: 0:00:01Progress: 100%|█████████████████████████████████████████| Time: 0:00:13Progress: 100%|█████████████████████████████████████████| Time: 0:00:14
# [ Info: Simulation duration: 14 seconds, 721 milliseconds
# ┌ Info: Write output states to netCDF file
# └ wflow_models/first_wflow_model/run_default/outstate/outstates.nc.

# %% [markdown]
# **What happens during the run?**
#
# 1. **Initialization**: Model reads configuration and loads static maps
# 2. **State loading**: Initial conditions are loaded from `inmaps/`
# 3. **Time loop**: For each timestep:
#    - Read forcing data (precipitation, temperature, PET)
#    - Compute interception and snow processes
#    - Calculate soil moisture dynamics
#    - Simulate runoff generation
#    - Route water through river network
#    - Write outputs at specified frequency
# 4. **Finalization**: Save final state for future runs
#
# **Runtime**: Depending on:
# - Simulation period length
# - Grid resolution and catchment size
# - Time step (daily, hourly, etc.)
# - Computer specifications
#
# Expect 1-30 minutes for typical daily simulations of 1-5 years.

# %% [markdown]
# ### 6.2 Monitoring Model Progress
#
# During the run, watch for:
# - **Water balance errors**: Should be < 0.1% per timestep
# - **Convergence issues**: Indicates potential parameter problems
# - **Memory usage**: Large models may need optimization
# - **Progress updates**: Shows current date being simulated

# %% [markdown]
# ---
#
# ## Part 7: Analyzing Model Results
#
# ### 7.1 Load and Inspect Output Files

# %%
# Load model outputs
output_file = "./wflow_models/first_wflow_model/run_default/output.nc"
ds = xr.open_dataset(output_file)

# Display dataset information
print("Output dataset contents:")
print(ds)
print("\nTime range:")
print(f"Start: {ds.time[0].values}")
print(f"End: {ds.time[-1].values}")
print(f"Total timesteps: {len(ds.time)}")
# Out:
# Output dataset contents:
# <xarray.Dataset> Size: 641kB
# Dimensions:  (time: 13, lat: 106, lon: 116, layer: 4)
# Coordinates:
#   * time     (time) datetime64[ns] 104B 2010-02-03 2010-02-04 ... 2010-02-15
#   * lat      (lat) float64 848B 45.81 45.82 45.83 45.84 ... 46.67 46.68 46.69
#   * lon      (lon) float64 928B 11.78 11.79 11.8 11.81 ... 12.72 12.73 12.74
#   * layer    (layer) float64 32B 1.0 2.0 3.0 4.0
# Data variables:
#     q_av     (time, lat, lon) float32 639kB ...
#
# Time range:
# Start: 2010-02-03T00:00:00.000000000
# End: 2010-02-15T00:00:00.000000000
# Total timesteps: 13

# %% [markdown]
# ### 7.2 Visualize Discharge Time Series
#
# Let's plot the simulated discharge at the basin outlet:

# %%
# Extract discharge at the outlet

# Get outlet location (typically where river has maximum upstream area)
discharge = ds['q_av'].max(dim=['lon', 'lat'])  # Adjust dimensions as needed

# Create discharge plot
fig, ax = plt.subplots(figsize=(14, 6))
discharge.plot(ax=ax, linewidth=1.5, color='steelblue')
ax.set_title('Simulated Discharge at Basin Outlet', fontsize=14, fontweight='bold')
ax.set_xlabel('Date', fontsize=12)
ax.set_ylabel('Discharge (m³/s)', fontsize=12)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.3 Spatial Visualization of Model Results
#
# Create spatial maps of outputs:

# %%
ds['q_av'].isel(time=6).plot()

# %% [markdown]
# ---
#
# ## Part 8: Best Practices and Troubleshooting
#
# ### 8.1 Common Issues and Solutions
#
# **Problem**: Model build fails with "No data found for region"
# - **Solution**: Check your region coordinates are correct (lon, lat order)
# - Verify data catalog has coverage for your area
# - Try a slightly larger bounding box
#
# **Problem**: Very high or low discharge values
# - **Solution**: Check forcing data units (mm/day vs mm/hour)
# - Verify DEM and river network are realistic
# - Inspect parameter maps for outliers
#
# **Problem**: Model runs slowly
# - **Solution**: Reduce grid resolution in build configuration
# - Use coarser timestep if appropriate
# - Limit output variables to essentials
#
# **Problem**: Large water balance errors
# - **Solution**: Check for missing or corrupted forcing data
# - Verify static maps have no missing values
# - Review numerical stability settings
#
# ### 8.2 Quality Control Checklist
#
# Before running your model, verify:
# - ✓ DEM has no sinks or anomalies
# - ✓ River network matches expected topology
# - ✓ Land use classes are reasonable
# - ✓ Soil parameters within physical ranges
# - ✓ Forcing data covers simulation period
# - ✓ No missing values in critical maps
# - ✓ Output directory has write permissions
#
# ### 8.3 Performance Optimization Tips
#
# 1. **Grid resolution**: Start coarse (500m-1km), refine if needed
# 2. **Timestep**: Use daily timestep unless sub-daily processes are critical
# 3. **Output frequency**: Write only what you need for analysis
# 4. **Spatial extent**: Model only the catchment of interest
# 5. **Warmup period**: Use 1-2 years to initialize states properly

# %% [markdown]
# ---
#
# ## Summary and Next Steps
#
# ### What We've Learned
#
# In this tutorial, you've learned the complete workflow for building and running your first Wflow model:
# 1. ✓ Set up and verify HydroMT installation
# 2. ✓ Build a complete Wflow model from scratch using example data
# 3. ✓ Visualize model components (topography, rivers, land use)
# 4. ✓ Understand model structure and key files
# 5. ✓ Run hydrological simulations
# 6. ✓ Analyze and visualize model outputs
#
# ### Additional Resources
#
# **Documentation**:
# - HydroMT docs: https://deltares.github.io/hydromt/
# - HydroMT-Wflow plugin: https://deltares.github.io/hydromt_wflow/
# - Wflow documentation: https://deltares.github.io/Wflow.jl/
#
# **Community**:
# - GitHub discussions: https://github.com/Deltares/hydromt/discussions
# - Issue tracker: https://github.com/Deltares/hydromt_wflow/issues
#
# ---
